# %% [markdown]
# # Error Analysis
#
# Now that I have my final model, I want to look at the individual points of error that are specific to that model. Within this section, I'll evaluate the residuals plots produced on the previous page and investigate the individual outliers to see if the model struggles with a specific type of data.

# %% [markdown]
# ### Library Imports

# %%
import numpy as np
from numpy.linalg import inv

import pandas as pd
import matplotlib.pyplot as plt
import requests
import pickle
import time
import seaborn as sns
import plotly.express as px

import pycaret
from pycaret.regression import *
from pycaret.regression import RegressionExperiment
from pycaret.regression import get_config
from pycaret.regression import save_model, load_model

from pandas import json_normalize
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import StandardScaler,OneHotEncoder

# %% [markdown]
# ### Data & Model Imports

# %%
with open('pickles/df_adj.pkl', 'rb') as f:
    df_adj = pickle.load(f) 
with open('pickles/df_model.pkl', 'rb') as f:
    df_model = pickle.load(f)
with open('pickles/combined_metrics.pkl', 'rb') as f:
    combined_metrics = pickle.load(f)

# %%
with open('pickles/data.pkl', 'rb') as f:
    data = pickle.load(f)
with open('pickles/data_unseen.pkl', 'rb') as f:
    data_unseen = pickle.load(f)

# %% [markdown]
# ### Model Setup

# %%
drop_cols = ['country',
             'city',
             'start_year',
             'end_year',
             'cost',
             'currency',
             'cost_km',
             'cost_real',
             'cost_km_2023',
             'time_diff',
             'lat',
             'lng',
             'wrb_class_name',
             'c_length',
             'c_tunnel',
             'inflation_index',
             'ppp_rate'
            
            ]
df_model = df_adj.drop(columns =drop_cols)

# %%
cont_feats = df_model.drop(columns=['region', 'sub_region','wrb_class_value','cost_real_2023','train_type']).columns.tolist()
cat_feats = ['region', 'sub_region','train_type']
ordinal_feats = ['wrb_class_value']

# %%
s = setup(data,
          target = 'cost_real_2023',
          ordinal_features ={'wrb_class_value': list(range(0, 30))},
          categorical_features= cat_feats,
          numeric_features= cont_feats,
          normalize = True,
          normalize_method = 'zscore',
          verbose = False,
          feature_selection = False,
          low_variance_threshold = 0.1,
          pca = False, 
          pca_components = 30,
          remove_multicollinearity = False,
          multicollinearity_threshold = 0.3
         )

# %%
transformed_data = get_config('X_train')
transformed_data
# Out:
#       rr?     length  tunnel_per     tunnel   elevated   at_grade  stations  \
# 989   1.0  72.699997    0.000000   0.000000  72.699997   0.000000      18.0
# 444   0.0  20.000000    1.000000  20.000000   0.000000   0.000000      18.0
# 83    0.0  12.000000    1.000000  12.000000   0.000000   0.000000      12.0
# 378   0.0  35.599998    1.000000  35.599998   0.000000   0.000000      25.0
# 565   0.0  21.000000    1.000000  21.000000   0.000000   0.000000      29.0
# ...   ...        ...         ...        ...        ...        ...       ...
# 1376  0.0   8.642788    0.000000   0.000000   0.000000   8.642788      16.0
# 305   0.0  26.600000    0.364662   9.700000   0.000000  16.900000      23.0
# 832   0.0   9.700000    1.000000   9.700000   0.000000   0.000000       6.0
# 1343  0.0   4.410000    0.000000   0.000000   0.000000   4.410000       7.0
# 364   0.0   4.500000    0.780000   3.510000   0.990000   0.000000       4.0
#
#       max_speed  track_gauge  overhead?  ...        prcp  land_cost_year  \
# 989        65.0       1435.0          1  ...    9.166667            2020
# 444        80.0       1435.0          1  ...   46.733334            2019
# 83         80.0       1435.0          1  ...   53.333332            2019
# 378        80.0       1435.0          1  ...  119.166664            2014
# 565        70.0       1435.0          0  ...   83.333336            2020
# ...         ...          ...        ...  ...         ...             ...
# 1376       80.0       1435.0          1  ...   55.416668            2005
# 305       120.0       1435.0          1  ...   58.083332            2001
# 832        80.0       1435.0          1  ...  140.166672            2020
# 1343       40.0       1435.0          1  ...   34.666668            2013
# 364        80.0       1435.0          1  ...  119.166664            2014
#
#      price_income_ratio  mortgage_perc_income  affordability_index urban?  \
# 989                   8                    77                    1      0
# 444                  29                   231                    0      0
# 83                    8                    65                    1      0
# 378                  26                   226                    0      0
# 565                   8                    56                    1      1
# ...                 ...                   ...                  ...    ...
# 1376                  5                    48                    2      0
# 305                   0                    58                    2      1
# 832                  29                   231                    0      1
# 1343                  2                    16                    6      0
# 364                  26                   226                    0      0
#
#      rental_yield  price_rent_ratio  union_density  stations_per_km
# 989             7                12       0.000000         0.247593
# 444             2                49      16.312870         0.900000
# 83              5                17      13.416667         1.000000
# 378             3                31      16.312870         0.702247
# 565             4                23      28.762728         1.380952
# ...           ...               ...            ...              ...
# 1376            5                16      21.885303         1.851254
# 305             8                10       5.337857         0.864662
# 832             1                58      16.312870         0.618557
# 1343           13                 7      11.802000         1.587302
# 364             3                31      16.312870         0.888889
#
# [802 rows x 68 columns]

# %% [markdown]
# ### The Model

# %%
blended = load_model('blended')
blended_tuned = load_model('blended_tuned')
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded

# %%
blended_tuned
# Out:
# Pipeline(memory=FastMemory(location=/var/folders/fm/_6kg8xkn3jz4slz27zwpqnhc0000gn/T/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['rr?', 'length', 'tunnel_per',
#                                              'tunnel', 'elevated', 'at_grade',
#                                              'stations', 'max_speed',
#                                              'track_gauge', 'overhead?', 'year',
#                                              'anglo', 'duration',
#                                              'country_pop_den', 'area_km',
#                                              'population',
#                                              'calculated_population',
#                                              'c...
#                                                                   n_jobs=-1,
#                                                                   random_state=8354)),
#                                              ('Bagging Regressor',
#                                               BaggingRegressor(estimator=LGBMRegressor(boosting_type='dart',
#                                                                                        colsample_bytree=0.5,
#                                                                                        learning_rate=0.2,
#                                                                                        min_child_weight=0.1,
#                                                                                        n_estimators=200,
#                                                                                        n_jobs=-1,
#                                                                                        objective='regression',
#                                                                                        random_state=8354,
#                                                                                        reg_alpha=0.5,
#                                                                                        reg_lambda=0.5,
#                                                                                        subsample=0.7),
#                                                                n_estimators=100,
#                                                                random_state=8354))],
#                                  n_jobs=-1, weights=[0.25, 0.1, 0.65]))])

# %% [markdown]
# ### The Data

# %%
data
# Out:
#       rr?     length  tunnel_per  tunnel   elevated   at_grade  stations  \
# 47    0.0  16.500000    1.000000   16.50   0.000000   0.000000      13.0
# 98    0.0  16.900000    1.000000   16.90   0.000000   0.000000      15.0
# 1289  0.0  14.377958    0.000000    0.00   0.000000  14.377958      15.0
# 1023  0.0  55.070000    1.000000   55.07   0.000000   0.000000      43.0
# 825   0.0  14.940000    0.087015    1.30  13.640000   0.000000      11.0
# ...   ...        ...         ...     ...        ...        ...       ...
# 1135  0.0  24.000000    0.500000   12.00   0.000000  12.000000      34.0
# 509   0.0   4.300000    1.000000    4.30   0.000000   0.000000       5.0
# 1495  0.0   7.723243    0.000000    0.00   0.000000   7.723243      27.0
# 1259  0.0   4.200000    0.000000    0.00   1.691144   2.494856       2.0
# 1197  0.0  39.600000    0.411616   16.30  23.300000   0.000000      25.0
#
#       max_speed  track_gauge  overhead?  ...        prcp  land_cost_year  \
# 47        100.0       1435.0          0  ...   48.166667            2010
# 98         80.0       1435.0          0  ...   78.750000            2009
# 1289       70.0       1435.0          1  ...   69.583333            2013
# 1023       80.0       1435.0          1  ...   58.333333            2008
# 825        80.0       1435.0          1  ...   85.083333            2019
# ...         ...          ...        ...  ...         ...             ...
# 1135       80.0       1435.0          1  ...   30.416667            2019
# 509        80.0       1435.0          0  ...   84.000000            2010
# 1495       60.0       1435.0          1  ...    8.750000            2017
# 1259       60.0       1435.0          1  ...   76.408333            2015
# 1197       80.0       1435.0          1  ...  119.583333            2018
#
#       price_income_ratio mortgage_perc_income  affordability_index  urban?  \
# 47                    17                  131                    0       0
# 98                    12                   91                    1       1
# 1289                   6                   51                    2       1
# 1023                  22                  184                    0       0
# 825                   29                  231                    0       1
# ...                  ...                  ...                  ...     ...
# 1135                  14                   97                    1       0
# 509                   14                  119                    0       0
# 1495                   3                   23                    4       0
# 1259                   2                   19                    5       1
# 1197                   9                  112                    0       1
#
#      rental_yield price_rent_ratio  union_density  stations_per_km
# 47              5               20      16.312870         0.787879
# 98              2               33      23.628823         0.887574
# 1289            5               17      28.591909         1.043264
# 1023            4               13      16.312870         0.780824
# 825             1               54      16.312870         0.736278
# ...           ...              ...            ...              ...
# 1135            3               32      25.160000         1.416667
# 509             4               23      38.052545         1.162791
# 1495           12                8      11.802000         3.495941
# 1259           11                9      11.802000         0.476190
# 1197            3               32      12.133509         0.631313
#
# [1147 rows x 69 columns]

# %%
data_unseen
# Out:
#       rr?     length  tunnel_per  tunnel  elevated   at_grade  stations  \
# 7     1.0   3.800000    1.000000    3.80       0.0   0.000000       4.0
# 10    0.0   7.400000    0.714286    5.00       2.0   0.000000       5.0
# 14    0.0  15.600000    0.820513   12.80       2.8   0.000000      15.0
# 18    0.0   0.800000    1.000000    0.80       0.0   0.000000       1.0
# 19    0.0   4.900000    1.000000    4.90       0.0   0.000000       5.0
# ...   ...        ...         ...     ...       ...        ...       ...
# 1632  0.0  43.000000    0.120000    5.16       0.0  37.840000      20.0
# 1640  1.0  16.465009    0.000000    0.00       0.0  16.465009       4.0
# 1647  0.0  37.500000    0.000000    0.00       0.0  37.500000      18.0
# 1659  0.0  14.255881    0.000000    0.00       0.0  14.255881      26.0
# 1663  0.0   0.500000    0.000000    0.00       0.0   0.500000       1.0
#
#       max_speed  track_gauge  overhead?  ...        prcp  land_cost_year  \
# 7          80.0       1432.0          0  ...  202.600000            2007
# 10         80.0       1435.0          0  ...  202.600000            2014
# 14         80.0       1432.0          0  ...  202.600000            1978
# 18         80.0       1435.0          0  ...   48.491667            1999
# 19         80.0       1435.0          0  ...   48.491667            1981
# ...         ...          ...        ...  ...         ...             ...
# 1632      120.0       1676.0          1  ...   90.833333            2004
# 1640       90.0       1435.0          0  ...   83.333333            2020
# 1647       90.0       1435.0          1  ...  128.750000            2020
# 1659       70.0       1435.0          1  ...   51.250000            2020
# 1663       30.0       1067.0          1  ...   51.333333            2020
#
#       price_income_ratio mortgage_perc_income  affordability_index  urban?  \
# 7                     15                   96                    0       1
# 10                    27                  174                    0       1
# 14                     1                   12                    1       1
# 18                     0                   10                    4       1
# 19                     0                    6                    6       1
# ...                  ...                  ...                  ...     ...
# 1632                   7                   40                    2       0
# 1640                   8                   56                    1       0
# 1647                  10                   98                    1       1
# 1659                   7                   44                    2       0
# 1663                   8                   65                    1       0
#
#      rental_yield price_rent_ratio  union_density  stations_per_km
# 7               3               19      21.699286         1.052632
# 10              3               33      21.699286         0.714286
# 14              7                3      21.699286         0.961538
# 18              6                8      17.506000         1.250000
# 19              8                6      17.506000         1.020408
# ...           ...              ...            ...              ...
# 1632            8               10      15.323333         0.465116
# 1640            5               18      28.762727         0.242939
# 1647            7               14       9.637500         0.480000
# 1659            4               24      67.999000         1.823809
# 1663            4               21      19.288182         2.000000
#
# [287 rows x 69 columns]

# %% [markdown]
# ### Model Evaluation

# %%
finalized_best = finalize_model(blended_tuned)
predictions = predict_model(finalized_best, data=data_unseen)
# Out:
# <style type="text/css">
# </style>
# <table id="T_22041">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22041_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_22041_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_22041_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_22041_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_22041_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_22041_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_22041_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22041_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22041_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_22041_row0_col1" class="data row0 col1" >503.6843</td>
#       <td id="T_22041_row0_col2" class="data row0 col2" >677512.4539</td>
#       <td id="T_22041_row0_col3" class="data row0 col3" >823.1114</td>
#       <td id="T_22041_row0_col4" class="data row0 col4" >0.8765</td>
#       <td id="T_22041_row0_col5" class="data row0 col5" >0.5185</td>
#       <td id="T_22041_row0_col6" class="data row0 col6" >0.5182</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions['Residuals'] = predictions['cost_real_2023'] - predictions['prediction_label']

# %%
outliers = predictions.sort_values(by='Residuals', key=abs, ascending=False)

# %%
mean_res = np.mean(outliers['Residuals'])
std_res = np.std(outliers['Residuals'])

outliers['standardized_residuals'] = (outliers['Residuals'] - mean_res) / std_res

# %%
high_residuals = outliers[abs(outliers['standardized_residuals'])>3].index.tolist()

# %%
high_residuals
# Out:
# [543, 1497, 1158, 1632]

# %%
column_to_plot = "standardized_residuals"

plt.figure(figsize=(10, 5))
sns.histplot(outliers[column_to_plot], kde=True)
plt.title(f'Histogram of {column_to_plot}')
plt.show()

# %%
len(high_residuals)
# Out:
# 4

# %% [markdown]
# ### Residuals & Leverage
#
# There are a few ways to go about outlier removal. Since I've previously cleaned the dataset and each datapoint that remains has been proven to be accurate and representative, I'll be less strict about eliminating outliers.
#
# Within this section I'll create a list of indexes that are either large outliers by measure of standardized residuals or by their leverage on the previous model iteration.

# %%
outliers[abs(outliers['standardized_residuals'])>2]
# Out:
#       rr?     length  tunnel_per     tunnel   elevated  at_grade  stations  \
# 543   0.0  16.000000    0.100000   1.600000  12.800000      1.60      13.0
# 1497  0.0  74.000000    0.000000   0.000000   0.000000     74.00      11.0
# 1158  0.0  19.700001    0.131980   2.600000  17.100000      0.00      14.0
# 1632  0.0  43.000000    0.120000   5.160000   0.000000     37.84      20.0
# 1105  0.0   9.700000    0.731959   7.100000   0.000000      2.60       8.0
# 315   0.0  32.000000    1.000000  32.000000   0.000000      0.00       7.0
# 952   0.0  23.629999    0.000000   0.000000  23.629999      0.00      17.0
# 664   0.0  37.353001    0.278050  10.386000  26.966999      0.00       9.0
# 206   0.0  28.000000    1.000000  28.000000   0.000000      0.00      16.0
# 309   0.0  21.700001    1.000000  21.700001   0.000000      0.00      16.0
# 1193  0.0  15.000000    0.213333   3.200000  10.800000      1.00       7.0
# 1160  0.0  36.000000    0.419444  15.100000  15.900000      5.00      13.0
# 343   0.0  25.100000    0.956175  24.000000   1.100000      0.00      25.0
# 961   0.0  28.400000    0.000000   0.000000  28.400000      0.00       8.0
# 1125  0.0  20.000000    0.200000   4.000000   4.000000     12.00      15.0
# 921   0.0   7.563920    0.735587   5.563920   1.000000      1.00       4.0
# 1045  0.0  17.700001    0.000000   0.000000  17.700001      0.00      18.0
# 541   0.0  11.500000    0.000000   0.000000  11.500000      0.00       8.0
# 10    0.0   7.400000    0.714286   5.000000   2.000000      0.00       5.0
#
#       max_speed  track_gauge  overhead?  ...  affordability_index  urban?  \
# 543        90.0       1067.0          1  ...                    0       1
# 1497      120.0       1435.0          1  ...                    0       0
# 1158       80.0       1435.0          1  ...                    0       1
# 1632      120.0       1676.0          1  ...                    2       0
# 1105       60.0       1435.0          0  ...                    2       1
# 315       120.0       1435.0          1  ...                    0       1
# 952       100.0       1435.0          0  ...                    0       1
# 664        80.0       1435.0          1  ...                    0       0
# 206        80.0       1435.0          1  ...                    0       0
# 309       120.0       1435.0          1  ...                    1       1
# 1193       95.0       1435.0          0  ...                    2       1
# 1160      100.0       1067.0          1  ...                    1       1
# 343        80.0       1435.0          1  ...                    1       1
# 961       140.0       1435.0          0  ...                    0       1
# 1125       80.0       1435.0          1  ...                    1       0
# 921        90.0       1435.0          1  ...                    3       0
# 1045       80.0          0.0          0  ...                    0       1
# 541        90.0       1435.0          0  ...                    0       1
# 10         80.0       1435.0          0  ...                    0       1
#
#      rental_yield  price_rent_ratio  union_density stations_per_km  \
# 543             1                72      39.355000        0.812500
# 1497            6                16      23.799999        0.148649
# 1158            4                22      20.403334        0.710660
# 1632            8                10      15.323334        0.465116
# 1105            5                17      21.885303        0.824742
# 315             5                18       5.337857        0.218750
# 952             3                31       3.348849        0.719424
# 664             1                52      16.312870        0.240945
# 206             1                52      16.312870        0.571429
# 309             7                13       5.337857        0.737327
# 1193           10                 9       0.000000        0.466667
# 1160            4                22      17.299999        0.361111
# 343             3                 7       9.769591        0.996016
# 961             3                26       3.348849        0.281690
# 1125            5                18      28.762728        0.750000
# 921            11                 8      11.802000        0.528826
# 1045            4                20      16.784445        1.016949
# 541             1                72      39.355000        0.695652
# 10              3                33      21.699286        0.714286
#
#      cost_real_2023  prediction_label    Residuals  standardized_residuals
# 543     8570.662109       3030.404373  5540.257736                6.678389
# 1497    8458.942383       4627.894914  3831.047469                4.597064
# 1158    6564.873047       3095.015829  3469.857218                4.157238
# 1632     878.751953       3308.650937 -2429.898984               -3.026966
# 1105    4499.181641       2098.132764  2401.048876                2.855737
# 315     1694.956909       3940.098860 -2245.141951               -2.801985
# 952     6790.682129       4575.193908  2215.488221                2.629778
# 664     2148.754395       4318.112323 -2169.357928               -2.709702
# 206     9050.780273       6968.794289  2081.985985                2.467210
# 309     1775.105103       3766.549041 -1991.443939               -2.493054
# 1193    4939.992676       2961.867035  1978.125640                2.340738
# 1160    6116.916992       4175.094627  1941.822365                2.296532
# 343     6073.417480       4136.296797  1937.120683                2.290806
# 961     2245.293701       4158.749531 -1913.455829               -2.398087
# 1125    4422.219238       2516.582985  1905.636253                2.252467
# 921     3716.671387       1885.226739  1831.444647                2.162123
# 1045     964.171143       2768.025585 -1803.854443               -2.264624
# 541     4310.504883       2533.040079  1777.464804                2.096391
# 10      3543.472656       1831.595134  1711.877522                2.016525
#
# [19 rows x 72 columns]

# %% [markdown]
# The above data points are all of the datapoints in the set that resulted in a standardized residual above 3. A residual, in this case, is the difference between the predicted cost of a project and the actual cost of the project.

# %%
X = data.drop(columns = ['cost_real_2023','region','sub_region','train_type'])
X['Intercept'] = 1
X = X[['Intercept'] + [col for col in X if col != 'Intercept']]
X_numeric = X.values

# %%
X_unseen = data_unseen.drop(columns = ['cost_real_2023','region','sub_region','train_type'])
X_unseen['Intercept'] = 1
X_unseen = X_unseen[['Intercept'] + [col for col in X_unseen if col != 'Intercept']]
X_unseen_numeric = X_unseen.values

# %%
H = X_numeric @ np.linalg.inv(X_numeric.T @ X_numeric) @ X_numeric.T
leverage = np.diag(H)

# %%
H_unseen = X_unseen_numeric @ np.linalg.pinv(X_unseen_numeric.T @ X_unseen_numeric) @ X_unseen_numeric.T
leverage_unseen = np.diag(H_unseen)

# %%
data['leverage'] = leverage
data_unseen['leverage'] = leverage_unseen

# %%
data.sort_values(by='leverage',ascending=False)
# Out:
#       rr?     length  tunnel_per  tunnel   elevated  at_grade  stations  \
# 1368  0.0  14.402527    0.000000   0.000  14.402527      0.00      16.0
# 516   0.0   3.600000    1.000000   2.700   0.000000      0.00       2.0
# 1325  0.0   0.680000    0.000000   0.000   0.000000      0.68      17.0
# 1464  0.0  27.000000    0.000000   0.000   5.000000     22.00      13.0
# 1359  0.0  77.000000    0.083117   6.400   0.000000     70.60      57.0
# ...   ...        ...         ...     ...        ...       ...       ...
# 698   0.0  13.800000    1.000000  13.800   0.000000      0.00       8.0
# 709   0.0  33.300000    1.000000  33.300   0.000000      0.00      28.0
# 702   0.0  19.000000    1.000000  19.000   0.000000      0.00      11.0
# 706   0.0  25.296000    1.000000  25.296   0.000000      0.00      15.0
# 707   0.0  25.700000    0.945525  24.300   1.400000      0.00      20.0
#
#       max_speed  track_gauge  overhead?  ...  land_cost_year  \
# 1368       90.0          0.0          0  ...            2020
# 516        80.0       1435.0          1  ...            2018
# 1325       50.0       1435.0          1  ...            2007
# 1464       60.0       1435.0          1  ...            2020
# 1359       80.0       1435.0          1  ...            1991
# ...         ...          ...        ...  ...             ...
# 698        80.0       1435.0          1  ...            2015
# 709        80.0       1435.0          1  ...            2016
# 702        80.0       1435.0          1  ...            2020
# 706        80.0       1435.0          1  ...            2018
# 707        80.0       1435.0          1  ...            2017
#
#       price_income_ratio  mortgage_perc_income affordability_index  urban?  \
# 1368                  13                   183                   0       1
# 516                    9                    63                   1       1
# 1325                   2                    15                   5       0
# 1464                   4                    96                   1       1
# 1359                   7                    76                   1       0
# ...                  ...                   ...                 ...     ...
# 698                   26                   230                   0       0
# 709                   25                   210                   0       0
# 702                   29                   231                   0       0
# 706                   28                   224                   0       0
# 707                   23                   189                   0       0
#
#       rental_yield price_rent_ratio union_density  stations_per_km  leverage
# 1368             6               14      8.441000         1.110916  0.997604
# 516              3               28     38.052545         0.740741  0.935985
# 1325            13                7     11.802000        25.000000  0.663954
# 1464            40                9      0.000000         0.481481  0.579281
# 1359             4               26     28.591909         0.740260  0.367571
# ...            ...              ...           ...              ...       ...
# 698              3               33     16.312870         0.579710  0.016399
# 709              2               37     16.312870         0.840841  0.016079
# 702              1               52     16.312870         0.578947  0.015223
# 706              2               47     16.312870         0.592979  0.014763
# 707              2               36     16.312870         0.778210  0.013585
#
# [1147 rows x 70 columns]

# %%
predictions_seen = predict_model(finalized_best, data=data)
predictions_unseen = predict_model(finalized_best, data=data_unseen)
# Out:
# <style type="text/css">
# </style>
# <table id="T_28381">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28381_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_28381_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_28381_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_28381_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_28381_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_28381_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_28381_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28381_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28381_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_28381_row0_col1" class="data row0 col1" >194.7296</td>
#       <td id="T_28381_row0_col2" class="data row0 col2" >106226.7784</td>
#       <td id="T_28381_row0_col3" class="data row0 col3" >325.9245</td>
#       <td id="T_28381_row0_col4" class="data row0 col4" >0.9814</td>
#       <td id="T_28381_row0_col5" class="data row0 col5" >0.3654</td>
#       <td id="T_28381_row0_col6" class="data row0 col6" >0.3365</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_a9394">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9394_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a9394_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a9394_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a9394_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a9394_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a9394_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a9394_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9394_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9394_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_a9394_row0_col1" class="data row0 col1" >503.6843</td>
#       <td id="T_a9394_row0_col2" class="data row0 col2" >677512.4539</td>
#       <td id="T_a9394_row0_col3" class="data row0 col3" >823.1114</td>
#       <td id="T_a9394_row0_col4" class="data row0 col4" >0.8765</td>
#       <td id="T_a9394_row0_col5" class="data row0 col5" >0.5185</td>
#       <td id="T_a9394_row0_col6" class="data row0 col6" >0.5182</td>
#     </tr>
#   </tbody>
# </table>

# %%
data['residuals'] = predictions_seen['cost_real_2023'] - predictions_seen['prediction_label']
data_unseen['residuals'] = predictions_unseen['cost_real_2023'] - predictions_unseen['prediction_label']

# %%
mean_res = np.mean(data['residuals'])
std_res = np.std(data['residuals'])

data['standardized_residuals'] = (data['residuals'] - mean_res) / std_res

# %%
mean_res = np.mean(data_unseen['residuals'])
std_res = np.std(data_unseen['residuals'])

data_unseen['standardized_residuals'] = (data_unseen['residuals'] - mean_res) / std_res

# %% [markdown]
# #### Leverage Histogram

# %%
column_to_plot = "leverage"

plt.figure(figsize=(10, 5))
sns.histplot(data[column_to_plot], kde=True)
plt.title(f'Histogram of {column_to_plot}')
plt.show()

# %% [markdown]
# #### Residuals vs. Leverage

# %%
plt.scatter(data['leverage'], data['standardized_residuals'])
plt.xlabel('leverage')
plt.ylabel('residuals')
plt.title('Leverage vs. Residuals')
plt.show()

# %% [markdown]
# From the above plots, we can see 2 things:
#
# 1) Several well distributed outliers in the long right tail
# 2) A tight, low leverage grouping around 0.
#
# Because the outliers aren't (all) obvious, I'll generate the cook's distance for each point to identify which points are outliers.

# %% [markdown]
# #### Cooks Distance

# %%
p = X.shape[1]
mse = np.mean(data['residuals'] ** 2)
data['cooks_distance'] = (data['residuals'] ** 2 / (p * mse)) * (data['leverage'] / (1 - data['leverage']) ** 2)
data.sort_values(by='cooks_distance',ascending=False).head(5)
# Out:
#       rr?     length  tunnel_per  tunnel   elevated  at_grade  stations  \
# 1368  0.0  14.402527    0.000000     0.0  14.402527       0.0      16.0
# 516   0.0   3.600000    1.000000     2.7   0.000000       0.0       2.0
# 1414  0.0  23.900000    0.000000     0.0  23.900000       0.0      15.0
# 1464  0.0  27.000000    0.000000     0.0   5.000000      22.0      13.0
# 966   0.0  42.300000    0.347518    14.7  27.600000       0.0      43.0
#
#       max_speed  track_gauge  overhead?  ...  affordability_index  urban?  \
# 1368       90.0          0.0          0  ...                    0       1
# 516        80.0       1435.0          1  ...                    1       1
# 1414       90.0       1435.0          1  ...                    0       1
# 1464       60.0       1435.0          1  ...                    1       1
# 966        80.0       1435.0          1  ...                    0       1
#
#       rental_yield price_rent_ratio  union_density  stations_per_km  leverage  \
# 1368             6               14       8.441000         1.110916  0.997604
# 516              3               28      38.052545         0.740741  0.935985
# 1414             4               22       4.854000         0.627615  0.249653
# 1464            40                9       0.000000         0.481481  0.579281
# 966              3               33      12.133509         1.016548  0.295656
#
#         residuals  standardized_residuals  cooks_distance
# 1368   -97.794967               -0.391911      237.020710
# 516    324.444552                0.908911        3.429327
# 1414  2312.061342                7.032301        0.338092
# 1464   693.752602                2.046664        0.224665
# 966   1067.796484                3.199007        0.096920
#
# [5 rows x 73 columns]

# %%
fig = px.bar(data, x=data['cooks_distance'], y=data.index, orientation='h', title="Cook's Distance",
             color_discrete_sequence=['black'], width=1000)

# Change the background color of the plot to a light gray for better contrast
fig.update_layout(plot_bgcolor='blanchedalmond', paper_bgcolor='blanchedalmond')

fig.show()

# %%
p = X_unseen.shape[1]
mse = np.mean(data_unseen['residuals'] ** 2)
data_unseen['cooks_distance'] = (data_unseen['residuals'] ** 2 / (p * mse)) * (data_unseen['leverage'] / (1 - data_unseen['leverage']) ** 2)
data_unseen.sort_values(by='cooks_distance',ascending=False)
# Out:
#       rr?     length  tunnel_per  tunnel  elevated   at_grade  stations  \
# 1497  0.0  74.000000         0.0     0.0       0.0  74.000000      11.0
# 543   0.0  16.000000         0.1     1.6      12.8   1.600000      13.0
# 1098  0.0  22.900000         1.0    22.9       0.0   0.000000      15.0
# 1616  0.0  19.000000         0.0     0.0       0.0  19.000000       6.0
# 1045  0.0  17.700000         0.0     0.0      17.7   0.000000      18.0
# ...   ...        ...         ...     ...       ...        ...       ...
# 523   0.0   8.000000         0.0     0.0       0.0   8.000000      20.0
# 1476  0.0   1.000000         0.0     0.0       0.0   0.970000       3.0
# 1354  0.0   1.200000         0.0     0.0       0.0   1.200000       2.0
# 152   0.0   4.393319         0.0     0.0       0.0   4.393319       9.0
# 518   0.0   1.500000         1.0     1.5       0.0   0.000000       1.0
#
#       max_speed  track_gauge  overhead?  ...  affordability_index  urban?  \
# 1497      120.0       1435.0          1  ...                    0       0
# 543        90.0       1067.0          1  ...                    0       1
# 1098       80.0       1435.0          1  ...                    0       1
# 1616      160.0       1435.0          1  ...                    0       1
# 1045       80.0          0.0          0  ...                    0       1
# ...         ...          ...        ...  ...                  ...     ...
# 523        50.0       1435.0          1  ...                    1       1
# 1476       40.0       1000.0          1  ...                    1       0
# 1354       60.0       1435.0          1  ...                    1       1
# 152        40.0       1435.0          1  ...                    1       1
# 518        80.0       1435.0          1  ...                    1       1
#
#       rental_yield price_rent_ratio  union_density  stations_per_km  leverage  \
# 1497             6               16      23.800000         0.148649  0.522255
# 543              1               72      39.355000         0.812500  0.323428
# 1098             6               14       9.000000         0.655022  0.786102
# 1616             1               53      11.405556         0.315789  0.742749
# 1045             4               20      16.784444         1.016949  0.466612
# ...            ...              ...            ...              ...       ...
# 523              3               25      38.052545         2.500000  0.102807
# 1476             3               27      17.506000         3.000000  0.089747
# 1354             3               31      10.648056         1.666667  0.083839
# 152              2               37      10.648056         2.048565  0.099270
# 518              3               30      38.052545         0.666667  0.077420
#
#         residuals  standardized_residuals  cooks_distance
# 1497  3831.047469                4.597064    7.510404e-01
# 543   5540.257736                6.678389    4.850085e-01
# 1098  -667.404122               -0.880755    1.711513e-01
# 1616  -699.051921               -0.919293    1.226555e-01
# 1045 -1803.854443               -2.264624    1.193466e-01
# ...           ...                     ...             ...
# 523     -7.419025               -0.077083    1.572118e-07
# 1476     7.158856               -0.059331    1.241431e-07
# 1354    -5.362894               -0.074579    6.424541e-08
# 152      2.288425               -0.065262    1.432980e-08
# 518      2.112505               -0.065476    9.077753e-09
#
# [287 rows x 73 columns]

# %% [markdown]
# #### Cooks Distance Removal Using 4/n rule
#
# The Cook's Distance combines the insights provided by both the residuals and the leverage features to create 1 feature that can identify which high residual points have a high leverage. A rule of thumb for determining which data are influential and which are not is the 4/n rule, where n is the number of observations in the dataset.
#
# Any datapoint with a Cook's Distance above this threshold will be evaluated.

# %%
n_seen = data.shape[0]
n_unseen= data_unseen.shape[0]
k = len(data.columns)

threshold_seen = 4/(n_seen-k-1)
threshold_unseen = 4/(n_unseen-k-1)

threshold_seen
# Out:
# 0.003727865796831314

# %%
threshold_unseen
# Out:
# 0.018779342723004695

# %%
cooks_outliers_seen = data[data['cooks_distance']>threshold_seen].sort_values(by='cooks_distance',ascending=False).index
cooks_outliers_unseen = data_unseen[data_unseen['cooks_distance']>threshold_unseen].sort_values(by='cooks_distance',ascending=False).index

# %% [markdown]
# ### Cook's Distance Evaluation
#
# I'll need to look at each datapoint to determine why the points are influential. Similar to sheet 6, I'll briefly describe the data and then identify what I intend to do with the data. Once again, it's not my goal to drop data, but I will drop the data if the information cannot be reconciled.

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Seen Data

# %%
cooks_outliers_seen
# Out:
# Int64Index([1368,  516, 1414, 1464,  966, 1517, 1480, 1168,  989, 1359, 1237,
#             1166, 1254,  965,   97,  388,  988,   15,  225,  389,  599,  643,
#              345, 1194, 1247,  859,  563, 1002, 1043, 1201,  909, 1511, 1056,
#              318, 1114, 1224,   16,  344, 1660, 1093,  408, 1462,  924, 1134,
#              391, 1643,  501, 1657, 1136,  901,  653,  922, 1615,  229, 1472,
#              296,  456, 1026, 1646,  552, 1576,  994,  793,  848,  193,  631,
#              885, 1038,  221, 1092,  500, 1648, 1057, 1023,  496,  984,  871,
#             1071,  860,  208,  646],
#            dtype='int64')

# %%
cooks_drop=[]

# %%
df_adj.loc[[15]]
# Out:
#    country       city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 15      HK  Hong Kong        1994      1998  0.0    34.0    0.235294     8.0
#
#     elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 15       6.0      20.0       9.0       80.0       1432.0          0  34000.0
#
#    currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 15      HKD  1996  0.130742  4445.232965  130.742146       0.0       0.0
#
#     anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  duration  \
# 15      0         1.739617     7733.003593    227.441282        MRT         4
#
#     country_pop_den region    sub_region  area_km   lat    lng  population  \
# 15      6129.047619   Asia  Eastern Asia    290.0  22.3  114.2   7450000.0
#
#     time_diff  calculated_population  city_density  per_below_line  \
# 15         24           6.546710e+06  22574.863522       91.142996
#
#     reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 15    1653.430868       Acrisols              0.0             13.0
#
#     prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 15           37.0            4.0            0.0            15.0
#
#     prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 15            3.0               0.0                0.0             0.0
#
#     prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 15              0.0            0.0             0.0             4.0
#
#     prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 15           3.0             0.0             0.0               0.0
#
#     prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 15            5.0             0.0           1.0             1.0
#
#     prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 15             1.0            4.0             0.0            0.0
#
#     prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 15            0.0              0.0             3.0            3.0
#
#     prob_Stagnosols  elevation  tavg  tmin  tmax   prcp  land_cost_year  \
# 15              0.0        0.0  23.5  21.6  26.0  202.6            1996
#
#     price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 15                   1                    13                    1       1
#
#     rental_yield  price_rent_ratio  union_density  stations_per_km
# 15             5                 5      21.699286         0.264706

# %% [markdown]
# This is the Airport Railway in Hong Kong, the overall cost is reported to be 35.1Bn HKD instead of the provided 34Bn. [adjust]

# %%
data.loc[15,'length'] = 34
data.loc[15,'cost_real_2023'] = 35100*0.130742*1.73

# %%
df_adj.loc[[16]]
# Out:
#    country       city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 16      HK  Hong Kong        2012      2022  1.0    17.0    0.882353    15.0
#
#     elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 16       2.0       0.0       9.0       80.0       1435.0          0  90700.0
#
#    currency  year  ppp_rate  cost_real      cost_km  c_length  c_tunnel  \
# 16      HKD  2017   0.16635   1509.248  5335.294118       0.0       0.0
#
#     anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  duration  \
# 16      0          1.11352     1668.411785      98.14187        MRT        10
#
#     country_pop_den region    sub_region  area_km   lat    lng  population  \
# 16      7041.142857   Asia  Eastern Asia    290.0  22.3  114.2   7450000.0
#
#     time_diff  calculated_population  city_density  per_below_line  \
# 16          3           7.330602e+06  25277.937294       22.368809
#
#     reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 16    8016.431435       Acrisols              0.0             13.0
#
#     prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 16           37.0            4.0            0.0            15.0
#
#     prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 16            3.0               0.0                0.0             0.0
#
#     prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 16              0.0            0.0             0.0             4.0
#
#     prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 16           3.0             0.0             0.0               0.0
#
#     prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 16            5.0             0.0           1.0             1.0
#
#     prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 16             1.0            4.0             0.0            0.0
#
#     prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 16            0.0              0.0             3.0            3.0
#
#     prob_Stagnosols  elevation  tavg  tmin  tmax   prcp  land_cost_year  \
# 16              0.0        0.0  23.5  21.6  26.0  202.6            2017
#
#     price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 16                  36                   224                    0       1
#
#     rental_yield  price_rent_ratio  union_density  stations_per_km
# 16             2                44      21.699286         0.529412

# %% [markdown]
# This is the Sha Tin-Central Link in Hong Kong. It's notable because it's the most expensive project in the history of Hong Kong. [remove]

# %%
cooks_drop.append(16)

# %%
df_adj.loc[[97]]
# Out:
#    country       city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 97      ES  Barcelona        2003      2026  0.0    47.8    0.914226    43.7
#
#     elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 97       4.1       0.0      52.0       80.0       1445.0          1  5954.0
#
#    currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 97      EUR  2015  1.504348  8956.885399  187.38254      47.8      43.7
#
#     anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  duration  \
# 97      0         1.151588     10314.64178    215.787485        MRT        23
#
#     country_pop_den  region       sub_region  area_km      lat     lng  \
# 97        92.952686  Europe  Southern Europe   1072.0  41.3825  2.1769
#
#     population  time_diff  calculated_population  city_density  \
# 97   4800000.0          5           4.679451e+06   4365.159198
#
#     per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 97        3.466943    25732.01836      Leptosols             16.0
#
#     prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 97              1.0            0.0            0.0            0.0
#
#     prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 97            12.0            0.0               4.0                0.0
#
#     prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 97            12.0              1.0            0.0             1.0
#
#     prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 97             6.0           2.0             0.0             3.0
#
#     prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 97               0.0           11.0             0.0           0.0
#
#     prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 97             1.0            11.0            1.0             6.0
#
#     prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 97            9.0            1.0              2.0            15.0
#
#     prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  tmax   prcp  \
# 97            1.0              0.0       30.0  16.7  12.7  20.8  78.75
#
#     land_cost_year  price_income_ratio  mortgage_perc_income  \
# 97            2015                   9                    66
#
#     affordability_index  urban?  rental_yield  price_rent_ratio  \
# 97                    1       1             3                25
#
#     union_density  stations_per_km
# 97      23.628823         1.087866

# %% [markdown]
# This is L9/10 Metro in Barcelona. The data are mostly correct. [keep]

# %%
df_adj.loc[[193]]
# Out:
#     country      city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 193      CN  Shanghai        2000      2005  0.0  22.032    0.943264  20.782
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 193      1.25       0.0       9.0       80.0       1435.0          1  12600.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 193      CNY  2003  0.369276  4652.871764  211.18699       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 193      0         1.483402     6902.078422    313.275164        MRT
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 193         5       136.704621   Asia  Eastern Asia  14922.7  31.1667
#
#           lng  population  time_diff  calculated_population  city_density  \
# 193  121.4667  24073000.0         17           1.600546e+07    1072.55821
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 193       95.483789    1653.430868      Fluvisols             11.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 193              0.0            5.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 193            14.0            9.0               1.0                2.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 193             0.0              1.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 193            19.0           6.0             0.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 193               0.0           17.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 193             0.0             6.0            4.0             1.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 193            2.0            1.0              6.0             3.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg   tmin       tmax  \
# 193            0.0              0.0        0.0  16.133333  12.45  19.841667
#
#           prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 193  92.658333            2003                  19                   163
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 193                    0       0             5                 2
#
#      union_density  stations_per_km
# 193       16.31287         0.408497

# %% [markdown]
# This is Shanghai Line 4 Phase 1. I'm unable to verify [remove]

# %%
cooks_drop.append(193)

# %%
df_adj.loc[[208]]
# Out:
#     country      city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 208      CN  Shanghai        2021      2027  1.0   41.36    0.935203   38.68
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 208      2.68       0.0      17.0      120.0       1435.0          1  39900.0
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 208      CNY  2024  0.248641  9920.770588  239.863892       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 208      0         0.984983      9771.78634    236.261759        MRT
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 208         6       149.723553   Asia  Eastern Asia  14922.7  31.1667
#
#           lng  population  time_diff  calculated_population  city_density  \
# 208  121.4667  24073000.0         -4           2.649957e+07    1775.78956
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 208       37.855836    8016.431435      Fluvisols             11.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 208              0.0            5.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 208            14.0            9.0               1.0                2.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 208             0.0              1.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 208            19.0           6.0             0.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 208               0.0           17.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 208             0.0             6.0            4.0             1.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 208            2.0            1.0              6.0             3.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg   tmin       tmax  \
# 208            0.0              0.0        0.0  16.133333  12.45  19.841667
#
#           prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 208  92.658333            2020                  29                   231
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 208                    0       0             1                52
#
#      union_density  stations_per_km
# 208       16.31287         0.411025

# %% [markdown]
# This is the Shanghai Jiamin Line. The data are accurate. [keep]

# %%
df_adj.loc[[221]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 221      EG  Cairo        2020      2024  0.0    19.0         0.9    17.1
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 221       0.0       1.9      17.0       80.0       1435.0          0  12000.0
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 221      EGP  2022  0.213574  2562.882701  134.888563       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 221      0         1.015482     2602.562323    136.976964        MRT
#
#      duration  country_pop_den  region       sub_region  area_km      lat  \
# 221         4       107.956335  Africa  Northern Africa   2010.0  30.0444
#
#          lng  population  time_diff  calculated_population  city_density  \
# 221  31.2358  20296000.0         -2           2.111182e+07  10503.392149
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 221       72.636646    3600.913793      Leptosols             16.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 221              0.0            0.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 221             5.0            2.0               1.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 221             7.0              0.0            0.0             6.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 221             7.0           0.0             0.0            14.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 221               0.0            2.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 221             0.0             2.0            0.0             2.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 221           14.0            1.0             11.0            23.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax   prcp  \
# 221            0.0              0.0       22.0  23.14  16.0  28.0  19.68
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 221            2020                  13                   193
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 221                    0       1             5                18
#
#      union_density  stations_per_km
# 221           23.8         0.894737

# %% [markdown]
# This is Cairo Line 4 (All Phases). The project cost is oft reported in Yen, which complicates the conversion. Because of this, I'll remove.

# %%
cooks_drop.append(221)

# %%
df_adj.loc[[225]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 225      EG  Cairo        2018      2023  1.0  103.31         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 225       0.0    103.31      18.0      120.0       1435.0          1  31000.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 225      EGP  2021  0.220401  6832.419124  66.135119       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023  train_type  \
# 225      0         1.007292      6882.24165     66.617381  Light Rail
#
#      duration  country_pop_den  region       sub_region  area_km      lat  \
# 225         5       107.956335  Africa  Northern Africa   2010.0  30.0444
#
#          lng  population  time_diff  calculated_population  city_density  \
# 225  31.2358  20296000.0         -1             20699890.4  10298.452935
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 225       64.458012    3600.913793      Leptosols             16.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 225              0.0            0.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 225             5.0            2.0               1.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 225             7.0              0.0            0.0             6.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 225             7.0           0.0             0.0            14.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 225               0.0            2.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 225             0.0             2.0            0.0             2.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 225           14.0            1.0             11.0            23.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax   prcp  \
# 225            0.0              0.0       22.0  23.14  16.0  28.0  19.68
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 225            2020                  13                   193
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 225                    0       1             5                18
#
#      union_density  stations_per_km
# 225           23.8         0.174233

# %% [markdown]
# This is Cairo Capital LRT (All Phases. Due to the length of this line, I'll drop the project. [remove]

# %%
cooks_drop.append(225)

# %%
df_adj.loc[[229]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 229      EG  Cairo        2017      2025  0.0    11.6         1.0    11.6
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 229       0.0       0.0      12.0       80.0       1435.0          0  4000.0
#
#     currency  year  ppp_rate   cost_real    cost_km  c_length  c_tunnel  \
# 229      EGP  2021  0.220401  881.602468  76.000213       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 229      0         1.007292      888.031181     76.554412        MRT
#
#      duration  country_pop_den  region       sub_region  area_km      lat  \
# 229         8       107.956335  Africa  Northern Africa   2010.0  30.0444
#
#          lng  population  time_diff  calculated_population  city_density  \
# 229  31.2358  20296000.0         -1             20699890.4  10298.452935
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 229       72.636646    3600.913793      Leptosols             16.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 229              0.0            0.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 229             5.0            2.0               1.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 229             7.0              0.0            0.0             6.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 229             7.0           0.0             0.0            14.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 229               0.0            2.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 229             0.0             2.0            0.0             2.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 229           14.0            1.0             11.0            23.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax   prcp  \
# 229            0.0              0.0       22.0  23.14  16.0  28.0  19.68
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 229            2020                  13                   193
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 229                    0       1             5                18
#
#      union_density  stations_per_km
# 229           23.8         1.034483

# %% [markdown]
# This is Cairo Line 3 (Phase 3). There's several incorrect components, that I was able to verify by several sources. I'll correct the data.

# %%
data.loc[229,'length'] = 17.7
data.loc[229,'duration'] = 2024-2017
data.loc[229,'cost_real_2023'] = 40700*0.220401*1.007292

# %%
df_adj.loc[[296]]
# Out:
#     country      city  start_year  end_year  rr?   length  tunnel_per  tunnel  \
# 296      CN  Hangzhou        2019      2022  0.0  59.1316    0.786382    46.5
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 296   12.6316       0.0      15.0      120.0       1435.0          1  43206.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 296      CNY  2021  0.238815  10318.24007  174.49621       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 296      0         1.007292     10393.48147    175.768649        MRT
#
#      duration  country_pop_den region    sub_region  area_km    lat       lng  \
# 296         3       149.723553   Asia  Eastern Asia   8259.9  30.25  120.1675
#
#      population  time_diff  calculated_population  city_density  \
# 296   9523000.0         -1              9750599.7   1180.474304
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 296       37.855836    8016.431435      Fluvisols             11.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 296              0.0           12.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 296            15.0           12.0               0.0                1.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 296             1.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 296            21.0           3.0             4.0             3.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 296               0.0            9.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 296             0.0             6.0            3.0             3.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 296            3.0            1.0              1.0             1.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg       tmin  \
# 296            1.0              0.0       17.0  16.741667  12.866667
#
#           tmax     prcp  land_cost_year  price_income_ratio  \
# 296  20.633333  114.675            2020                  29
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 296                   231                    0       0             1
#
#      price_rent_ratio  union_density  stations_per_km
# 296                52       16.31287         0.253671

# %% [markdown]
# This is the K1 Airport Line in Hangzhou. It's a high speed rail line. [remove]

# %%
cooks_drop.append(296)

# %%
df_adj.loc[[319]]
# Out:
#     country      city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 319      TR  Istanbul        2017      2021  0.0     8.8         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 319       0.0       8.8      12.0       80.0       1435.0          0  4388.42
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 319      TRY  2019  0.536477  2354.287419  267.532661       8.8       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 319      0         1.067626     2513.497297    285.624693       Tram
#
#      duration  country_pop_den region    sub_region  area_km      lat     lng  \
# 319         4       108.469893   Asia  Western Asia   1471.0  41.0136  28.955
#
#      population  time_diff  calculated_population  city_density  \
# 319  16079000.0          1           1.586482e+07  10785.061091
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 319       13.702734    11006.27952      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 319              1.0            6.0            3.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 319            27.0            0.0               3.0                1.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 319             4.0              3.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 319             5.0           2.0             0.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 319               0.0           15.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 319             0.0             9.0            1.0             6.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 319           11.0            0.0              0.0             3.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg       tmin  \
# 319            0.0              0.0       41.0  14.458333  10.383333
#
#           tmax       prcp  land_cost_year  price_income_ratio  \
# 319  18.491667  58.083333            2019                   9
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 319                   185                    0       1             4
#
#      price_rent_ratio  union_density  stations_per_km
# 319                20       5.337857         1.363636

# %% [markdown]
# This is the Istanbul T5. The data are correct. [keep]

# %%
df_adj.loc[[318]]
# Out:
#     country      city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 318      TR  Istanbul        1992      2014  0.0    23.5    0.914894    21.5
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 318       2.0       0.0      17.0      120.0       1435.0          0  3765.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 318      TRY  2003  1.357757  5111.953825  217.52995      23.5      21.5
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 318      0         1.483402     7583.081586    322.684323        MRT
#
#      duration  country_pop_den region    sub_region  area_km      lat     lng  \
# 318        22        86.882433   Asia  Western Asia   1471.0  41.0136  28.955
#
#      population  time_diff  calculated_population  city_density  \
# 318  16079000.0         17           1.280133e+07   8702.470524
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 318       38.833735    6373.131907      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 318              1.0            6.0            3.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 318            27.0            0.0               3.0                1.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 318             4.0              3.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 318             5.0           2.0             0.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 318               0.0           15.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 318             0.0             9.0            1.0             6.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 318           11.0            0.0              0.0             3.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg       tmin  \
# 318            0.0              0.0       41.0  14.458333  10.383333
#
#           tmax       prcp  land_cost_year  price_income_ratio  \
# 318  18.491667  58.083333            2003                   1
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 318                    62                    2       1             8
#
#      price_rent_ratio  union_density  stations_per_km
# 318                11       5.337857         0.723404

# %% [markdown]
# This is the M2 in Istanbul. I've previously reviewed this line and the project duration is concerning from the perspective of correctly identifying the PPP rate to use for this line. [remove]

# %%
cooks_drop.append(318)

# %%
df_adj.loc[[344]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 344      KR  Seoul        2020      2028  0.0    71.0         1.0    71.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 344       0.0       0.0      53.0       80.0       1435.0          1
#
#           cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 344  7230200.0      KRW  2024  0.001202  8690.762894  122.405111      71.0
#
#      c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 344      71.0      0         0.984983     8560.250172    120.566904
#
#     train_type  duration  country_pop_den region    sub_region  area_km  \
# 344        MRT         8       531.109006   Asia  Eastern Asia   2769.0
#
#        lat     lng  population  time_diff  calculated_population  \
# 344  37.56  126.99  23016000.0         -4           2.312668e+07
#
#      city_density  per_below_line  reporting_gdp wrb_class_name  \
# 344     8351.9956        1.228063    29461.78401       Luvisols
#
#      wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 344             18.0              0.0            1.0            1.0
#
#      prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 344            0.0            19.0            2.0               4.0
#
#      prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 344                0.0             0.0              4.0            0.0
#
#      prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 344             1.0             9.0           5.0             3.0
#
#      prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 344             1.0               0.0           29.0             0.0
#
#      prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 344           0.0             0.0             1.0            2.0
#
#      prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 344             4.0            3.0            0.0              1.0
#
#      prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation       tavg  \
# 344             6.0            0.0              0.0       44.0  12.183333
#
#       tmin   tmax    prcp  land_cost_year  price_income_ratio  \
# 344  7.825  16.55  114.25            2020                  17
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 344                   121                    0       1             1
#
#      price_rent_ratio  union_density  stations_per_km
# 344                67       9.769591         0.746479

# %% [markdown]
# This is the Seoul 2020s program. I'll remove this datapoint because of the vagness of the project title.

# %%
cooks_drop.append(344)

# %%
df_adj.loc[[345]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 345      KR  Seoul        1978      1982  0.0    54.2         0.8   44.16
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 345     10.04       0.0      51.0       80.0       1435.0          1
#
#          cost currency  year  ppp_rate  cost_real       cost_km  c_length  \
# 345  877100.0      KRW  1980    0.0017    1491.07  16182.656827      50.2
#
#      c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 345     40.16      0         3.312451     4903.340454     90.467536
#
#     train_type  duration  country_pop_den region    sub_region  area_km  \
# 345        MRT         4       395.228851   Asia  Eastern Asia   2769.0
#
#        lat     lng  population  time_diff  calculated_population  \
# 345  37.56  126.99  23016000.0         40           2.193796e+07
#
#      city_density  per_below_line  reporting_gdp wrb_class_name  \
# 345    7922.70081             5.0        2989.78       Luvisols
#
#      wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 345             18.0              0.0            1.0            1.0
#
#      prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 345            0.0            19.0            2.0               4.0
#
#      prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 345                0.0             0.0              4.0            0.0
#
#      prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 345             1.0             9.0           5.0             3.0
#
#      prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 345             1.0               0.0           29.0             0.0
#
#      prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 345           0.0             0.0             1.0            2.0
#
#      prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 345             4.0            3.0            0.0              1.0
#
#      prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation       tavg  \
# 345             6.0            0.0              0.0       44.0  12.183333
#
#       tmin   tmax    prcp  land_cost_year  price_income_ratio  \
# 345  7.825  16.55  114.25            1980                   0
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 345                    29                    1       1             6
#
#      price_rent_ratio  union_density  stations_per_km
# 345                 0       9.769591         1.015936

# %% [markdown]
# I've previously reviewed this line (line 2 Seoul). [remove]

# %%
cooks_drop.append(345)

# %%
df_adj.loc[[388]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 388      JP  Tokyo        1992      2000  0.0    27.8         1.0    27.8
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 388       0.0       0.0      27.0       70.0       1435.0          1
#
#          cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 388  988600.0      JPY  1996   0.00587  5803.529851  208.760067       0.0
#
#      c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 388       0.0      0         1.739617     10095.92018    363.162596
#
#     train_type  duration  country_pop_den region    sub_region  area_km  \
# 388        MRT         8       345.012346   Asia  Eastern Asia   6993.0
#
#          lat       lng  population  time_diff  calculated_population  \
# 388  35.6897  139.6922  37732000.0         24           2.967834e+07
#
#      city_density  per_below_line  reporting_gdp wrb_class_name  \
# 388   4244.006777        2.220306        25769.0      Cambisols
#
#      wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 388              6.0              0.0           15.0            6.0
#
#      prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 388            0.0            17.0           16.0               2.0
#
#      prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 388                0.0             0.0              2.0            0.0
#
#      prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 388             0.0             7.0           2.0             4.0
#
#      prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 388             0.0               0.0           11.0             0.0
#
#      prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 388           1.0             0.0             3.0            1.0
#
#      prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 388             1.0            2.0            0.0              3.0
#
#      prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation       tavg  \
# 388             4.0            0.0              0.0       40.0  15.791667
#
#           tmin       tmax   prcp  land_cost_year  price_income_ratio  \
# 388  12.016667  19.541667  117.5            1996                  13
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 388                    79                    1       1             4
#
#      price_rent_ratio  union_density  stations_per_km
# 388                28      21.337222         0.971223

# %% [markdown]
# This is the Tokyo Oedo Line. The construction cost varies significantly, however several sources list the construction cost as higher than the data's cost. I'll update the cost.

# %%
data.loc[338,'length'] = 27.8
data.loc[338,'cost_real_2023'] = 1335960*0.00587*1.739617

# %%
df_adj.loc[[389]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 389      JP  Tokyo        1997      2005  0.0    58.3    0.279588    16.3
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 389      42.0       0.0      20.0      130.0       1067.0          1
#
#          cost currency  year  ppp_rate   cost_real     cost_km  c_length  \
# 389  949400.0      JPY  2001  0.006683  6344.48023  108.824704       0.0
#
#      c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 389       0.0      0         1.541197      9778.09194    167.720273
#
#     train_type  duration  country_pop_den region    sub_region  area_km  \
# 389        MRT         8       348.831276   Asia  Eastern Asia   6993.0
#
#          lat       lng  population  time_diff  calculated_population  \
# 389  35.6897  139.6922  37732000.0         19           3.120057e+07
#
#      city_density  per_below_line  reporting_gdp wrb_class_name  \
# 389   4461.686312        2.220306        25769.0      Cambisols
#
#      wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 389              6.0              0.0           15.0            6.0
#
#      prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 389            0.0            17.0           16.0               2.0
#
#      prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 389                0.0             0.0              2.0            0.0
#
#      prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 389             0.0             7.0           2.0             4.0
#
#      prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 389             0.0               0.0           11.0             0.0
#
#      prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 389           1.0             0.0             3.0            1.0
#
#      prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 389             1.0            2.0            0.0              3.0
#
#      prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation       tavg  \
# 389             4.0            0.0              0.0       40.0  15.791667
#
#           tmin       tmax   prcp  land_cost_year  price_income_ratio  \
# 389  12.016667  19.541667  117.5            2001                  13
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 389                    77                    1       1             3
#
#      price_rent_ratio  union_density  stations_per_km
# 389                31      21.337222         0.343053

# %% [markdown]
# This is the Tokyo Nippori-Toneri Liner. The data are correct. [keep]

# %%
df_adj.loc[[391]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 391      JP  Tokyo        1996      1998  0.0    16.0         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 391      16.0       0.0      19.0       75.0          0.0          0  32700.0
#
#     currency  year  ppp_rate   cost_real    cost_km  c_length  c_tunnel  \
# 391      JPY  1997  0.005942  194.293904  12.143369       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 391      0         1.700598       330.41577     20.650986   Monorail
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 391         2       345.835391   Asia  Eastern Asia   6993.0  35.6897
#
#           lng  population  time_diff  calculated_population  city_density  \
# 391  139.6922  37732000.0         23           2.997673e+07   4286.676021
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 391        2.220306        25769.0      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 391              0.0           15.0            6.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 391            17.0           16.0               2.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 391             0.0              2.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 391             7.0           2.0             4.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 391               0.0           11.0             0.0           1.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 391             0.0             3.0            1.0             1.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 391            2.0            0.0              3.0             4.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg       tmin  \
# 391            0.0              0.0       40.0  15.791667  12.016667
#
#           tmax   prcp  land_cost_year  price_income_ratio  \
# 391  19.541667  117.5            1997                  13
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 391                    79                    1       1             4
#
#      price_rent_ratio  union_density  stations_per_km
# 391                29      21.337222           1.1875

# %% [markdown]
# This is the Line S4 Nanjing-Chuzhou Phase 1 (Chuzhou Section) in Nanjing. It's unclear what is included as part of this phase and so I'll remove the line [remove]

# %%
cooks_drop.append(391)

# %%
df_adj.loc[[408]]
# Out:
#     country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 408      IN  Mumbai        2018      2022  0.0    32.3         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 408     31.71      0.59      32.0       80.0       1435.0          1
#
#          cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 408  145490.0      INR  2020  0.045478  6616.638109  204.849477       0.0
#
#      c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 408       0.0      0         1.054615     6978.005066    216.037308
#
#     train_type  duration  country_pop_den region     sub_region  area_km  \
# 408        MRT         4       469.659567   Asia  Southern Asia    976.0
#
#          lat      lng  population  time_diff  calculated_population  \
# 408  19.0761  72.8775  24973000.0          0             24973000.0
#
#      city_density  per_below_line  reporting_gdp wrb_class_name  \
# 408  25587.090164       88.900103     1580.05946      Vertisols
#
#      wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 408             29.0              0.0            3.0            1.0
#
#      prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 408            0.0             7.0            7.0               0.0
#
#      prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 408                0.0             1.0              0.0            0.0
#
#      prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 408             0.0             9.0           1.0             0.0
#
#      prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 408             5.0               1.0            4.0             0.0
#
#      prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 408           0.0             0.0            22.0            6.0
#
#      prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 408             5.0            2.0            0.0              8.0
#
#      prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  \
# 408            12.0            1.0              0.0        6.0  27.5  22.7
#
#      tmax        prcp  land_cost_year  price_income_ratio  \
# 408  32.4  182.083333            2020                  11
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 408                   126                    0       1             3
#
#      price_rent_ratio  union_density  stations_per_km
# 408                33      12.133509         0.990712

# %% [markdown]
# This is Line 4 in Mumbai. The data are correct. [keep]

# %%
df_adj.loc[[451]]
# Out:
#     country     city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 451      CN  Tianjin        2017      2020  0.0    39.3    0.455471    17.9
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 451      21.4       0.0       5.0       80.0       1435.0          1  29975.0
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 451      CNY  2019  0.237623  7122.760994  181.240738       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 451      0         1.067626     7604.441312    193.497234        MRT
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 451         3       149.367573   Asia  Eastern Asia  11970.0  39.1467
#
#           lng  population  time_diff  calculated_population  city_density  \
# 451  117.2056  10368000.0          1           1.020272e+07    852.357226
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 451       37.855836    8016.431435       Luvisols             18.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 451              0.0            1.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 451             9.0            4.0               8.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 451             3.0              3.0            0.0             1.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 451            20.0           0.0             0.0             3.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 451               0.0           24.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 451             0.0             1.0            0.0             5.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 451            1.0            1.0             13.0             0.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg   tmin       tmax  \
# 451            0.0              0.0        2.0  12.983333  8.175  17.783333
#
#           prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 451  46.733333            2019                  29                   231
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 451                    0       0             2                49
#
#      union_density  stations_per_km
# 451       16.31287         0.127226

# %% [markdown]
# This is the Tianjin	M8 Phase 10. The data are correct [keep]

# %%
df_adj.loc[[456]]
# Out:
#     country     city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 456      CN  Wenzhou        2021      2024  0.0  70.299         1.0  70.299
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 456       0.0       0.0      20.0       80.0       1435.0          1  26200.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 456      CNY  2023  0.248641  6514.390712  92.666904       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 456      0              1.0     6514.390712     92.666904        MRT
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 456         3       149.723553   Asia  Eastern Asia   2900.0  27.9991
#
#           lng  population  time_diff  calculated_population  city_density  \
# 456  120.6561   3604446.0         -3           3.880458e+06   1338.089014
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 456       37.855836    8016.431435      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 456              0.0            7.0            2.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 456            25.0            5.0               2.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 456             0.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 456            19.0           0.0             0.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 456               0.0            9.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 456             0.0             5.0            3.0             0.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 456           11.0            1.0              2.0             2.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg       tmin  \
# 456            1.0              0.0        7.0  18.358333  14.808333
#
#           tmax    prcp  land_cost_year  price_income_ratio  \
# 456  21.908333  139.95            2020                  29
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 456                   231                    0       0             1
#
#      price_rent_ratio  union_density  stations_per_km
# 456                52       16.31287         0.284499

# %% [markdown]
# This is Wenzhou S2 (Phase 1). The data are correct [keep]

# %%
df_adj.loc[[496]]
# Out:
#     country     city  start_year  end_year  rr?     length  tunnel_per  \
# 496      US  Chicago        2021      2024  1.0  41.527738         0.0
#
#      tunnel  elevated   at_grade  stations  max_speed  track_gauge  overhead?  \
# 496     0.0       0.0  41.527738       3.0       90.0       1435.0          0
#
#       cost currency  year  ppp_rate  cost_real    cost_km  c_length  c_tunnel  \
# 496  456.0      USD  2023       1.0      456.0  10.980612       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023     train_type  \
# 496      1              1.0           456.0     10.980612  Regional Rail
#
#      duration  country_pop_den    region        sub_region  area_km      lat  \
# 496         3        36.240985  Americas  Northern America   589.82  41.8375
#
#          lng  population  time_diff  calculated_population  city_density  \
# 496 -87.6866   8595181.0         -3           8.698736e+06  14748.120258
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 496        2.248539     56863.3715       Luvisols             18.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 496              0.0            0.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 496            10.0            6.0               2.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 496             0.0             25.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 496             8.0           0.0             2.0             2.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 496               0.0           27.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 496             1.0             2.0            0.0            11.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 496            2.0            0.0              0.0             0.0
#
#      prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  tmax       prcp  \
# 496            0.0              0.0      184.0   7.4   2.3  12.5  83.333333
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 496            2020                   3                    26
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 496                    3       1            10                 9
#
#      union_density  stations_per_km
# 496         11.802         0.072241

# %% [markdown]
# This is the Chicago Northwest Indiana Double Track Project. Due to the nature of this project, I'll drop this project. [drop]

# %%
cooks_drop.append(496)

# %%
df_adj.loc[[501]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per     tunnel  \
# 501      US  Miami        1979      1985  0.0    33.8     0.97619  32.995238
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?   cost  \
# 501     0.805       0.0      21.0       95.0       1435.0          0  987.0
#
#     currency  year  ppp_rate  cost_real    cost_km  c_length  c_tunnel  anglo  \
# 501      USD  1982       1.0      987.0  29.192547       0.0       0.0      1
#
#      inflation_index  cost_real_2023  cost_km_2023 train_type  duration  \
# 501         2.828455     2791.685357     82.569812        MRT         6
#
#      country_pop_den    region        sub_region  area_km     lat      lng  \
# 501        25.293701  Americas  Northern America   3313.0  25.784 -80.2101
#
#      population  time_diff  calculated_population  city_density  \
# 501   5711945.0         38           3.243952e+06    979.158449
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 501         1.49923    31523.40568      Vertisols             29.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 501              4.0            4.0            1.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 501            12.0            6.0               2.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 501             0.0              4.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 501             5.0           0.0             1.0             3.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 501               1.0           12.0             1.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 501             0.0            15.0            7.0             6.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 501            1.0            0.0              3.0             6.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg       tmin  \
# 501            1.0              0.0        4.0  24.391667  20.541667
#
#           tmax        prcp  land_cost_year  price_income_ratio  \
# 501  28.241667  120.416667            1982                   1
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 501                     2                    9       0            16
#
#      price_rent_ratio  union_density  stations_per_km
# 501                 4         11.802         0.621302

# %% [markdown]
# This is the Miami Metrorail. The data are correct. [keep]

# %%
df_adj.loc[[516]]
# Out:
#     country  city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 516      IT  Rome        2013      2023  0.0     3.6         1.0     2.7
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?   cost  \
# 516       0.0       0.0       2.0       80.0       1435.0          1  861.0
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 516      EUR  2018  1.467957  1263.910977  351.086383       2.7       2.7
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 516      0         1.086971     1363.888863    378.858018        MRT
#
#      duration  country_pop_den  region       sub_region  area_km      lat  \
# 516        10       204.322226  Europe  Southern Europe    842.0  41.8931
#
#          lng  population  time_diff  calculated_population  city_density  \
# 516  12.4828   2872800.0          2           2.849387e+06   3384.070223
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 516         3.86843     30230.2263       Luvisols             18.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 516              0.0            1.0            1.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 516            17.0            1.0               2.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 516             8.0              1.0            0.0             1.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 516            14.0           1.0             3.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 516               0.0           18.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 516             0.0            12.0            0.0             2.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 516            4.0            0.0              2.0             8.0
#
#      prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  tmax   prcp  \
# 516            0.0              0.0       42.0  16.0  11.1  21.0  66.25
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 516            2018                   9                    63
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 516                    1       1             3                28
#
#      union_density  stations_per_km
# 516      38.052545         0.740741

# %% [markdown]
# This line (Rome Line C section T3) was previously adjusted and will be removed. [remove]

# %%
cooks_drop.append(516)

# %%
df_adj.loc[[552]]
# Out:
#     country    city  start_year  end_year  rr?    length  tunnel_per  tunnel  \
# 552      TW  Taipei        2016      2023  0.0  7.578861         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 552       1.0  6.578861       9.0       90.0       1435.0          1  16600.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 552      TWD  2020   0.19367  3214.929284  424.19689       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 552      0         1.054615      3390.51229    447.364357        MRT
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 552         7            664.0   Asia  Eastern Asia    376.0  25.0375
#
#           lng  population  time_diff  calculated_population  city_density  \
# 552  121.5625   9078000.0          0              9078000.0  24143.617021
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 552        0.247678       47008.92      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 552             14.0           14.0            7.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 552            17.0            4.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 552             0.0              1.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 552             8.0           2.0             0.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 552               0.0            4.0             0.0           1.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 552             4.0             3.0            3.0             1.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 552            3.0            2.0              1.0             3.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax   prcp  \
# 552            4.0              0.0        9.0  20.15  20.6  26.9  197.5
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 552            2020                  23                   142
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 552                    0       1             1                72
#
#      union_density  stations_per_km
# 552         39.355         1.187514

# %% [markdown]
# This is the Taipei Ankeng Light Rail. The data are correct [keep]

# %%
df_adj.loc[[585]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 585      JP  Osaka        1999      2019  1.0    20.3         1.0    20.3
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 585       0.0       0.0       0.0      120.0       1435.0          1
#
#          cost currency  year  ppp_rate    cost_real    cost_km  c_length  \
# 585  120000.0      JPY  2009  0.008679  1041.494214  51.305134       0.0
#
#      c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 585       0.0      0         1.272256     1325.047014     65.273252
#
#     train_type  duration  country_pop_den region    sub_region  area_km  \
# 585        MRT        20       351.294925   Asia  Eastern Asia   3020.0
#
#          lat       lng  population  time_diff  calculated_population  \
# 585  34.6939  135.5022  15126000.0         11           1.553114e+07
#
#      city_density  per_below_line  reporting_gdp wrb_class_name  \
# 585   5142.760599        2.220306     33557.6454      Cambisols
#
#      wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 585              6.0              0.0           13.0            3.0
#
#      prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 585            0.0            22.0           11.0               2.0
#
#      prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 585                1.0             1.0              0.0            0.0
#
#      prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 585             0.0            19.0           2.0             2.0
#
#      prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 585             1.0               0.0           12.0             0.0
#
#      prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 585           1.0             0.0             6.0            0.0
#
#      prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 585             0.0            2.0            0.0              2.0
#
#      prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation       tavg  \
# 585             1.0            0.0              0.0        3.0  16.533333
#
#           tmin       tmax    prcp  land_cost_year  price_income_ratio  \
# 585  12.558333  20.516667  109.75            2009                  12
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 585                    74                    1       1             3
#
#      price_rent_ratio  union_density  stations_per_km
# 585                36      21.337222              0.0

# %% [markdown]
# This is the Osaka Higashi Line. The data are correct [keep]

# %%
cooks_drop.append(599)

# %%
df_adj.loc[[631]]
# Out:
#     country      city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 631      CN  Shenzhen        2020      2025  0.0   50.34         1.0   50.34
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 631       0.0       0.0      17.0       80.0       1435.0          1  41005.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 631      CNY  2023  0.248641  10195.51875  202.53315       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 631      0              1.0     10195.51875     202.53315        MRT
#
#      duration  country_pop_den region    sub_region  area_km     lat      lng  \
# 631         5       149.723553   Asia  Eastern Asia   2000.0  22.535  114.054
#
#      population  time_diff  calculated_population  city_density  \
# 631  17619000.0         -3           1.863151e+07   9315.755225
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 631       37.855836    8016.431435      Fluvisols             11.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 631              2.0           17.0            2.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 631            16.0            2.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 631             0.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 631            18.0           1.0             0.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 631               5.0            6.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 631             2.0             4.0            6.0             2.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 631            2.0            3.0              1.0             1.0
#
#      prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  tmax        prcp  \
# 631            1.0              0.0       12.0  23.7  20.4  27.2  160.358333
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 631            2020                  29                   231
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 631                    0       1             1                58
#
#      union_density  stations_per_km
# 631       16.31287         0.337704

# %% [markdown]
# This is Line 14 in Shenzhen. There is some confusion regarding the project components. [remove]

# %%
cooks_drop.append(631)

# %%
df_adj.loc[[643]]
# Out:
#     country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 643      CN  Fuzhou        2021      2024  0.0    62.4     0.75641    47.2
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 643      15.2       0.0      15.0      350.0       1435.0          1  39890.0
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 643      CNY  2023  0.248641  9918.284179  158.946862       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023     train_type  \
# 643      0              1.0     9918.284179    158.946862  Regional Rail
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 643         3       149.723553   Asia  Eastern Asia   1768.2  27.9814
#
#           lng  population  time_diff  calculated_population  city_density  \
# 643  116.3577   4047200.0         -3           4.294921e+06   2428.979198
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 643       37.855836    8016.431435       Acrisols              0.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 643              0.0           22.0            2.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 643            17.0            3.0               1.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 643             0.0              1.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 643            13.0           5.0             3.0             2.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 643               0.0            5.0             0.0           1.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 643             0.0             2.0            5.0             0.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 643           11.0            0.0              0.0             5.0
#
#      prob_Nitisols  prob_Stagnosols  elevation    tavg       tmin       tmax  \
# 643            0.0              0.0       50.0  18.375  14.383333  22.383333
#
#            prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 643  137.533333            2020                  29                   231
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 643                    0       0             1                52
#
#      union_density  stations_per_km
# 643       16.31287         0.240385

# %% [markdown]
# This is the F1 Express Line in Fuzhou. Since it's a high speed rail project, I'll remove. [remove]

# %%
cooks_drop.append(643)

# %%
df_adj.loc[[653]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 653      TR  Bursa        1997      2014  0.0    39.0    0.160256    6.25
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?   cost  \
# 653       0.0     32.75      38.0       80.0       1435.0          0  850.0
#
#     currency  year  ppp_rate    cost_real   cost_km  c_length  c_tunnel  \
# 653      TRY  2006  1.187846  1009.669066  25.88895      39.0      6.25
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023  train_type  \
# 653      0         1.353898     1366.989416     35.051011  Light Rail
#
#      duration  country_pop_den region    sub_region  area_km      lat    lng  \
# 653        17        90.434797   Asia  Western Asia   1290.0  40.1833  29.05
#
#      population  time_diff  calculated_population  city_density  \
# 653   1999998.0         14           1.614765e+06   1251.755834
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 653       25.943063    8173.536251      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 653              1.0            7.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 653            30.0            0.0               4.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 653             6.0              2.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 653             5.0           1.0             0.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 653               0.0           20.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 653             0.0             1.0            0.0             7.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 653            7.0            0.0              0.0             7.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg   tmin       tmax  \
# 653            0.0              0.0      257.0  14.408333  8.725  20.108333
#
#           prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 653  56.916667            2006                   3                    68
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 653                    1       0             7                12
#
#      union_density  stations_per_km
# 653       5.337857         0.974359

# %% [markdown]
# This is the Bursa tram (Bursaray). The data are correct [keep]

# %%
df_adj.loc[[679]]
# Out:
#     country       city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 679      CN  Chongqing        2012      2016  0.0   50.93    0.856509  43.622
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 679     7.308       0.0      33.0       80.0       1435.0          1  34163.0
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 679      CNY  2014  0.266039  9088.684039  178.454428       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 679      0         1.152955     10478.84291     205.74991        MRT
#
#      duration  country_pop_den region    sub_region  area_km    lat       lng  \
# 679         4       145.560051   Asia  Eastern Asia   5472.8  29.55  106.5069
#
#      population  time_diff  calculated_population  city_density  \
# 679  12135000.0          6           1.030612e+07   1883.153101
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 679       69.489729    4711.635127      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 679              2.0            7.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 679            29.0            1.0               0.0                1.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 679             2.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 679             5.0          11.0             2.0             2.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 679               0.0            4.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 679             0.0             2.0            4.0             3.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 679           13.0            0.0              1.0             8.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg       tmin    tmax  \
# 679            1.0              0.0      218.0  18.291667  15.291667  21.275
#
#           prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 679  89.916667            2014                  26                   226
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 679                    0       0             3                31
#
#      union_density  stations_per_km
# 679       16.31287         0.647948

# %% [markdown]
# This is the Ring Line in Chongqing. The data appears to be accurate. [keep]

# %%
df_adj.loc[[848]]
# Out:
#     country       city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 848      CN  Guangzhou        2021      2026  1.0    41.1         1.0    41.1
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 848       0.0       0.0      10.0       80.0       1435.0          1  38130.0
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 848      CNY  2024  0.248641  9480.676253  230.673388       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 848      0         0.984983     9338.301082    227.209272        MRT
#
#      duration  country_pop_den region    sub_region  area_km    lat     lng  \
# 848         5       149.723553   Asia  Eastern Asia  3843.43  23.13  113.26
#
#      population  time_diff  calculated_population  city_density  \
# 848  26940000.0         -4           2.949377e+07    7673.81509
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 848       37.855836    8016.431435      Fluvisols             11.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 848             10.0           15.0            1.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 848            15.0            8.0               1.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 848             0.0              1.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 848            17.0           2.0             0.0             1.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 848               3.0            5.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 848             0.0             6.0            3.0             1.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 848            2.0            0.0              2.0             0.0
#
#      prob_Nitisols  prob_Stagnosols  elevation    tavg       tmin    tmax  \
# 848            2.0              0.0       21.0  22.425  18.658333  26.225
#
#            prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 848  140.166667            2020                  29                   231
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 848                    0       1             1                58
#
#      union_density  stations_per_km
# 848       16.31287         0.243309

# %% [markdown]
# This is line 4 in Xiamen. The data are correct. [keep]

# %%
df_adj.loc[[859]]
# Out:
#     country      city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 859      BR  Salvador        2020      2022  0.0    23.3         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 859      23.3       0.0      26.0       80.0       1000.0          0  3582.8
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 859      BRL  2021  0.395862  1418.295409  60.871048       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 859      0         1.007292     1428.637728     61.314924   Monorail
#
#      duration  country_pop_den    region                       sub_region  \
# 859         2        25.507625  Americas  Latin America and the Caribbean
#
#      area_km      lat      lng  population  time_diff  calculated_population  \
# 859    693.8 -12.9747 -38.4767   2886698.0         -1           2.914988e+06
#
#      city_density  per_below_line  reporting_gdp wrb_class_name  \
# 859   4201.481177       25.276877    8813.989806     Ferralsols
#
#      wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 859             10.0             21.0            8.0            0.0
#
#      prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 859            0.0             7.0            7.0               1.0
#
#      prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 859                0.0             0.0              0.0            0.0
#
#      prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 859             0.0             8.0          11.0             5.0
#
#      prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 859             7.0               1.0            4.0             0.0
#
#      prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 859           0.0             1.0             6.0            5.0
#
#      prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 859             2.0            0.0            0.0              0.0
#
#      prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  \
# 859             1.0            3.0              0.0       15.0  29.4  24.0
#
#      tmax        prcp  land_cost_year  price_income_ratio  \
# 859  29.4  159.166667            2020                  16
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 859                   188                    0       1             4
#
#      price_rent_ratio  union_density  stations_per_km
# 859                24      16.784444          1.11588

# %% [markdown]
# This is the Bahia SkyRail. I've previously evaluated this outlier and so now I will remove it. [remove]

# %%
cooks_drop.append(859)

# %%
df_adj.loc[[861]]
# Out:
#     country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 861      RU  Moscow        2016      2019  0.0    11.6    0.137931     1.6
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 861      0.14     9.836       4.0       40.0       1520.0          0
#
#           cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 861  41032.869      RUB  2018  0.040745  1671.883205  144.127862       0.0
#
#      c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 861       0.0      0         1.086971     1817.287941    156.662754
#
#     train_type  duration  country_pop_den  region      sub_region  area_km  \
# 861        MRT         3         8.822068  Europe  Eastern Europe   6154.0
#
#          lat      lng  population  time_diff  calculated_population  \
# 861  55.7558  37.6178  17332000.0          2           1.722504e+07
#
#      city_density  per_below_line  reporting_gdp wrb_class_name  \
# 861   2798.998899        4.079388    9666.814664   Albeluvisols
#
#      wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 861              1.0              0.0            0.0            0.0
#
#      prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 861            0.0            10.0           10.0               2.0
#
#      prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 861               17.0             0.0             10.0            0.0
#
#      prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 861             0.0             6.0           0.0             2.0
#
#      prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 861             4.0               0.0           13.0             0.0
#
#      prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 861           6.0             2.0             0.0            0.0
#
#      prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 861            11.0            2.0            0.0              0.0
#
#      prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation      tavg  \
# 861             3.0            0.0              1.0      149.0  5.091667
#
#       tmin      tmax       prcp  land_cost_year  price_income_ratio  \
# 861  1.225  8.941667  57.333333            2018                  11
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 861                   154                    0       1             6
#
#      price_rent_ratio  union_density  stations_per_km
# 861                15      33.739286         0.344828

# %% [markdown]
# Since this project is in Russia and isn't yet completed, it's reasonable to assume that the initial project schedule and budget have been altered by the war. I'll remove. [remove]

# %%
cooks_drop.append(861)

# %%
df_adj.loc[[871]]
# Out:
#     country     city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 871      CN  Qingdao        2008      2016  0.0    60.0         0.2    12.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 871      48.0       0.0      10.0      120.0       1435.0          0  20763.0
#
#     currency  year  ppp_rate   cost_real    cost_km  c_length  c_tunnel  \
# 871      CNY  2012  0.280823  5830.71794  97.178632       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 871      0          1.18882     6931.673974      115.5279        MRT
#
#      duration  country_pop_den region    sub_region  area_km      lat    lng  \
# 871         8       143.685196   Asia  Eastern Asia   5171.4  36.1167  120.4
#
#      population  time_diff  calculated_population  city_density  \
# 871   5818255.0          8           4.938645e+06    954.991931
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 871       69.489729    4711.635127       Luvisols             18.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 871              0.0            1.0            3.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 871            17.0            1.0               2.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 871             3.0              1.0            0.0             1.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 871            16.0           0.0             1.0             2.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 871               0.0           29.0             0.0           1.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 871             0.0             1.0            0.0             2.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 871            6.0            0.0              3.0             6.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg      tmin       tmax  \
# 871            0.0              0.0       47.0  12.75  9.683333  15.816667
#
#      prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 871  64.0            2012                  29                   247
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 871                    0       0             3                31
#
#      union_density  stations_per_km
# 871       16.31287         0.166667

# %% [markdown]
# This is the Qingdao-Pingdu Intercity Rail project. The data are correct [keep].

# %%
df_adj.loc[[885]]
# Out:
#     country           city  start_year  end_year  rr?  length  tunnel_per  \
# 885      US  San Francisco        2012      2017  1.0    72.0         0.0
#
#      tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 885     0.0       0.0      72.0      12.0      127.0       1435.0          0
#
#       cost currency  year  ppp_rate  cost_real   cost_km  c_length  c_tunnel  \
# 885  400.0      USD  2015       1.0      400.0  5.555556       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023     train_type  \
# 885      1         1.151588      460.635202      6.397711  Regional Rail
#
#      duration  country_pop_den    region        sub_region  area_km      lat  \
# 885         5        35.063329  Americas  Northern America   1365.0  37.7558
#
#           lng  population  time_diff  calculated_population  city_density  \
# 885 -122.4449   3290197.0          5           3.244519e+06   2376.936744
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 885        2.248539     56863.3715    Kastanozems             15.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 885              0.0            4.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 885            18.0            2.0              22.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 885             2.0              2.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 885             1.0           4.0             0.0             1.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 885               0.0           14.0             0.0           1.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 885             1.0             7.0            3.0             2.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 885            4.0            0.0              0.0             7.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg   tmin       tmax  \
# 885            1.0              0.0      209.0  14.85  10.95  18.758333
#
#           prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 885  37.991667            2015                   2                    19
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 885                    5       0            12                 7
#
#      union_density  stations_per_km
# 885         11.802         0.166667

# %% [markdown]
# This is the San Francisco SMART Train (Phase 1). The data are correct [keep]

# %%
df_adj.loc[[901]]
# Out:
#     country         city  start_year  end_year  rr?  length  tunnel_per  \
# 901      US  Los Angeles        1987      1995  0.0    31.4         0.0
#
#      tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 901     0.0    31.395       0.0      14.0      105.0       1435.0          1
#
#       cost currency  year  ppp_rate  cost_real    cost_km  c_length  c_tunnel  \
# 901  718.0      USD  1991       1.0      718.0  22.869884       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023  train_type  \
# 901      1         2.004008     1438.877978     45.831437  Light Rail
#
#      duration  country_pop_den    region        sub_region  area_km      lat  \
# 901         8        27.621149  Americas  Northern America   1300.0  34.1141
#
#           lng  population  time_diff  calculated_population  city_density  \
# 901 -118.4068  12121244.0         29           9.082959e+06   6986.891541
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 901        1.498851    35864.82439    Kastanozems             15.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 901              0.0            0.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 901            11.0            0.0              26.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 901             2.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 901             2.0           0.0             0.0             2.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 901               0.0           20.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 901             0.0             6.0            0.0             2.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 901           18.0            0.0              0.0             8.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax  prcp  \
# 901            1.0              0.0      354.0  19.15  13.7  24.6  30.0
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 901            1991                   1                     1
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 901                    8       1            12                 6
#
#      union_density  stations_per_km
# 901         11.802          0.44586

# %% [markdown]
# This is the Los Angeles Green Line (Initial and Extensions). The data are correct [keep]

# %%
df_adj.loc[[909]]
# Out:
#     country         city  start_year  end_year  rr?     length  tunnel_per  \
# 909      US  Los Angeles        2025      2035  0.0  29.349008    0.170364
#
#      tunnel  elevated   at_grade  stations  max_speed  track_gauge  overhead?  \
# 909     5.0      10.0  14.349008       8.0       90.0       1435.0          1
#
#        cost currency  year  ppp_rate  cost_real     cost_km  c_length  \
# 909  6500.0  Unknown  2030       1.0     6500.0  221.472566       0.0
#
#      c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 909       0.0      1         0.903567     5873.186658    200.115341
#
#      train_type  duration  country_pop_den    region        sub_region  \
# 909  Light Rail        10        36.240985  Americas  Northern America
#
#      area_km      lat       lng  population  time_diff  calculated_population  \
# 909   1300.0  34.1141 -118.4068  12121244.0        -10           1.338939e+07
#
#      city_density  per_below_line  reporting_gdp wrb_class_name  \
# 909  10299.534085         2.15759    65536.73429    Kastanozems
#
#      wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 909             15.0              0.0            0.0            0.0
#
#      prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 909            0.0            11.0            0.0              26.0
#
#      prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 909                0.0             2.0              0.0            0.0
#
#      prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 909             0.0             2.0           0.0             0.0
#
#      prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 909             2.0               0.0           20.0             0.0
#
#      prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 909           0.0             0.0             6.0            0.0
#
#      prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 909             2.0           18.0            0.0              0.0
#
#      prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  \
# 909             8.0            1.0              0.0      354.0  19.15  13.7
#
#      tmax  prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 909  24.6  30.0            2020                   3                    26
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 909                    3       1            10                 9
#
#      union_density  stations_per_km
# 909         11.802         0.272582

# %% [markdown]
# This is the Los Angeles West Santa Ana Transit Corridor project. The data are correct [keep]

# %%
df_adj.loc[[922]]
# Out:
#     country     city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 922      US  Seattle        2030      2037  0.0    26.2         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 922      13.1      13.1       6.0       90.0       1435.0          1  6500.0
#
#     currency  year  ppp_rate  cost_real     cost_km  c_length  c_tunnel  \
# 922      USD  2034       1.0     6500.0  248.091603       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023  train_type  \
# 922      1         0.845781     5497.577502    209.831202  Light Rail
#
#      duration  country_pop_den    region        sub_region  area_km      lat  \
# 922         7        36.240985  Americas  Northern America   2470.0  47.6211
#
#           lng  population  time_diff  calculated_population  city_density  \
# 922 -122.3244   3438221.0        -14           4.063132e+06   1644.992834
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 922         2.15759    65536.73429      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 922              0.0            5.0            1.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 922            40.0            5.0               3.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 922             1.0              2.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 922             3.0           4.0             0.0             1.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 922               0.0           18.0             0.0           4.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 922             3.0             1.0            0.0             0.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 922            1.0            0.0              0.0             5.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax       prcp  \
# 922            0.0              0.0       87.0  12.05   7.9  16.3  83.333333
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 922            2020                   3                    26
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 922                    3       0            11                 8
#
#      union_density  stations_per_km
# 922         11.802         0.229008

# %% [markdown]
# This is the Seattle 3 Line (Everett Segment). The data are correct [keep]

# %%
df_adj.loc[[924]]
# Out:
#     country     city  start_year  end_year  rr?     length  tunnel_per  \
# 924      US  Seattle        2040      2045  0.0  12.944996         0.0
#
#      tunnel  elevated   at_grade  stations  max_speed  track_gauge  overhead?  \
# 924     0.0       0.0  12.944996       2.0       90.0       1435.0          1
#
#       cost currency  year  ppp_rate  cost_real    cost_km  c_length  c_tunnel  \
# 924  300.0      USD  2043       1.0      300.0  23.174977       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023     train_type  \
# 924      1         0.752911       225.87345     17.448707  Regional Rail
#
#      duration  country_pop_den    region        sub_region  area_km      lat  \
# 924         5             41.0  Americas  Northern America   2470.0  47.6211
#
#           lng  population  time_diff  calculated_population  city_density  \
# 924 -122.3244   3438221.0        -23           4.523614e+06   1831.422827
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 924        2.310825    72059.71398      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 924              0.0            5.0            1.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 924            40.0            5.0               3.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 924             1.0              2.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 924             3.0           4.0             0.0             1.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 924               0.0           18.0             0.0           4.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 924             3.0             1.0            0.0             0.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 924            1.0            0.0              0.0             5.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax       prcp  \
# 924            0.0              0.0       87.0  12.05   7.9  16.3  83.333333
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 924            2020                   3                    26
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 924                    3       0            11                 8
#
#      union_density  stations_per_km
# 924         11.802           0.1545

# %% [markdown]
# This is the Seattle- Lakewood to DuPont Sounder project. The data are correct [keep]

# %%
df_adj.loc[[965]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 965      IN  Delhi        2015      2019  0.0    29.7         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 965      29.7       0.0      21.0       80.0       1435.0          1  42610.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 965      INR  2017  0.048431  2063.658813  69.483462       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023  train_type  \
# 965      0          1.11352     2297.924618     77.371199  Light Rail
#
#      duration  country_pop_den region     sub_region  area_km    lat    lng  \
# 965         4       455.468934   Asia  Southern Asia    700.0  28.61  77.23
#
#      population  time_diff  calculated_population  city_density  \
# 965  32226000.0          3           2.972450e+07  42463.569511
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 965       88.900103     1580.05946       Luvisols             18.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 965              2.0            3.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 965            15.0            3.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 965             2.0              0.0            2.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 965            14.0           0.0             0.0             3.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 965               1.0           21.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 965             0.0             9.0            1.0             5.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 965            5.0            3.0              1.0             6.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax       prcp  \
# 965            1.0              0.0      214.0  25.35  19.0  31.7  69.166667
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 965            2017                  10                   123
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 965                    0       1             3                32
#
#      union_density  stations_per_km
# 965      12.133509         0.707071

# %% [markdown]
# This is the Noida Metro in Delhi. The final construction cost was 55Bn INR. [adjust]

# %%
data_unseen.loc[965,'length'] = 29.7
data_unseen.loc[965,'cost_real_2023'] = 55030*0.048431*1.11352

# %%
df_adj.loc[[966]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 966      IN  Delhi        2019      2025  0.0    42.3    0.347518    14.7
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 966      27.6       0.0      43.0       80.0       1435.0          1
#
#          cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 966  215363.5      INR  2022  0.041564  8951.292642  211.614483       0.0
#
#      c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 966       0.0      0         1.015482     9089.880299    214.890787
#
#     train_type  duration  country_pop_den region     sub_region  area_km  \
# 966        MRT         6       469.659567   Asia  Southern Asia    700.0
#
#        lat    lng  population  time_diff  calculated_population  city_density  \
# 966  28.61  77.23  32226000.0         -2           3.400956e+07  48585.081879
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 966       88.900103     1580.05946       Luvisols             18.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 966              2.0            3.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 966            15.0            3.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 966             2.0              0.0            2.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 966            14.0           0.0             0.0             3.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 966               1.0           21.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 966             0.0             9.0            1.0             5.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 966            5.0            3.0              1.0             6.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax       prcp  \
# 966            1.0              0.0      214.0  25.35  19.0  31.7  69.166667
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 966            2020                  11                   126
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 966                    0       1             3                33
#
#      union_density  stations_per_km
# 966      12.133509         1.016548

# %% [markdown]
# This is for the Phase 4 second half in Delhi. The wording of this item makes it difficult to verify. [remove]

# %%
cooks_drop.append(966)

# %%
df_adj.loc[[984]]
# Out:
#     country       city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 984      IN  Hyderabad        2020      2025  0.0    31.0    0.080645     2.5
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 984      28.5       0.0      10.0      135.0       1435.0          1  46500.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 984      INR  2023  0.041564  1932.709618  62.345472       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 984      0              1.0     1932.709618     62.345472        MRT
#
#      duration  country_pop_den region     sub_region  area_km     lat  \
# 984         5       469.659567   Asia  Southern Asia   1404.0  17.385
#
#          lng  population  time_diff  calculated_population  city_density  \
# 984  78.4867  10494000.0         -3           1.131082e+07    8056.13665
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 984       88.900103     1580.05946       Luvisols             18.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 984              1.0           12.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 984            12.0            2.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 984             2.0              1.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 984            10.0           0.0             0.0             5.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 984               1.0           17.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 984             0.0            16.0            4.0             1.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 984            4.0            0.0              4.0             3.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax       prcp  \
# 984            1.0              0.0      505.0  26.95  20.9  33.2  69.166667
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 984            2020                  11                   126
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 984                    0       1             3                33
#
#      union_density  stations_per_km
# 984      12.133509         0.322581

# %% [markdown]
# This is the Airport express in Hyderabad. The overall cost appears to be lower than reported. I'll update. [adjust]

# %%
data_unseen.loc[984,'length'] = 31
data_unseen.loc[984,'cost_real_2023'] = 62500*0.045478*1.05

# %%
df_adj.loc[[988]]
# Out:
#     country     city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 988      BH  Bahrain        2018      2024  1.0    28.6         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?   cost  \
# 988      28.6       0.0      20.0       65.0       1435.0          1  453.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 988       BD  2021  5.436123  2462.563775  86.103629       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023  train_type  \
# 988      0         1.007292      2480.52098     86.731503  Light Rail
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 988         6      1882.126115   Asia  Western Asia    760.0  26.0667
#
#          lng  population  time_diff  calculated_population  city_density  \
# 988  50.5577   1487202.0         -1            1499843.217   1973.477917
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 988       43.486984       26562.97       Regosols             24.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 988              0.0            0.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 988             1.0            1.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 988             1.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 988             7.0           0.0             0.0            11.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 988               0.0            0.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 988             0.0             1.0            0.0             0.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 988           31.0            2.0             27.0            15.0
#
#      prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  tmax      prcp  \
# 988            0.0              0.0       55.0  29.1  23.5  34.8  9.166667
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 988            2020                   8                    77
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 988                    1       0             7                12
#
#      union_density  stations_per_km
# 988            0.0         0.699301

# %% [markdown]
# This is the Bahrain Red & Blue (Phase 1). The data are correct [keep]

# %%
df_adj.loc[[989]]
# Out:
#     country     city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 989      BH  Bahrain        2020      2025  1.0    72.7         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 989      72.7       0.0      18.0       65.0       1435.0          1  1500.0
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 989       BD  2023  5.400636  8100.953413  111.429896       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023  train_type  \
# 989      0              1.0     8100.953413    111.429896  Light Rail
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 989         5      1882.126115   Asia  Western Asia    760.0  26.0667
#
#          lng  population  time_diff  calculated_population  city_density  \
# 989  50.5577   1487202.0         -3           1.525449e+06   2007.169625
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 989       43.486984       26562.97       Regosols             24.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 989              0.0            0.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 989             1.0            1.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 989             1.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 989             7.0           0.0             0.0            11.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 989               0.0            0.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 989             0.0             1.0            0.0             0.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 989           31.0            2.0             27.0            15.0
#
#      prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  tmax      prcp  \
# 989            0.0              0.0       55.0  29.1  23.5  34.8  9.166667
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 989            2020                   8                    77
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 989                    1       0             7                12
#
#      union_density  stations_per_km
# 989            0.0         0.247593

# %% [markdown]
# This is the 2nd phase of the Bahrain metro system. There is an abundance of information regarding phase 1, however very little regarding phase 2. [remove]

# %%
cooks_drop.append(989)

# %%
df_adj.loc[[994]]
# Out:
#     country    city  start_year  end_year  rr?     length  tunnel_per  tunnel  \
# 994      US  Boston        2017      2023  1.0  38.889938         0.0     0.0
#
#      elevated   at_grade  stations  max_speed  track_gauge  overhead?   cost  \
# 994       0.0  38.889938      18.0       40.0       1435.0          0  403.5
#
#     currency  year  ppp_rate  cost_real    cost_km  c_length  c_tunnel  anglo  \
# 994      USD  2020       1.0      403.5  10.375434       0.0       0.0      1
#
#      inflation_index  cost_real_2023  cost_km_2023     train_type  duration  \
# 994         1.054615      425.537108     10.942088  Regional Rail         6
#
#      country_pop_den    region        sub_region  area_km      lat      lng  \
# 994        36.240985  Americas  Northern America    232.1  42.3188 -71.0852
#
#      population  time_diff  calculated_population  city_density  \
# 994   4208580.0          0              4208580.0  18132.615252
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 994        2.248539     56863.3715      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 994              0.0            7.0            1.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 994            25.0            3.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 994             0.0              2.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 994             3.0          10.0             0.0             3.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 994               0.0           21.0             0.0           2.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 994             0.0             2.0            1.0             2.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 994           11.0            1.0              0.0             2.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg      tmin  tmax  \
# 994            1.0              0.0       26.0  10.641667  6.408333  14.9
#
#           prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 994  87.666667            2020                   3                    26
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 994                    3       1            10                 9
#
#      union_density  stations_per_km
# 994         11.802         0.462845

# %% [markdown]
# This is the Boston Middleborough/New Bedford Line. The data are correct [keep]

# %%
df_adj.loc[[1002]]
# Out:
#      country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1002      IR  Tehran        2015      2017  0.0    27.0         1.0    27.0
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1002       0.0       0.0      25.0       80.0       1435.0          0
#
#             cost currency  year  ppp_rate    cost_real    cost_km  c_length  \
# 1002  90000000.0      IRR  2016  0.000085  7629.180755  282.56225       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1002       0.0      0         1.137242     8676.221391    321.341533
#
#       train_type  duration  country_pop_den region     sub_region  area_km  \
# 1002  Light Rail         2        51.147027   Asia  Southern Asia   1704.0
#
#           lat      lng  population  time_diff  calculated_population  \
# 1002  35.6892  51.3889  14148000.0          4           1.345685e+07
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1002   7897.211486       21.850269        4091.21       Regosols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1002             24.0              0.0            0.0            0.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1002            0.0            15.0            0.0               6.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1002                0.0            22.0              1.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1002             3.0             8.0           0.0             0.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1002             1.0               0.0            4.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1002           0.0             0.0             2.0            0.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1002             0.0           26.0            4.0              3.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  \
# 1002             6.0            0.0              0.0     1173.0  18.15  13.2
#
#       tmax       prcp  land_cost_year  price_income_ratio  \
# 1002  23.2  19.166667            2016                  14
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1002                   356                    0       1             5
#
#       price_rent_ratio  union_density  stations_per_km
# 1002                17            0.0         0.925926

# %% [markdown]
# This is Line 7 in Tehran. It's unclear what the final cost was for this segment. There was a request for additional funds, but I can't verify what the initial funding was. [remove]

# %%
cooks_drop.append(1002)

# %%
df_adj.loc[[1023]]
# Out:
#      country      city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1023      CN  Shenyang        2005      2010  0.0   55.07         1.0   55.07
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1023       0.0       0.0      43.0       80.0       1435.0          1
#
#          cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1023  24685.0      CNY  2008   0.31458  7765.418611  141.009962       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1023       0.0      0         1.267729     9844.449153    178.762469
#
#      train_type  duration  country_pop_den region    sub_region  area_km  \
# 1023        MRT         5       140.551423   Asia  Eastern Asia   3658.2
#
#           lat       lng  population  time_diff  calculated_population  \
# 1023  41.8025  123.4281   7964000.0         12           6.257439e+06
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1023   1710.523977       69.489729    4711.635127      Phaeozems
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1023             20.0              0.0            0.0            0.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1023            0.0             7.0            6.0               7.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1023                0.0             1.0              6.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1023             1.0             4.0           0.0             1.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1023             3.0               0.0           17.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1023           2.0             0.0             1.0            0.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1023            25.0            6.0            5.0              6.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  \
# 1023             1.0            0.0              0.0       42.0  8.65   3.3
#
#       tmax       prcp  land_cost_year  price_income_ratio  \
# 1023  14.1  58.333333            2008                  22
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1023                   184                    0       0             4
#
#       price_rent_ratio  union_density  stations_per_km
# 1023                13       16.31287         0.780824

# %% [markdown]
# This is the Shenyang Line 1 and 2 (Phase 1). The data are correct [keep]

# %%
df_adj.loc[[1026]]
# Out:
#      country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1026      IN  Kochi        2013      2017  0.0    13.0         0.0     0.0
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1026      13.0       0.0      11.0       80.0       1435.0          0
#
#          cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1026  51810.0      INR  2015  0.051989  2693.527004  207.194385       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1026       0.0      0         1.151588     3101.833387    238.602568
#
#      train_type  duration  country_pop_den region     sub_region  area_km  \
# 1026        MRT         4       444.931708   Asia  Southern Asia    94.88
#
#        lat    lng  population  time_diff  calculated_population  city_density  \
# 1026  9.97  76.28    677381.0          5          579516.569978    6107.88965
#
#       per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 1026       88.900103     1580.05946      Fluvisols             11.0
#
#       prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 1026              0.0           11.0            0.0            0.0
#
#       prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 1026             7.0           13.0               0.0                0.0
#
#       prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 1026             0.0              0.0            0.0             0.0
#
#       prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 1026            30.0           0.0             0.0             0.0
#
#       prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 1026               0.0            6.0             0.0           0.0
#
#       prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 1026             0.0             0.0            0.0             0.0
#
#       prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 1026            0.0            0.0              0.0             0.0
#
#       prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax  \
# 1026            0.0              0.0        8.0  27.75  22.2  33.4
#
#             prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 1026  100.416667            2015                  10                   124
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 1026                    0       1             3                30
#
#       union_density  stations_per_km
# 1026      12.133509         0.846154

# %% [markdown]
# This is the Kochi Metro. The data are correct [keep]

# %%
df_adj.loc[[1027]]
# Out:
#      country     city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1027      ID  Jakarta        2013      2019  0.0    15.7    0.375796     5.9
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1027       9.8       0.0      13.0       80.0       1435.0          1
#
#             cost currency  year  ppp_rate   cost_real    cost_km  c_length  \
# 1027  13776070.0      IDR  2016  0.000221  3049.08209  194.20905       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1027       0.0      0         1.137242      3467.54286    220.862603
#
#      train_type  duration  country_pop_den region          sub_region  \
# 1027        MRT         6       139.466062   Asia  South-eastern Asia
#
#       area_km    lat       lng  population  time_diff  calculated_population  \
# 1027   3546.0 -6.175  106.8275  33756000.0          4           3.171679e+07
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1027   8944.384022       72.949046    3331.695115     Ferralsols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1027             10.0             24.0           11.0            1.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1027            0.0             6.0            4.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1027                0.0             0.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1027             0.0            13.0           3.0             0.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1027             2.0               4.0            0.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1027           1.0            18.0             0.0            3.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1027             3.0            0.0            0.0              0.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation  tavg   tmin  \
# 1027             0.0            3.0              0.0        4.0  27.3  23.35
#
#       tmax   prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 1027  31.3  159.5            2016                  19                   225
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 1027                    0       1             4                22
#
#       union_density  stations_per_km
# 1027          12.14         0.828025

# %% [markdown]
# This is the MRT first phase in Jakarta. The [official](https://jakartamrt.co.id/id/proyek/fase-1), initial estimate was given as 12.5 trillion IDR. It appears the cost had risen to 16 trillion, per local news sources as of 2023.

# %%
data.loc[1027,'length'] = 15.7
data.loc[1027,'cost_real_2023'] = 16006070*0.000221*1.13

# %%
df_adj.loc[[1038]]
# Out:
#      country       city  start_year  end_year  rr?  length  tunnel_per  \
# 1038      BR  Sao Paulo        2010      2019  0.0    12.0         1.0
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1038    12.0       0.0       0.0      11.0       80.0       1435.0          1
#
#         cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1038  6900.0      BRL  2015  0.502812  3469.404379  289.117032       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1038       0.0      0         1.151588     3995.324465    332.943705
#
#      train_type  duration  country_pop_den    region  \
# 1038        MRT         9        24.549506  Americas
#
#                            sub_region  area_km    lat      lng  population  \
# 1038  Latin America and the Caribbean   7947.0 -23.55 -46.6333  23086000.0
#
#       time_diff  calculated_population  city_density  per_below_line  \
# 1038          5           2.212938e+07   2784.620176       25.276877
#
#       reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 1038    8813.989806     Ferralsols             10.0             20.0
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 1038            8.0            1.0            0.0            13.0
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 1038            4.0               0.0                0.0             0.0
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 1038              0.0            0.0             0.0             3.0
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 1038           1.0             1.0             7.0               1.0
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 1038            3.0             0.0           0.0             0.0
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 1038             4.0           10.0             3.0            1.0
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 1038            1.0              0.0            14.0            3.0
#
#       prob_Stagnosols  elevation  tavg  tmin   tmax    prcp  land_cost_year  \
# 1038              0.0      761.0  8.55  16.8  21.45  121.25            2015
#
#       price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 1038                  16                   200                    0       1
#
#       rental_yield  price_rent_ratio  union_density  stations_per_km
# 1038             4                23      16.784444         0.916667

# %% [markdown]
# This is the line 5 extension in Sao Paulo. The construction cost was 6480000 riyals, which is in line with the provided data. [drop]

# %%
cooks_drop.append(1038)

# %%
df_adj.loc[[1043]]
# Out:
#      country       city  start_year  end_year  rr?  length  tunnel_per  \
# 1043      BR  Sao Paulo        2009      2014  0.0    15.3         0.0
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1043     0.0      15.3       0.0      11.0       80.0          0.0          0
#
#         cost currency  year  ppp_rate    cost_real    cost_km  c_length  \
# 1043  5200.0      BRL  2012   0.62278  3238.454908  211.66372       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1043       0.0      0          1.18882     3849.939893    251.630058
#
#      train_type  duration  country_pop_den    region  \
# 1043   Monorail         5        23.926102  Americas
#
#                            sub_region  area_km    lat      lng  population  \
# 1043  Latin America and the Caribbean   7947.0 -23.55 -46.6333  23086000.0
#
#       time_diff  calculated_population  city_density  per_below_line  \
# 1043          8           2.157454e+07   2714.802609       41.379542
#
#       reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 1043     7560.70204     Ferralsols             10.0             20.0
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 1043            8.0            1.0            0.0            13.0
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 1043            4.0               0.0                0.0             0.0
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 1043              0.0            0.0             0.0             3.0
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 1043           1.0             1.0             7.0               1.0
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 1043            3.0             0.0           0.0             0.0
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 1043             4.0           10.0             3.0            1.0
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 1043            1.0              0.0            14.0            3.0
#
#       prob_Stagnosols  elevation  tavg  tmin   tmax    prcp  land_cost_year  \
# 1043              0.0      761.0  8.55  16.8  21.45  121.25            2012
#
#       price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 1043                  13                   161                    0       1
#
#       rental_yield  price_rent_ratio  union_density  stations_per_km
# 1043             5                18      16.784444         0.718954

# %% [markdown]
# This is the Sao Paulo 15 Prata. The data are correct [keep]

# %%
df_adj.loc[[1056]]
# Out:
#      country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1056      CN  Xiamen        2021      2028  1.0    51.2         0.0     0.0
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1056       0.0      51.2       4.0      200.0       1435.0          1
#
#          cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1056  30320.0      CNY  2025  0.248641  7538.791083  147.242013       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1056       0.0      0          0.97041     7315.714924    142.885057
#
#          train_type  duration  country_pop_den region    sub_region  area_km  \
# 1056  Regional Rail         7       149.723553   Asia  Eastern Asia  1700.61
#
#           lat       lng  population  time_diff  calculated_population  \
# 1056  24.4797  118.0819   3707090.0         -5           4.068907e+06
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1056   2392.616442       37.855836    8016.431435       Acrisols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1056              0.0              6.0           21.0            0.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1056            0.0            15.0            5.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1056                0.0             0.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1056             0.0             7.0           0.0             0.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1056             5.0               1.0            8.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1056           1.0             0.0             5.0            4.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1056             2.0            8.0            0.0              1.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation    tavg  \
# 1056             4.0            3.0              0.0       12.0  21.275
#
#            tmin  tmax       prcp  land_cost_year  price_income_ratio  \
# 1056  17.833333  24.7  99.291667            2020                  29
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1056                   231                    0       0             1
#
#       price_rent_ratio  union_density  stations_per_km
# 1056                52       16.31287         0.078125

# %% [markdown]
# This is the Quanzhou-Xiamen-Zhangzhou Regional Rail R1 (Xiamen Section). The data appear correct. [keep]

# %%
df_adj.loc[[1057]]
# Out:
#      country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1057      CN  Xiamen        2017      2022  0.0    69.6    0.448276    31.2
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1057      38.4       0.0      18.0       80.0       1435.0          1
#
#          cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1057  36256.0      CNY  2020  0.239311  8676.467738  124.661893       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1057       0.0      0         1.054615     9150.332061    131.470288
#
#      train_type  duration  country_pop_den region    sub_region  area_km  \
# 1057        MRT         5       149.723553   Asia  Eastern Asia  1700.61
#
#           lat       lng  population  time_diff  calculated_population  \
# 1057  24.4797  118.0819   3707090.0          0              3707090.0
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1057   2179.858992       37.855836    8016.431435       Acrisols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1057              0.0              6.0           21.0            0.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1057            0.0            15.0            5.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1057                0.0             0.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1057             0.0             7.0           0.0             0.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1057             5.0               1.0            8.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1057           1.0             0.0             5.0            4.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1057             2.0            8.0            0.0              1.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation    tavg  \
# 1057             4.0            3.0              0.0       12.0  21.275
#
#            tmin  tmax       prcp  land_cost_year  price_income_ratio  \
# 1057  17.833333  24.7  99.291667            2020                  29
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1057                   231                    0       0             1
#
#       price_rent_ratio  union_density  stations_per_km
# 1057                52       16.31287         0.258621

# %% [markdown]
# This is line 4 in Xiamen. The data are correct. [keep]

# %%
df_adj.loc[[1071]]
# Out:
#      country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1071      PH  Manila        2017      2024  0.0     6.7         0.0     0.0
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1071       6.7       0.0       5.0       90.0       1435.0          1
#
#          cost currency  year  ppp_rate   cost_real     cost_km  c_length  \
# 1071  64000.0      PHP  2021   0.05241  3354.23307  500.631801       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1071       0.0      0         1.007292     3378.692395    504.282447
#
#       train_type  duration  country_pop_den region          sub_region  \
# 1071  Light Rail         7       376.265141   Asia  South-eastern Asia
#
#       area_km      lat       lng  population  time_diff  \
# 1071   1911.0  14.5958  120.9772  24922000.0         -1
#
#       calculated_population  city_density  per_below_line  reporting_gdp  \
# 1071             25373088.2   13277.38786       68.060575    3001.043182
#
#      wrb_class_name  wrb_class_value  prob_Ferralsols  prob_Acrisols  \
# 1071      Cambisols              6.0              7.0            7.0
#
#       prob_Andosols  prob_Cryosols  prob_Cambisols  prob_Gleysols  \
# 1071            8.0            0.0            19.0           14.0
#
#       prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  prob_Chernozems  \
# 1071               0.0                0.0             0.0              0.0
#
#       prob_Durisols  prob_Gypsisols  prob_Fluvisols  prob_Alisols  \
# 1071            0.0             0.0             9.0           2.0
#
#       prob_Planosols  prob_Arenosols  prob_Plinthosols  prob_Luvisols  \
# 1071             0.0             3.0               6.0            6.0
#
#       prob_Umbrisols  prob_Podzols  prob_Histosols  prob_Vertisols  \
# 1071             0.0           1.0             0.0             7.0
#
#       prob_Lixisols  prob_Phaeozems  prob_Regosols  prob_Solonetz  \
# 1071            2.0             1.0            0.0            0.0
#
#       prob_Solonchaks  prob_Leptosols  prob_Nitisols  prob_Stagnosols  \
# 1071              0.0             1.0            3.0              0.0
#
#       elevation   tavg  tmin  tmax        prcp  land_cost_year  \
# 1071        1.0  28.05  24.4  31.8  187.083333            2020
#
#       price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 1071                  24                   237                    0       1
#
#       rental_yield  price_rent_ratio  union_density  stations_per_km
# 1071             3                29       8.862364         0.746269

# %% [markdown]
# This is the Manila LRT Line 1 (Phase 1- Cavite Extension). The data are correct [keep]

# %%
df_adj.loc[[1093]]
# Out:
#      country         city  start_year  end_year  rr?  length  tunnel_per  \
# 1093      PA  Panama City        2020      2024  0.0    26.7         0.0
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1093     0.0      26.7       0.0      14.0       70.0       1435.0          1
#
#          cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1093  2431.79      PAB  2022  2.262963  5503.051357  206.106792       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1093       0.0      0         1.015482       5588.2519    209.297824
#
#      train_type  duration  country_pop_den    region  \
# 1093   Monorail         4        57.891561  Americas
#
#                            sub_region  area_km     lat      lng  population  \
# 1093  Latin America and the Caribbean    275.0  8.9833 -79.5167   1500189.0
#
#       time_diff  calculated_population  city_density  per_below_line  \
# 1093         -2           1.561103e+06   5676.737051       15.398764
#
#       reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 1093    13630.30114      Cambisols              6.0              9.0
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 1093            9.0            7.0            0.0            17.0
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 1093            4.0               0.0                0.0             0.0
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 1093              0.0            0.0             0.0             8.0
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 1093           4.0             0.0             7.0              10.0
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 1093            4.0             0.0           1.0             2.0
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 1093             4.0            4.0             1.0            2.0
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 1093            0.0              0.0             2.0            2.0
#
#       prob_Stagnosols  elevation  tavg  tmin  tmax    prcp  land_cost_year  \
# 1093              0.0       17.0  27.6  23.4  32.0  158.75            2020
#
#       price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 1093                  12                   101                    1       1
#
#       rental_yield  price_rent_ratio  union_density  stations_per_km
# 1093             8                12          20.23         0.524345

# %% [markdown]
# This is the Panama City Line 3 project. The data are correct [keep]

# %%
df_adj.loc[[1163]]
# Out:
#      country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1163      AU  Sydney        2019      2023  0.0    12.0         0.0     0.0
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 1163       0.0      12.0      16.0      100.0       1435.0          1  2348.0
#
#      currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 1163      AUD  2021  0.690809  1622.019677  135.168306       0.0       0.0
#
#       anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 1163      1         1.007292     1633.847569    136.153964       Tram
#
#       duration  country_pop_den   region                 sub_region  area_km  \
# 1163         4         3.335312  Oceania  Australia and New Zealand   1687.0
#
#           lat     lng  population  time_diff  calculated_population  \
# 1163 -33.8678  151.21   4840600.0         -1             4902075.62
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1163   2905.794677        0.989104    57527.17703      Cambisols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1163              6.0              6.0           10.0            0.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1163            0.0            11.0            2.0               2.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1163                0.0             1.0              2.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1163             0.0             1.0           0.0             6.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1163             9.0               0.0            6.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1163           1.0             1.0            11.0            3.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1163             8.0            4.0            1.0              2.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation       tavg  \
# 1163             5.0            3.0              0.0       72.0  18.191667
#
#         tmin       tmax        prcp  land_cost_year  price_income_ratio  \
# 1163  14.225  22.133333  107.908333            2020                   7
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1163                    55                    1       1             4
#
#       price_rent_ratio  union_density  stations_per_km
# 1163                22           17.3         1.333333

# %% [markdown]
# This is the Metro City & SW Metro in Sydney. The most recent cost estimate has the total cost at 20.5Bn AUD.[ adjust]

# %%
data.loc[1163,'length'] = 30
data.loc[1163,'cost_real_2023'] = 20500*0.690809*1

# %%
df_adj.loc[[1166]]
# Out:
#      country       city  start_year  end_year  rr?  length  tunnel_per  \
# 1166      SG  Singapore        2002      2012  0.0    35.5         1.0
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1166    35.5       0.0       0.0      30.0       80.0       1435.0          0
#
#         cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1166  6749.0      SGD  2007  1.157571  7812.446679  220.068921       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1166       0.0      1         1.316404    10209.891254    287.602571
#
#      train_type  duration  country_pop_den region          sub_region  \
# 1166        MRT        10      6602.300719   Asia  South-eastern Asia
#
#       area_km  lat    lng  population  time_diff  calculated_population  \
# 1166    523.0  1.3  103.8   5983000.0         13           5.478445e+06
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1166  10475.038421         1.52869          950.0      Cambisols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1166              6.0             17.0           14.0            2.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1166            0.0            17.0            2.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1166                0.0             0.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1166             0.0             8.0           1.0             1.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1166             3.0               8.0            0.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1166           3.0            16.0             1.0            3.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1166             1.0            0.0            0.0              0.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  \
# 1166             0.0            2.0              0.0       14.0  28.25  25.0
#
#       tmax    prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 1166  31.6  176.25            2007                  19                   124
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 1166                    0       1             3                23
#
#       union_density  stations_per_km
# 1166      16.007242          0.84507

# %% [markdown]
# This is the Singapore Circle Line (Stages 1-5). The data are correct [keep]

# %%
df_adj.loc[[1168]]
# Out:
#      country       city  start_year  end_year  rr?  length  tunnel_per  \
# 1168      SG  Singapore        2014      2024  0.0    43.0         1.0
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1168    43.0       0.0       0.0      32.0       80.0       1435.0          0
#
#          cost currency  year  ppp_rate  cost_real    cost_km  c_length  \
# 1168  12300.0      SGD  2019  1.140573     1808.1  42.048837       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1168       0.0      1         1.067626     1916.399766     44.567436
#
#      train_type  duration  country_pop_den region          sub_region  \
# 1168        MRT        10      7965.878492   Asia  South-eastern Asia
#
#       area_km  lat    lng  population  time_diff  calculated_population  \
# 1168    523.0  1.3  103.8   5983000.0          1           5.942590e+06
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1168  11362.505517        1.709393        82807.6      Cambisols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1168              6.0             17.0           14.0            2.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1168            0.0            17.0            2.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1168                0.0             0.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1168             0.0             8.0           1.0             1.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1168             3.0               8.0            0.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1168           3.0            16.0             1.0            3.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1168             1.0            0.0            0.0              0.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  \
# 1168             0.0            2.0              0.0       14.0  28.25  25.0
#
#       tmax    prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 1168  31.6  176.25            2019                  21                   133
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 1168                    0       1             2                42
#
#       union_density  stations_per_km
# 1168      16.007242         0.744186

# %% [markdown]
# This is the Singapore Thomson MRT Line. The data are correct [keep]

# %%
df_adj.loc[[1254]]
# Out:
#      country       city  start_year  end_year  rr?     length  tunnel_per  \
# 1254      US  Charlotte        2024      2030  0.0  40.877868         0.0
#
#       tunnel  elevated   at_grade  stations  max_speed  track_gauge  \
# 1254     0.0       0.0  40.877868      31.0      100.0       1435.0
#
#       overhead?    cost currency  year  ppp_rate  cost_real     cost_km  \
# 1254          1  8500.0      USD  2027       1.0     8500.0  207.936479
#
#       c_length  c_tunnel  anglo  inflation_index  cost_real_2023  \
# 1254       0.0       0.0      1          0.94252     8011.419793
#
#       cost_km_2023  train_type  duration  country_pop_den    region  \
# 1254    195.984285  Light Rail         6        36.240985  Americas
#
#             sub_region  area_km      lat      lng  population  time_diff  \
# 1254  Northern America   1126.0  35.2083 -80.8303   1516107.0         -7
#
#       calculated_population  city_density  per_below_line  reporting_gdp  \
# 1254           1.552560e+06   1378.828143         2.15759    65536.73429
#
#      wrb_class_name  wrb_class_value  prob_Ferralsols  prob_Acrisols  \
# 1254       Luvisols             18.0              0.0           31.0
#
#       prob_Andosols  prob_Cryosols  prob_Cambisols  prob_Gleysols  \
# 1254            0.0            0.0             5.0            0.0
#
#       prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  prob_Chernozems  \
# 1254               2.0                0.0             0.0              0.0
#
#       prob_Durisols  prob_Gypsisols  prob_Fluvisols  prob_Alisols  \
# 1254            0.0             0.0             1.0           5.0
#
#       prob_Planosols  prob_Arenosols  prob_Plinthosols  prob_Luvisols  \
# 1254             1.0             0.0               0.0           41.0
#
#       prob_Umbrisols  prob_Podzols  prob_Histosols  prob_Vertisols  \
# 1254             0.0           2.0             1.0             3.0
#
#       prob_Lixisols  prob_Phaeozems  prob_Regosols  prob_Solonetz  \
# 1254            3.0             1.0            3.0            0.0
#
#       prob_Solonchaks  prob_Leptosols  prob_Nitisols  prob_Stagnosols  \
# 1254              0.0             0.0            0.0              0.0
#
#       elevation       tavg      tmin  tmax       prcp  land_cost_year  \
# 1254      209.0  15.558333  9.783333  21.3  90.416667            2020
#
#       price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 1254                   3                    26                    3       0
#
#       rental_yield  price_rent_ratio  union_density  stations_per_km
# 1254            11                 8         11.802         0.758357

# %% [markdown]
# This is the Charlotte Silver Line. The data are correct [keep]

# %%
df_adj.loc[[1359]]
# Out:
#      country           city  start_year  end_year  rr?  length  tunnel_per  \
# 1359      UK  Tyne-and-Wear        1980      2002  0.0    77.0    0.083117
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1359     6.4       0.0      70.6      57.0       80.0       1435.0          1
#
#        cost currency  year  ppp_rate   cost_real   cost_km  c_length  \
# 1359  397.0      GBP  1991  1.543856  612.910646  7.959879       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1359       0.0      1         2.004008     1228.278039     15.951663
#
#       train_type  duration  country_pop_den  region       sub_region  area_km  \
# 1359  Light Rail        22       237.361621  Europe  Northern Europe    540.0
#
#           lat     lng  population  time_diff  calculated_population  \
# 1359  54.9783 -1.6178   1140000.0         29          972354.611625
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1359   1800.656688          2.7194    27602.94391      Cambisols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1359              6.0              0.0            0.0            0.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1359            1.0            21.0            7.0               1.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1359                0.0             0.0              1.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1359             0.0             6.0           1.0             5.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1359             3.0               0.0           18.0             3.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1359          10.0             4.0             1.0            0.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1359             3.0            0.0            0.0              1.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  \
# 1359             5.0            0.0              6.0       58.0  10.6   7.5
#
#       tmax       prcp  land_cost_year  price_income_ratio  \
# 1359  13.7  69.583333            1991                   7
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1359                    76                    1       0             4
#
#       price_rent_ratio  union_density  stations_per_km
# 1359                26      28.591909          0.74026

# %% [markdown]
# This is the Tyne and Wear line. I previously verified this data. [drop]

# %%
cooks_drop.append(1359)

# %%
df_adj.loc[[1368]]
# Out:
#      country      city  start_year  end_year  rr?     length  tunnel_per  \
# 1368      DO  Santiago        2022      2024  0.0  14.402527         0.0
#
#       tunnel   elevated  at_grade  stations  max_speed  track_gauge  \
# 1368     0.0  14.402527       0.0      16.0       90.0          0.0
#
#       overhead?     cost currency  year  ppp_rate    cost_real    cost_km  \
# 1368          0  25000.0      DRD  2023  0.040954  1023.843749  71.087784
#
#       c_length  c_tunnel  anglo  inflation_index  cost_real_2023  \
# 1368       0.0       0.0      0              1.0     1023.843749
#
#       cost_km_2023 train_type  duration  country_pop_den    region  \
# 1368     71.087784   Monorail         2       227.689174  Americas
#
#                            sub_region  area_km      lat      lng  population  \
# 1368  Latin America and the Caribbean    0.641  19.4572 -70.6889   1343423.0
#
#       time_diff  calculated_population  city_density  per_below_line  \
# 1368         -3           1.370607e+06  2.138233e+06       30.352532
#
#       reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 1368    6921.520594      Vertisols             29.0              8.0
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 1368            8.0            2.0            0.0            13.0
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 1368            1.0               6.0                0.0             0.0
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 1368              0.0            0.0             0.0             2.0
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 1368           0.0             2.0             3.0               0.0
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 1368           12.0             0.0           0.0             0.0
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 1368            22.0            5.0             6.0            2.0
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 1368            0.0              0.0             2.0            4.0
#
#       prob_Stagnosols  elevation  tavg  tmin  tmax    prcp  land_cost_year  \
# 1368              0.0      203.0  26.6  22.9  30.3  126.25            2020
#
#       price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 1368                  13                   183                    0       1
#
#       rental_yield  price_rent_ratio  union_density  stations_per_km
# 1368             6                14          8.441         1.110916

# %% [markdown]
# This is the Santiago Monorriel. I can't verify the data and this datapoint is the most significant outlier in the dataset. [remove]

# %%
cooks_drop.append(1368)

# %%
df_adj.loc[[1414]]
# Out:
#      country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1414      CO  Bogota        2020      2024  0.0    23.9         0.0     0.0
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1414      23.9       0.0      15.0       90.0       1435.0          1
#
#             cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1414  13800000.0      COP  2022  0.000719  9920.921293  415.101309       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1414       0.0      0         1.015482     10074.52115    421.528081
#
#      train_type  duration  country_pop_den    region  \
# 1414       Tram         4        45.904157  Americas
#
#                            sub_region  area_km     lat      lng  population  \
# 1414  Latin America and the Caribbean    518.0  4.7111 -74.0722   7968095.0
#
#       time_diff  calculated_population  city_density  per_below_line  \
# 1414         -2           8.199228e+06  15828.626255       34.596413
#
#       reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 1414     6175.87603       Andosols              3.0              5.0
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 1414            5.0           24.0            0.0            16.0
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 1414           11.0               0.0                0.0             1.0
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 1414              0.0            0.0             0.0             3.0
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 1414           4.0             1.0             0.0               0.0
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 1414            7.0             0.0           0.0             0.0
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 1414             3.0            2.0             3.0            3.0
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 1414            0.0              0.0             6.0            0.0
#
#       prob_Stagnosols  elevation       tavg      tmin       tmax       prcp  \
# 1414              0.0     2557.0  13.108333  7.158333  19.083333  68.666667
#
#       land_cost_year  price_income_ratio  mortgage_perc_income  \
# 1414            2020                  19                   255
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 1414                    0       1             4                22
#
#       union_density  stations_per_km
# 1414          4.854         0.627615

# %% [markdown]
# This is Bogota Line 1. This is a significant outlier [remove]

# %%
cooks_drop.append(1414)

# %%
df_adj.loc[[1237]]
# Out:
#      country          city  start_year  end_year  rr?  length  tunnel_per  \
# 1237      MY  Kuala Lumpur        2017      2025  0.0    37.6    0.053191
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1237     2.0      35.6       0.0      26.0      100.0       1435.0          0
#
#          cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1237  16630.0      MYR  2021  0.631288  10498.31589  279.210529       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1237       0.0      0         1.007292     10574.87041    281.246554
#
#       train_type  duration  country_pop_den region          sub_region  \
# 1237  Light Rail         8       101.050047   Asia  South-eastern Asia
#
#       area_km     lat       lng  population  time_diff  calculated_population  \
# 1237   2163.0  3.1478  101.6953   8911000.0         -1              9124864.0
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1237   4218.614887        4.818305    9955.242722       Acrisols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1237              0.0             12.0           51.0            2.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1237            0.0            10.0            1.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1237                0.0             0.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1237             0.0             2.0           1.0             1.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1237             5.0               2.0            1.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1237           2.0             3.0             1.0            1.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1237             1.0            0.0            0.0              0.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  \
# 1237             0.0            2.0              0.0       35.0  28.45  24.1
#
#       tmax        prcp  land_cost_year  price_income_ratio  \
# 1237  32.9  202.083333            2020                   9
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1237                    75                    1       1             3
#
#       price_rent_ratio  union_density  stations_per_km
# 1237                27       9.168442         0.691489

# %% [markdown]
# This is the Kuala Lumpur LRT3 (Shah Alam line). The data are correct [keep]

# %%
df_adj.loc[[1464]]
# Out:
#      country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1464      NG  Lagos        2020      2023  0.0    27.0         0.0     0.0
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1464       5.0      22.0      13.0       60.0       1435.0          1
#
#           cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1464  927864.0      NGN  2022  0.006329  5872.185305  217.488345       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1464       0.0      0         1.015482     5963.100934     220.85559
#
#       train_type  duration  country_pop_den  region          sub_region  \
# 1464  Light Rail         3       228.737667  Africa  Sub-Saharan Africa
#
#       area_km    lat     lng  population  time_diff  calculated_population  \
# 1464   1966.0  6.455  3.3841  16637000.0         -2           1.786677e+07
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1464   9087.878234       89.539519    2687.480056       Acrisols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1464              0.0              5.0           19.0            0.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1464            0.0            10.0            6.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1464                0.0             1.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1464             0.0            13.0           3.0             0.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1464             6.0               4.0            1.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1464           0.0             0.0            11.0            9.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1464             1.0            0.0            0.0              3.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  \
# 1464             2.0            1.0              0.0        9.0  27.75  23.9
#
#       tmax        prcp  land_cost_year  price_income_ratio  \
# 1464  31.7  128.333333            2020                   4
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1464                    96                    1       1            40
#
#       price_rent_ratio  union_density  stations_per_km
# 1464                 9            0.0         0.481481

# %% [markdown]
# This is the Lagos Rail Mass Transit (LRMT) Blue Line. This is a significant outlier [remove]

# %%
cooks_drop.append(1464)

# %%
df_adj.loc[[1480]]
# Out:
#      country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1480      QA  Lusail        2016      2020  0.0    22.5    0.568889    12.8
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 1480       0.0       9.7      16.0       60.0       1435.0          1  2394.0
#
#      currency  year  ppp_rate   cost_real    cost_km  c_length  c_tunnel  \
# 1480      QAR  2018  0.388308  929.609652  41.315985       0.0       0.0
#
#       anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 1480      0         1.086971     1010.458389     44.909262       Tram
#
#       duration  country_pop_den region    sub_region  area_km      lat    lng  \
# 1480         4       240.794778   Asia  Western Asia     38.0  25.4865  51.52
#
#       population  time_diff  calculated_population  city_density  \
# 1480    198600.0          2          183616.863905   4832.022734
#
#       per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 1480       43.486984         1500.0     Solonchaks             25.0
#
#       prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 1480              0.0            0.0            0.0            0.0
#
#       prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 1480             0.0            0.0               0.0                0.0
#
#       prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 1480             0.0              0.0            0.0             0.0
#
#       prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 1480             5.0           0.0             0.0             3.0
#
#       prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 1480               0.0            0.0             0.0           0.0
#
#       prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 1480             0.0             0.0            0.0             0.0
#
#       prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 1480           28.0            0.0             53.0             4.0
#
#       prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  tmax  prcp  \
# 1480            0.0              0.0        0.0  28.6  14.7  25.1  6.25
#
#       land_cost_year  price_income_ratio  mortgage_perc_income  \
# 1480            2018                   5                    44
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 1480                    2       1             6                15
#
#       union_density  stations_per_km
# 1480            0.0         0.711111

# %% [markdown]
# This is the Lusail Orange Line. The data are correct [keep]

# %%
df_adj.loc[[1517]]
# Out:
#      country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1517      TR  Konya        1996      1999  0.0    18.5         0.0     0.0
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?   cost  \
# 1517       0.0      18.5      18.0       70.0       1435.0          1  754.8
#
#      currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 1517      TRY  1998  7.759818  5857.110709  316.600579      18.5       0.0
#
#       anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 1517      0         1.674515     9807.819347    530.152397       Tram
#
#       duration  country_pop_den region    sub_region  area_km      lat  \
# 1517         3        80.872892   Asia  Western Asia   1055.0  37.8667
#
#           lng  population  time_diff  calculated_population  city_density  \
# 1517  32.4833   2232374.0         22           1.514234e+06   1435.293349
#
#       per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 1517       38.833735    6373.131907      Calcisols              5.0
#
#       prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 1517              0.0            0.0            2.0            0.0
#
#       prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 1517            15.0            1.0               9.0                0.0
#
#       prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 1517            19.0              0.0            0.0             2.0
#
#       prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 1517             6.0           0.0             0.0             1.0
#
#       prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 1517               0.0           16.0             0.0           1.0
#
#       prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 1517             0.0             1.0            0.0             1.0
#
#       prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 1517           16.0            1.0              3.0             6.0
#
#       prob_Nitisols  prob_Stagnosols  elevation       tavg   tmin    tmax  \
# 1517            0.0              0.0     1025.0  11.608333  5.425  17.825
#
#        prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 1517  27.75            1998                   0                    53
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 1517                    2       0             8                 9
#
#       union_density  stations_per_km
# 1517       5.337857         0.972973

# %% [markdown]
# This is the Konya T1 (tram). The data are correct [keep]

# %% [markdown]
# #### Unseen Data

# %%
cooks_outliers_unseen
# Out:
# Int64Index([1497,  543, 1098, 1616, 1045, 1158, 1091, 1632,   10, 1193, 1105,
#              541, 1190, 1461,  206, 1125, 1200,   14,  400,  952, 1160,  343,
#              996,  664,  315,    7, 1039,  961],
#            dtype='int64')

# %%
df_adj.loc[[7]]
# Out:
#   country       city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 7      HK  Hong Kong        2005      2009  1.0     3.8         1.0     3.8
#
#    elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 7       0.0       0.0       4.0       80.0       1432.0          0  8300.0
#
#   currency  year  ppp_rate  cost_real     cost_km  c_length  c_tunnel  anglo  \
# 7      HKD  2007  0.189588  1599.6258  420.954158       0.0       0.0      0
#
#    inflation_index  cost_real_2023  cost_km_2023 train_type  duration  \
# 7         1.316404     2015.528508    530.402239        MRT         4
#
#    country_pop_den region    sub_region  area_km   lat    lng  population  \
# 7      6586.952381   Asia  Eastern Asia    290.0  22.3  114.2   7450000.0
#
#    time_diff  calculated_population  city_density  per_below_line  \
# 7         13           6.946257e+06  23952.608894       46.826807
#
#    reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 7    4711.635127       Acrisols              0.0             13.0
#
#    prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  prob_Gleysols  \
# 7           37.0            4.0            0.0            15.0            3.0
#
#    prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  prob_Chernozems  \
# 7               0.0                0.0             0.0              0.0
#
#    prob_Durisols  prob_Gypsisols  prob_Fluvisols  prob_Alisols  \
# 7            0.0             0.0             4.0           3.0
#
#    prob_Planosols  prob_Arenosols  prob_Plinthosols  prob_Luvisols  \
# 7             0.0             0.0               0.0            5.0
#
#    prob_Umbrisols  prob_Podzols  prob_Histosols  prob_Vertisols  \
# 7             0.0           1.0             1.0             1.0
#
#    prob_Lixisols  prob_Phaeozems  prob_Regosols  prob_Solonetz  \
# 7            4.0             0.0            0.0            0.0
#
#    prob_Solonchaks  prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation  \
# 7              0.0             3.0            3.0              0.0        0.0
#
#    tavg  tmin  tmax   prcp  land_cost_year  price_income_ratio  \
# 7  23.5  21.6  26.0  202.6            2007                  15
#
#    mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 7                    96                    0       1             3
#
#    price_rent_ratio  union_density  stations_per_km
# 7                19      21.699286         1.052632

# %% [markdown]
# This is the Kowloon Southern Link in Hong Kong. The data are correct. [keep]

# %%
df_adj.loc[[10]]
# Out:
#    country       city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 10      HK  Hong Kong        2011      2016  0.0     7.4    0.714286     5.0
#
#     elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 10       2.0       0.0       5.0       80.0       1435.0          0  16900.0
#
#    currency  year  ppp_rate  cost_real      cost_km  c_length  c_tunnel  \
# 10      HKD  2014   0.17524  3046.3771  2283.783784       0.0       0.0
#
#     anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  duration  \
# 10      0         1.152955      3543.47273    478.847666        MRT         5
#
#     country_pop_den region    sub_region  area_km   lat    lng  population  \
# 10      6885.238095   Asia  Eastern Asia    290.0  22.3  114.2   7450000.0
#
#     time_diff  calculated_population  city_density  per_below_line  \
# 10          6           7.213117e+06  24872.817854       46.826807
#
#     reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 10    4711.635127       Acrisols              0.0             13.0
#
#     prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 10           37.0            4.0            0.0            15.0
#
#     prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 10            3.0               0.0                0.0             0.0
#
#     prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 10              0.0            0.0             0.0             4.0
#
#     prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 10           3.0             0.0             0.0               0.0
#
#     prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 10            5.0             0.0           1.0             1.0
#
#     prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 10             1.0            4.0             0.0            0.0
#
#     prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 10            0.0              0.0             3.0            3.0
#
#     prob_Stagnosols  elevation  tavg  tmin  tmax   prcp  land_cost_year  \
# 10              0.0        0.0  23.5  21.6  26.0  202.6            2014
#
#     price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 10                  27                   174                    0       1
#
#     rental_yield  price_rent_ratio  union_density  stations_per_km
# 10             3                33      21.699286         0.714286

# %% [markdown]
# This is the South Island Line (East) in Hong Kong. I've previously reviewed this data. [remove]

# %%
cooks_drop.append(10)

# %%
df_adj.loc[[14]]
# Out:
#    country       city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 14      HK  Hong Kong        1975      1980  0.0    15.6    0.820513    12.8
#
#     elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 14       2.8       0.0      15.0       80.0       1432.0          0  5637.0
#
#    currency  year  ppp_rate  cost_real    cost_km  c_length  c_tunnel  anglo  \
# 14      HKD  1978       0.2     1127.4  72.269231       0.0       0.0      0
#
#     inflation_index  cost_real_2023  cost_km_2023 train_type  duration  \
# 14         4.186287     4719.620338    302.539765        MRT         5
#
#     country_pop_den region    sub_region  area_km   lat    lng  population  \
# 14           4667.5   Asia  Eastern Asia    290.0  22.3  114.2   7450000.0
#
#     time_diff  calculated_population  city_density  per_below_line  \
# 14         42           5.941872e+06  20489.213005       99.922875
#
#     reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 14     447.118997       Acrisols              0.0             13.0
#
#     prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 14           37.0            4.0            0.0            15.0
#
#     prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 14            3.0               0.0                0.0             0.0
#
#     prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 14              0.0            0.0             0.0             4.0
#
#     prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 14           3.0             0.0             0.0               0.0
#
#     prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 14            5.0             0.0           1.0             1.0
#
#     prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 14             1.0            4.0             0.0            0.0
#
#     prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 14            0.0              0.0             3.0            3.0
#
#     prob_Stagnosols  elevation  tavg  tmin  tmax   prcp  land_cost_year  \
# 14              0.0        0.0  23.5  21.6  26.0  202.6            1978
#
#     price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 14                   1                    12                    1       1
#
#     rental_yield  price_rent_ratio  union_density  stations_per_km
# 14             7                 3      21.699286         0.961538

# %% [markdown]
# This is the Modified Initial System in Hong Kong. Due to the age of this project, I'm unable to verify some components. [remove]

# %%
cooks_drop.append(14)

# %%
df_adj.loc[[206]]
# Out:
#     country      city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 206      CN  Shanghai        2022      2026  0.0    28.0         1.0    28.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 206       0.0       0.0      16.0       80.0       1435.0          1  36956.0
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 206      CNY  2024  0.248641  9188.771876  328.170424       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 206      0         0.984983     9050.780351    323.242155        MRT
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 206         4       149.723553   Asia  Eastern Asia  14922.7  31.1667
#
#           lng  population  time_diff  calculated_population  city_density  \
# 206  121.4667  24073000.0         -4           2.649957e+07    1775.78956
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 206       37.855836    8016.431435      Fluvisols             11.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 206              0.0            5.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 206            14.0            9.0               1.0                2.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 206             0.0              1.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 206            19.0           6.0             0.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 206               0.0           17.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 206             0.0             6.0            4.0             1.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 206            2.0            1.0              6.0             3.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg   tmin       tmax  \
# 206            0.0              0.0        0.0  16.133333  12.45  19.841667
#
#           prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 206  92.658333            2020                  29                   231
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 206                    0       0             1                52
#
#      union_density  stations_per_km
# 206       16.31287         0.571429

# %% [markdown]
# This is line 21, phase 1 in Shanghai. The data are correct. [remove]

# %%
cooks_drop.append(206)

# %%
df_adj.loc[[315]]
# Out:
#     country      city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 315      TR  Istanbul        2018      2022  0.0    32.0         1.0    32.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 315       0.0       0.0       7.0      120.0       1435.0          1
#
#            cost currency  year  ppp_rate    cost_real    cost_km  c_length  \
# 315  3478.26087      TRY  2020  0.462065  1607.180884  50.224403      32.0
#
#      c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 315      32.0      0         1.054615      1694.95689     52.967403
#
#     train_type  duration  country_pop_den region    sub_region  area_km  \
# 315        MRT         4        109.31932   Asia  Western Asia   1471.0
#
#          lat     lng  population  time_diff  calculated_population  \
# 315  41.0136  28.955  16079000.0          0             16079000.0
#
#      city_density  per_below_line  reporting_gdp wrb_class_name  \
# 315  10930.659415       13.702734    11006.27952      Cambisols
#
#      wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 315              6.0              1.0            6.0            3.0
#
#      prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 315            0.0            27.0            0.0               3.0
#
#      prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 315                1.0             4.0              3.0            0.0
#
#      prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 315             0.0             5.0           2.0             0.0
#
#      prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 315             0.0               0.0           15.0             0.0
#
#      prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 315           0.0             0.0             9.0            1.0
#
#      prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 315             6.0           11.0            0.0              0.0
#
#      prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation       tavg  \
# 315             3.0            0.0              0.0       41.0  14.458333
#
#           tmin       tmax       prcp  land_cost_year  price_income_ratio  \
# 315  10.383333  18.491667  58.083333            2020                   7
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 315                   155                    0       1             5
#
#      price_rent_ratio  union_density  stations_per_km
# 315                18       5.337857          0.21875

# %% [markdown]
# This is the M11 Phase 2 in Istanbul. The overall cost is off by a factor of 10. Additionally, since 2018, the PPP rate and conversion rate has been wildly inconsistent. [remove]

# %%
cooks_drop.append(315)

# %%
df_adj.loc[[343]]
# Out:
#     country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 343      KR  Seoul        2002      2009  0.0    25.1    0.956175    24.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 343       1.1       0.0      25.0       80.0       1435.0          1
#
#           cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 343  3464064.0      KRW  2006  0.001295  4485.873483  178.720059      25.1
#
#      c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 343      24.0      0         1.353898     6073.417302    241.968817
#
#     train_type  duration  country_pop_den region    sub_region  area_km  \
# 343        MRT         7        499.98237   Asia  Eastern Asia   2769.0
#
#        lat     lng  population  time_diff  calculated_population  \
# 343  37.56  126.99  23016000.0         14           2.263279e+07
#
#      city_density  per_below_line  reporting_gdp wrb_class_name  \
# 343   8173.632741        1.994652    22192.18512       Luvisols
#
#      wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 343             18.0              0.0            1.0            1.0
#
#      prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 343            0.0            19.0            2.0               4.0
#
#      prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 343                0.0             0.0              4.0            0.0
#
#      prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 343             1.0             9.0           5.0             3.0
#
#      prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 343             1.0               0.0           29.0             0.0
#
#      prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 343           0.0             0.0             1.0            2.0
#
#      prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 343             4.0            3.0            0.0              1.0
#
#      prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation       tavg  \
# 343             6.0            0.0              0.0       44.0  12.183333
#
#       tmin   tmax    prcp  land_cost_year  price_income_ratio  \
# 343  7.825  16.55  114.25            2006                   7
#
#      mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 343                    92                    1       1             3
#
#      price_rent_ratio  union_density  stations_per_km
# 343                 7       9.769591         0.996016

# %% [markdown]
# This is Seoul Line 9 (Phase 1). The data are correct. [keep]

# %%
df_adj.loc[[400]]
# Out:
#     country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 400      IN  Mumbai        2020      2026  0.0    20.8         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 400      20.8       0.0      17.0       80.0       1435.0          1  47380.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 400      INR  2023  0.041564  1969.285628  94.677194       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 400      0              1.0     1969.285628     94.677194        MRT
#
#      duration  country_pop_den region     sub_region  area_km      lat  \
# 400         6       469.659567   Asia  Southern Asia    976.0  19.0761
#
#          lng  population  time_diff  calculated_population  city_density  \
# 400  72.8775  24973000.0         -3           2.619099e+07  26835.026182
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 400       88.900103     1580.05946      Vertisols             29.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 400              0.0            3.0            1.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 400             7.0            7.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 400             1.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 400             9.0           1.0             0.0             5.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 400               1.0            4.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 400             0.0            22.0            6.0             5.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 400            2.0            0.0              8.0            12.0
#
#      prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  tmax        prcp  \
# 400            1.0              0.0        6.0  27.5  22.7  32.4  182.083333
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 400            2020                  11                   126
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 400                    0       1             3                33
#
#      union_density  stations_per_km
# 400      12.133509         0.817308

# %% [markdown]
# This is Mumbai Line 12. The data are correct. [keep]

# %%
df_adj.loc[[541]]
# Out:
#     country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 541      TW  Taipei        2019      2025  0.0    11.5         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 541      11.5       0.0       8.0       90.0       1435.0          0  19558.0
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 541      TWD  2022  0.217036  4244.785228  369.111759       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 541      0         1.015482     4310.504768    374.826502        MRT
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 541         6            673.0   Asia  Eastern Asia    376.0  25.0375
#
#           lng  population  time_diff  calculated_population  city_density  \
# 541  121.5625   9078000.0         -2           9.156239e+06  24351.698543
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 541        0.247678       47008.92      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 541             14.0           14.0            7.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 541            17.0            4.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 541             0.0              1.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 541             8.0           2.0             0.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 541               0.0            4.0             0.0           1.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 541             4.0             3.0            3.0             1.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 541            3.0            2.0              1.0             3.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax   prcp  \
# 541            4.0              0.0        9.0  20.15  20.6  26.9  197.5
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 541            2020                  23                   142
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 541                    0       1             1                72
#
#      union_density  stations_per_km
# 541         39.355         0.695652

# %% [markdown]
# This is the Taoyuan MRT Brown Line in Taipei. The data are correct.[keep]

# %%
df_adj.loc[[543]]
# Out:
#     country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 543      TW  Taipei        2023      2032  0.0    16.0         0.1     1.6
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 543      12.8       1.6      13.0       90.0       1067.0          1  42500.0
#
#     currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 543      TWD  2028  0.217036  9224.019439  576.501215       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 543      0         0.929168      8570.66211    535.666382        MRT
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 543         9            676.0   Asia  Eastern Asia    376.0  25.0375
#
#           lng  population  time_diff  calculated_population  city_density  \
# 543  121.5625   9078000.0         -8           9.395024e+06  24986.765157
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 543        0.247678       50008.92      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 543             14.0           14.0            7.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 543            17.0            4.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 543             0.0              1.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 543             8.0           2.0             0.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 543               0.0            4.0             0.0           1.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 543             4.0             3.0            3.0             1.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 543            3.0            2.0              1.0             3.0
#
#      prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  tmax   prcp  \
# 543            4.0              0.0        9.0  20.15  20.6  26.9  197.5
#
#      land_cost_year  price_income_ratio  mortgage_perc_income  \
# 543            2020                  23                   142
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 543                    0       1             1                72
#
#      union_density  stations_per_km
# 543         39.355           0.8125

# %% [markdown]
# This is the Taipei Keelung MRT project. This is a significant outlier [remove]

# %%
cooks_drop.append(543)

# %%
df_adj.loc[[664]]
# Out:
#     country       city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 664      CN  Chongqing        2020      2025  0.0  37.353     0.27805  10.386
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 664    26.967       0.0       9.0       80.0       1435.0          1  8642.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 664      CNY  2023  0.248641  2148.754371  57.525617       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 664      0              1.0     2148.754371     57.525617        MRT
#
#      duration  country_pop_den region    sub_region  area_km    lat       lng  \
# 664         5       149.723553   Asia  Eastern Asia   5472.8  29.55  106.5069
#
#      population  time_diff  calculated_population  city_density  \
# 664  12135000.0         -3           1.316777e+07   2406.038044
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 664       37.855836    8016.431435      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 664              2.0            7.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 664            29.0            1.0               0.0                1.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 664             2.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 664             5.0          11.0             2.0             2.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 664               0.0            4.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 664             0.0             2.0            4.0             3.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 664           13.0            0.0              1.0             8.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg       tmin    tmax  \
# 664            1.0              0.0      218.0  18.291667  15.291667  21.275
#
#           prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 664  89.916667            2020                  29                   231
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 664                    0       0             1                52
#
#      union_density  stations_per_km
# 664       16.31287         0.240945

# %% [markdown]
# This is the Chongqing Bishan-Tongliang Line.  The data are correct.[keep]

# %%
df_adj.loc[[952]]
# Out:
#     country     city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 952      TH  Bangkok        2022      2027  0.0   23.63         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 952     23.63       0.0      17.0      100.0       1435.0          0  82000.0
#
#     currency  year  ppp_rate   cost_real     cost_km  c_length  c_tunnel  \
# 952      THB  2025  0.085338  6997.74864  296.138326       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 952      0          0.97041     6790.682166    287.375462        MRT
#
#      duration  country_pop_den region          sub_region  area_km      lat  \
# 952         5       139.904214   Asia  South-eastern Asia   3199.0  13.7525
#
#           lng  population  time_diff  calculated_population  city_density  \
# 952  100.4942  18007000.0         -5           1.945606e+07   6081.918351
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 952       14.598018    5840.053067      Fluvisols             11.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 952              2.0            0.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 952             9.0            3.0               1.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 952             2.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 952            61.0           0.0             1.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 952               0.0            6.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 952             0.0             5.0            1.0             0.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 952            1.0            3.0              1.0             2.0
#
#      prob_Nitisols  prob_Stagnosols  elevation  tavg       tmin       tmax  \
# 952            0.0              0.0        4.0  28.4  24.083333  32.733333
#
#            prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 952  124.833333            2020                  22                   185
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 952                    0       1             3                31
#
#      union_density  stations_per_km
# 952       3.348848         0.719424

# %% [markdown]
# This is the Bangkok Purple Line (Southern Extension). The data are correct.[keep]

# %%
df_adj.loc[[961]]
# Out:
#     country     city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 961      TH  Bangkok        2015      2018  0.0    28.4         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?     cost  \
# 961      28.4       0.0       8.0      140.0       1435.0          0  25900.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 961      THB  2017  0.077853  2016.393345  70.999766       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023     train_type  \
# 961      0          1.11352      2245.29359     79.059633  Regional Rail
#
#      duration  country_pop_den region          sub_region  area_km      lat  \
# 961         3       138.773908   Asia  South-eastern Asia   3199.0  13.7525
#
#           lng  population  time_diff  calculated_population  city_density  \
# 961  100.4942  18007000.0          3           1.718990e+07   5373.522205
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 961       14.598018    5840.053067      Fluvisols             11.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 961              2.0            0.0            0.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 961             9.0            3.0               1.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 961             2.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 961            61.0           0.0             1.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 961               0.0            6.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 961             0.0             5.0            1.0             0.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 961            1.0            3.0              1.0             2.0
#
#      prob_Nitisols  prob_Stagnosols  elevation  tavg       tmin       tmax  \
# 961            0.0              0.0        4.0  28.4  24.083333  32.733333
#
#            prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 961  124.833333            2017                  24                   212
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 961                    0       1             3                26
#
#      union_density  stations_per_km
# 961       3.348848          0.28169

# %% [markdown]
# This is the Bangkok Airport Link.  The data are correct.[keep]

# %%
df_adj.loc[[969]]
# Out:
#     country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 969      CN  Guilin        2020      2025  0.0   29.27    0.064913     1.9
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 969     27.37       0.0      13.0       80.0       1435.0          1  8299.0
#
#     currency  year  ppp_rate    cost_real    cost_km  c_length  c_tunnel  \
# 969      CNY  2023  0.248641  2063.470554  70.497798       0.0       0.0
#
#      anglo  inflation_index  cost_real_2023  cost_km_2023 train_type  \
# 969      0              1.0     2063.470554     70.497798        MRT
#
#      duration  country_pop_den region    sub_region  area_km      lat  \
# 969         5       149.723553   Asia  Eastern Asia   2753.0  25.2819
#
#           lng  population  time_diff  calculated_population  city_density  \
# 969  110.2864   5085500.0         -3           5.366671e+06   1949.390115
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 969       37.855836    8016.431435      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 969              1.0           17.0            1.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 969            22.0            3.0               2.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 969             0.0              0.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 969             8.0           1.0             1.0             0.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 969               0.0           11.0             0.0           0.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 969             0.0             4.0            9.0             0.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 969            7.0            2.0              0.0             6.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg       tmin    tmax  \
# 969            2.0              0.0      161.0  19.441667  15.708333  23.175
#
#            prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 969  155.066667            2020                  29                   231
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 969                    0       0             1                52
#
#      union_density  stations_per_km
# 969       16.31287         0.444141

# %% [markdown]
# This is Guilin Line 1.  The data are correct.[keep]

# %%
df_adj.loc[[996]]
# Out:
#     country    city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 996      US  Boston        2013      2024  1.0   58.26         0.0     0.0
#
#      elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 996       0.0     58.26       6.0      120.0       1435.0          0  1000.0
#
#     currency  year  ppp_rate  cost_real    cost_km  c_length  c_tunnel  anglo  \
# 996      EUR  2019       1.0     1000.0  17.164435       0.0       0.0      1
#
#      inflation_index  cost_real_2023  cost_km_2023     train_type  duration  \
# 996         1.067626     1067.625506     18.325189  Regional Rail        11
#
#      country_pop_den    region        sub_region  area_km      lat      lng  \
# 996        35.893176  Americas  Northern America    232.1  42.3188 -71.0852
#
#      population  time_diff  calculated_population  city_density  \
# 996   4208580.0          1           4.191813e+06  18060.373757
#
#      per_below_line  reporting_gdp wrb_class_name  wrb_class_value  \
# 996        2.248539     56863.3715      Cambisols              6.0
#
#      prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 996              0.0            7.0            1.0            0.0
#
#      prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 996            25.0            3.0               0.0                0.0
#
#      prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 996             0.0              2.0            0.0             0.0
#
#      prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 996             3.0          10.0             0.0             3.0
#
#      prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 996               0.0           21.0             0.0           2.0
#
#      prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 996             0.0             2.0            1.0             2.0
#
#      prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 996           11.0            1.0              0.0             2.0
#
#      prob_Nitisols  prob_Stagnosols  elevation       tavg      tmin  tmax  \
# 996            1.0              0.0       26.0  10.641667  6.408333  14.9
#
#           prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 996  87.666667            2019                   3                    26
#
#      affordability_index  urban?  rental_yield  price_rent_ratio  \
# 996                    3       1            10                 9
#
#      union_density  stations_per_km
# 996         11.802         0.102987

# %% [markdown]
# This is Boston South Coast Rail (Phase 1).  The data are correct.[keep]

# %%
df_adj.loc[[1039]]
# Out:
#      country       city  start_year  end_year  rr?  length  tunnel_per  \
# 1039      BR  Sao Paulo        2015      2023  0.0    15.9    0.842767
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1039    13.4       2.5       0.0      15.0       80.0       1435.0          1
#
#         cost currency  year  ppp_rate   cost_real     cost_km  c_length  \
# 1039  9600.0      BRL  2019   0.43866  4211.13767  264.851426       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1039       0.0      0         1.067626     4495.917987    282.762137
#
#      train_type  duration  country_pop_den    region  \
# 1039        MRT         8        25.338518  Americas
#
#                            sub_region  area_km    lat      lng  population  \
# 1039  Latin America and the Caribbean   7947.0 -23.55 -46.6333  23086000.0
#
#       time_diff  calculated_population  city_density  per_below_line  \
# 1039          1           2.289142e+07    2880.51125       25.276877
#
#       reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 1039    8813.989806     Ferralsols             10.0             20.0
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 1039            8.0            1.0            0.0            13.0
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 1039            4.0               0.0                0.0             0.0
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 1039              0.0            0.0             0.0             3.0
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 1039           1.0             1.0             7.0               1.0
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 1039            3.0             0.0           0.0             0.0
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 1039             4.0           10.0             3.0            1.0
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 1039            1.0              0.0            14.0            3.0
#
#       prob_Stagnosols  elevation  tavg  tmin   tmax    prcp  land_cost_year  \
# 1039              0.0      761.0  8.55  16.8  21.45  121.25            2019
#
#       price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 1039                  18                   219                    0       1
#
#       rental_yield  price_rent_ratio  union_density  stations_per_km
# 1039             3                26      16.784444         0.943396

# %% [markdown]
# This is Sao Paulo Line 6 (phase 1).  The data are correct.[keep]

# %%
df_adj.loc[[1045]]
# Out:
#      country       city  start_year  end_year  rr?  length  tunnel_per  \
# 1045      BR  Sao Paulo        2011      2014  0.0    17.7         0.0
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1045     0.0      17.7       0.0      18.0       80.0          0.0          0
#
#         cost currency  year  ppp_rate   cost_real    cost_km  c_length  \
# 1045  1400.0      BRL  2013  0.587794  822.911744  46.492189       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1045       0.0      0         1.171658      964.171133     54.472945
#
#      train_type  duration  country_pop_den    region  \
# 1045   Monorail         3        24.134768  Americas
#
#                            sub_region  area_km    lat      lng  population  \
# 1045  Latin America and the Caribbean   7947.0 -23.55 -46.6333  23086000.0
#
#       time_diff  calculated_population  city_density  per_below_line  \
# 1045          7           2.175792e+07   2737.878431       41.379542
#
#       reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 1045     7560.70204     Ferralsols             10.0             20.0
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 1045            8.0            1.0            0.0            13.0
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 1045            4.0               0.0                0.0             0.0
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 1045              0.0            0.0             0.0             3.0
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 1045           1.0             1.0             7.0               1.0
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 1045            3.0             0.0           0.0             0.0
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 1045             4.0           10.0             3.0            1.0
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 1045            1.0              0.0            14.0            3.0
#
#       prob_Stagnosols  elevation  tavg  tmin   tmax    prcp  land_cost_year  \
# 1045              0.0      761.0  8.55  16.8  21.45  121.25            2013
#
#       price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 1045                  13                   157                    0       1
#
#       rental_yield  price_rent_ratio  union_density  stations_per_km
# 1045             4                20      16.784444         1.016949

# %% [markdown]
# This is the Sao Paulo 17 Ouro Monorail. This is a significant outlier [remove].

# %%
cooks_drop.append(1045)

# %%
df_adj.loc[[1091]]
# Out:
#      country         city  start_year  end_year  rr?  length  tunnel_per  \
# 1091      PA  Panama City        2010      2014  0.0    13.7    0.532847
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1091     7.3      4.69      1.71      12.0       70.0       1435.0          1
#
#          cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1091  1948.73      PAB  2012  1.742124  3394.930193  247.805124       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1091       0.0      0          1.18882     4035.960838    294.595682
#
#      train_type  duration  country_pop_den    region  \
# 1091        MRT         4        50.509309  Americas
#
#                            sub_region  area_km     lat      lng  population  \
# 1091  Latin America and the Caribbean    275.0  8.9833 -79.5167   1500189.0
#
#       time_diff  calculated_population  city_density  per_below_line  \
# 1091          8           1.279393e+06    4652.33846       33.876227
#
#       reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 1091    8337.585391      Cambisols              6.0              9.0
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 1091            9.0            7.0            0.0            17.0
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 1091            4.0               0.0                0.0             0.0
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 1091              0.0            0.0             0.0             8.0
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 1091           4.0             0.0             7.0              10.0
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 1091            4.0             0.0           1.0             2.0
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 1091             4.0            4.0             1.0            2.0
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 1091            0.0              0.0             2.0            2.0
#
#       prob_Stagnosols  elevation  tavg  tmin  tmax    prcp  land_cost_year  \
# 1091              0.0       17.0  27.6  23.4  32.0  158.75            2012
#
#       price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 1091                   8                    75                    1       1
#
#       rental_yield  price_rent_ratio  union_density  stations_per_km
# 1091            10                 9          20.23         0.875912

# %% [markdown]
# This is the Panama City Line 1. The data are correct.[keep]

# %%
df_adj.loc[[1098]]
# Out:
#      country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1098      EC  Quito        2012      2019  0.0    22.9         1.0    22.9
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?    cost  \
# 1098       0.0       0.0      15.0       80.0       1435.0          1  2010.0
#
#      currency  year  ppp_rate    cost_real     cost_km  c_length  c_tunnel  \
# 1098      USD  2016  1.820809  3659.825219  159.817695       0.0       0.0
#
#       anglo  inflation_index  cost_real_2023  cost_km_2023  train_type  \
# 1098      0         1.137242     4162.105326    181.751324  Light Rail
#
#       duration  country_pop_den    region                       sub_region  \
# 1098         7        66.192563  Americas  Latin America and the Caribbean
#
#       area_km   lat      lng  population  time_diff  calculated_population  \
# 1098    479.0 -0.22 -78.5125   2011388.0          4           1.895845e+06
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1098   3957.922913       28.798778    6124.490887       Andosols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1098              3.0              2.0            5.0           36.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1098            0.0            17.0            1.0               1.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1098                0.0             0.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1098             0.0             1.0           2.0             0.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1098             0.0               0.0           11.0             1.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1098           0.0             0.0             2.0            1.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1098             4.0           10.0            0.0              0.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  \
# 1098             4.0            0.0              0.0     2831.0  14.55   9.7
#
#       tmax       prcp  land_cost_year  price_income_ratio  \
# 1098  19.5  91.666667            2016                  11
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1098                   138                    0       1             6
#
#       price_rent_ratio  union_density  stations_per_km
# 1098                14            9.0         0.655022

# %% [markdown]
# This is the Quito Metro . This datapoint is a signficant outlier [remove]

# %%
cooks_drop.append(1098)

# %%
df_adj.loc[[1105]]
# Out:
#      country       city  start_year  end_year  rr?  length  tunnel_per  \
# 1105      NL  Amsterdam        2003      2018  0.0     9.7    0.731959
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1105     7.1       0.0       2.6       8.0       60.0       1435.0          0
#
#         cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1105  3100.0      EUR  2011  1.196079  3707.845682  382.252132       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1105       0.0      0         1.213422     4499.181569    463.833151
#
#      train_type  duration  country_pop_den  region      sub_region  area_km  \
# 1105        MRT        15       495.049644  Europe  Western Europe    219.3
#
#           lat     lng  population  time_diff  calculated_population  \
# 1105  52.3728  4.8936   1459402.0          9           1.370597e+06
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1105   6249.871245        0.232243    43574.77519      Fluvisols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1105             11.0              0.0            0.0            0.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1105            0.0            18.0            8.0               2.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1105                0.0             2.0              3.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1105             0.0            22.0           0.0             1.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1105             6.0               0.0            3.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1105          13.0             5.0             4.0            0.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1105             3.0            3.0            0.0              0.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  \
# 1105             4.0            0.0              0.0       19.0  11.5   7.0
#
#       tmax       prcp  land_cost_year  price_income_ratio  \
# 1105  16.1  55.416667            2011                   5
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1105                    43                    2       1             5
#
#       price_rent_ratio  union_density  stations_per_km
# 1105                17      21.885303         0.824742

# %% [markdown]
# This is the Amsterdam North-South Line . The data are correct.[keep]

# %%
df_adj.loc[[1158]]
# Out:
#      country              city  start_year  end_year  rr?  length  tunnel_per  \
# 1158      VN  Ho Chi Minh City        2012      2021  0.0    19.7     0.13198
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1158     2.6      17.1       0.0      14.0       80.0       1435.0          1
#
#             cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1158  43600000.0      VND  2017  0.000135  5895.605822  299.269331       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1158       0.0      0          1.11352      6564.87287    333.242278
#
#      train_type  duration  country_pop_den region          sub_region  \
# 1158        MRT         9       300.038762   Asia  South-eastern Asia
#
#       area_km      lat       lng  population  time_diff  \
# 1158   2165.0  10.7756  106.7019  15136000.0          3
#
#       calculated_population  city_density  per_below_line  reporting_gdp  \
# 1158           1.398149e+07   6457.964278         43.5672        3756.49
#
#      wrb_class_name  wrb_class_value  prob_Ferralsols  prob_Acrisols  \
# 1158      Fluvisols             11.0              6.0            9.0
#
#       prob_Andosols  prob_Cryosols  prob_Cambisols  prob_Gleysols  \
# 1158            1.0            0.0            19.0            4.0
#
#       prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  prob_Chernozems  \
# 1158               0.0                0.0             0.0              0.0
#
#       prob_Durisols  prob_Gypsisols  prob_Fluvisols  prob_Alisols  \
# 1158            0.0             0.0            34.0           1.0
#
#       prob_Planosols  prob_Arenosols  prob_Plinthosols  prob_Luvisols  \
# 1158             2.0             8.0               5.0            2.0
#
#       prob_Umbrisols  prob_Podzols  prob_Histosols  prob_Vertisols  \
# 1158             0.0           0.0             0.0             3.0
#
#       prob_Lixisols  prob_Phaeozems  prob_Regosols  prob_Solonetz  \
# 1158            2.0             0.0            0.0            0.0
#
#       prob_Solonchaks  prob_Leptosols  prob_Nitisols  prob_Stagnosols  \
# 1158              0.0             1.0            1.0              0.0
#
#       elevation  tavg  tmin  tmax        prcp  land_cost_year  \
# 1158       14.0  27.5  24.6  30.4  165.166667            2017
#
#       price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 1158                  26                   285                    0       1
#
#       rental_yield  price_rent_ratio  union_density  stations_per_km
# 1158             4                22      20.403333          0.71066

# %% [markdown]
# This is the Ho Chi Minh City Line 1. The data are correct.[keep]

# %%
data_unseen.sort_values(by='cooks_distance',ascending=False).head(5)
# Out:
#       rr?  length  tunnel_per  tunnel  elevated  at_grade  stations  \
# 1497  0.0    74.0         0.0     0.0       0.0      74.0      11.0
# 543   0.0    16.0         0.1     1.6      12.8       1.6      13.0
# 1098  0.0    22.9         1.0    22.9       0.0       0.0      15.0
# 1616  0.0    19.0         0.0     0.0       0.0      19.0       6.0
# 1045  0.0    17.7         0.0     0.0      17.7       0.0      18.0
#
#       max_speed  track_gauge  overhead?    year  anglo  cost_real_2023  \
# 1497      120.0       1435.0        1.0  2020.0    0.0     8458.942644
# 543        90.0       1067.0        1.0  2028.0    0.0     8570.662110
# 1098       80.0       1435.0        1.0  2016.0    0.0     4162.105326
# 1616      160.0       1435.0        1.0  2022.0    0.0     1397.047101
# 1045       80.0          0.0        0.0  2013.0    0.0      964.171133
#
#          train_type  duration  country_pop_den    region  \
# 1497     Light Rail       3.0       107.956335    Africa
# 543             MRT       9.0       676.000000      Asia
# 1098     Light Rail       7.0        66.192563  Americas
# 1616  Regional Rail       5.0        85.369137    Africa
# 1045       Monorail       3.0        24.134768  Americas
#
#                            sub_region  area_km  population  \
# 1497                  Northern Africa    250.0    246148.0
# 543                      Eastern Asia    376.0   9078000.0
# 1098  Latin America and the Caribbean    479.0   2011388.0
# 1616               Sub-Saharan Africa     83.0   1438725.0
# 1045  Latin America and the Caribbean   7947.0  23086000.0
#
#       calculated_population  city_density  per_below_line  reporting_gdp  \
# 1497           2.461480e+05    984.592000       64.458012    3600.913793
# 543            9.395024e+06  24986.765157        0.247678   50008.920000
# 1098           1.895845e+06   3957.922913       28.798778    6124.490887
# 1616           1.529605e+06  18428.978846       74.350530    1360.239278
# 1045           2.175792e+07   2737.878431       41.379542    7560.702040
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1497             16.0              0.0            0.0            0.0
# 543               6.0             14.0           14.0            7.0
# 1098              3.0              2.0            5.0           36.0
# 1616              4.0              2.0            2.0            0.0
# 1045             10.0             20.0            8.0            1.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1497            0.0             0.0            2.0               1.0
# 543             0.0            17.0            4.0               0.0
# 1098            0.0            17.0            1.0               1.0
# 1616            0.0            13.0           13.0               0.0
# 1045            0.0            13.0            4.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1497                0.0            12.0              0.0            0.0
# 543                 0.0             0.0              1.0            0.0
# 1098                0.0             0.0              0.0            0.0
# 1616                0.0             2.0              0.0            0.0
# 1045                0.0             0.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1497             5.0            11.0           0.0             0.0
# 543              0.0             8.0           2.0             0.0
# 1098             0.0             1.0           2.0             0.0
# 1616             0.0             4.0           2.0             0.0
# 1045             0.0             3.0           1.0             1.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1497            13.0               0.0            0.0             0.0
# 543              0.0               0.0            4.0             0.0
# 1098             0.0               0.0           11.0             1.0
# 1616            28.0               1.0            8.0             0.0
# 1045             7.0               1.0            3.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1497           0.0             0.0             1.0            0.0
# 543            1.0             4.0             3.0            3.0
# 1098           0.0             0.0             2.0            1.0
# 1616           0.0             0.0             8.0            3.0
# 1045           0.0             0.0             4.0           10.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1497             0.0           13.0            2.0             17.0
# 543              1.0            3.0            2.0              1.0
# 1098             4.0           10.0            0.0              0.0
# 1616             1.0            5.0            0.0              3.0
# 1045             3.0            1.0            1.0              0.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  \
# 1497            21.0            0.0              0.0      112.0  29.10  23.5
# 543              3.0            4.0              0.0        9.0  20.15  20.6
# 1098             4.0            0.0              0.0     2831.0  14.55   9.7
# 1616             2.0            0.0              0.0        7.0  25.10  22.0
# 1045            14.0            3.0              0.0      761.0   8.55  16.8
#
#        tmax        prcp  land_cost_year  price_income_ratio  \
# 1497  34.80    9.166667          2020.0                13.0
# 543   26.90  197.500000          2020.0                23.0
# 1098  19.50   91.666667          2016.0                11.0
# 1616  28.40   42.916667          2020.0                31.0
# 1045  21.45  121.250000          2013.0                13.0
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1497                 193.0                  0.0     0.0           6.0
# 543                  142.0                  0.0     1.0           1.0
# 1098                 138.0                  0.0     1.0           6.0
# 1616                 649.0                  0.0     1.0           1.0
# 1045                 157.0                  0.0     1.0           4.0
#
#       price_rent_ratio  union_density  stations_per_km  leverage    residuals  \
# 1497              16.0      23.800000         0.148649  0.522255  3831.047469
# 543               72.0      39.355000         0.812500  0.323428  5540.257736
# 1098              14.0       9.000000         0.655022  0.786102  -667.404122
# 1616              53.0      11.405556         0.315789  0.742749  -699.051921
# 1045              20.0      16.784444         1.016949  0.466612 -1803.854443
#
#       standardized_residuals  cooks_distance
# 1497                4.597064        0.751040
# 543                 6.678389        0.485009
# 1098               -0.880755        0.171151
# 1616               -0.919293        0.122656
# 1045               -2.264624        0.119347

# %%
df_adj.loc[[1190]]
# Out:
#      country       city  start_year  end_year  rr?    length  tunnel_per  \
# 1190      SG  Singapore        1996      1999  0.0  7.572402         0.0
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1190     0.0  7.572402       0.0      13.0       50.0       2642.0          0
#
#        cost currency  year  ppp_rate   cost_real    cost_km  c_length  \
# 1190  285.0      SGD  1998  1.028015  292.984411  38.691078       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1190       0.0      1         1.674515      490.606772     64.788789
#
#      train_type  duration  country_pop_den region          sub_region  \
# 1190        MRT         3       5861.51194   Asia  South-eastern Asia
#
#       area_km  lat    lng  population  time_diff  calculated_population  \
# 1190    523.0  1.3  103.8   5983000.0         22           5.154285e+06
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1190   9855.229965        1.944834          780.0      Cambisols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1190              6.0             17.0           14.0            2.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1190            0.0            17.0            2.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1190                0.0             0.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1190             0.0             8.0           1.0             1.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1190             3.0               8.0            0.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1190           3.0            16.0             1.0            3.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1190             1.0            0.0            0.0              0.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  \
# 1190             0.0            2.0              0.0       14.0  28.25  25.0
#
#       tmax    prcp  land_cost_year  price_income_ratio  mortgage_perc_income  \
# 1190  31.6  176.25            1998                  19                   123
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 1190                    0       1             4                13
#
#       union_density  stations_per_km
# 1190      16.007242          1.71676

# %% [markdown]
# This is the Singapore Bukit Panjang LRT. The data are correct.[keep]

# %%
df_adj.loc[[1193]]
# Out:
#      country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1193      AE  Dubai        2016      2020  0.0    15.0    0.213333     3.2
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1193      10.8       1.0       7.0       95.0       1435.0          0
#
#          cost currency  year  ppp_rate    cost_real     cost_km  c_length  \
# 1193  10643.0      AED  2018  0.427016  4544.734394  302.982293       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1193       0.0      0         1.086971     4939.992809    329.332854
#
#      train_type  duration  country_pop_den region    sub_region  area_km  \
# 1193        MRT         4       128.698522   Asia  Western Asia    712.0
#
#           lat      lng  population  time_diff  calculated_population  \
# 1193  25.2631  55.2972   3331420.0          2           3.236232e+06
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1193   4545.269923       43.486984    34495.76527     Solonchaks
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1193             25.0              1.0            0.0            0.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1193            0.0             2.0            1.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1193                0.0             5.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1193             0.0            11.0           0.0             0.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1193             5.0               0.0            0.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1193           0.0             0.0             0.0            0.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1193             0.0           27.0            0.0             43.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  \
# 1193             3.0            0.0              0.0       10.0  28.75  23.7
#
#       tmax      prcp  land_cost_year  price_income_ratio  \
# 1193  33.9  7.916667            2018                   4
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1193                    35                    2       1            10
#
#       price_rent_ratio  union_density  stations_per_km
# 1193                 9            0.0         0.466667

# %% [markdown]
# This is the Dubai Red Line Phase 3. The data are correct.[keep]

# %%
df_adj.loc[[1461]]
# Out:
#      country     city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1461      NG  Calabar        2005      2016  0.0    12.9         0.0     0.0
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1461      12.9       0.0       3.0       70.0          0.0          0
#
#          cost currency  year  ppp_rate   cost_real   cost_km  c_length  \
# 1461  45000.0      NGN  2011  0.012694  571.210967  44.27992       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1461       0.0      0         1.213422      693.119961      53.73023
#
#      train_type  duration  country_pop_den  region          sub_region  \
# 1461   Monorail        11       181.674567  Africa  Sub-Saharan Africa
#
#       area_km     lat     lng  population  time_diff  calculated_population  \
# 1461    406.0  4.9767  8.3383    461796.0          9          319717.338755
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1461     787.48113       90.812825    2403.645256      Cambisols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1461              6.0             13.0           17.0           12.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1461            0.0            20.0            2.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1461                0.0             0.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1461             0.0            10.0           0.0             1.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1461             1.0               3.0            2.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1461           0.0             1.0             0.0            8.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1461             1.0            2.0            0.0              0.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation   tavg  tmin  \
# 1461             1.0            3.0              0.0       50.0  26.75  20.1
#
#       tmax       prcp  land_cost_year  price_income_ratio  \
# 1461  33.5  72.083333            2011                  15
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1461                   299                    0       0             9
#
#       price_rent_ratio  union_density  stations_per_km
# 1461                10            0.0         0.232558

# %% [markdown]
# This is the Calabar Monorail. The data are correct.[keep]

# %%
df_adj.loc[[1497]]
# Out:
#      country                  city  start_year  end_year  rr?  length  \
# 1497      EG  10th of Ramadan City        2018      2021  0.0    74.0
#
#       tunnel_per  tunnel  elevated  at_grade  stations  max_speed  \
# 1497         0.0     0.0       0.0      74.0      11.0      120.0
#
#       track_gauge  overhead?     cost currency  year  ppp_rate    cost_real  \
# 1497       1435.0          1  36269.0      EGP  2020  0.221148  8020.883008
#
#          cost_km  c_length  c_tunnel  anglo  inflation_index  cost_real_2023  \
# 1497  108.390311       0.0       0.0      0         1.054615     8458.942644
#
#       cost_km_2023  train_type  duration  country_pop_den  region  \
# 1497    114.310036  Light Rail         3       107.956335  Africa
#
#            sub_region  area_km      lat     lng  population  time_diff  \
# 1497  Northern Africa    250.0  30.2917  31.742    246148.0          0
#
#       calculated_population  city_density  per_below_line  reporting_gdp  \
# 1497               246148.0       984.592       64.458012    3600.913793
#
#      wrb_class_name  wrb_class_value  prob_Ferralsols  prob_Acrisols  \
# 1497      Leptosols             16.0              0.0            0.0
#
#       prob_Andosols  prob_Cryosols  prob_Cambisols  prob_Gleysols  \
# 1497            0.0            0.0             0.0            2.0
#
#       prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  prob_Chernozems  \
# 1497               1.0                0.0            12.0              0.0
#
#       prob_Durisols  prob_Gypsisols  prob_Fluvisols  prob_Alisols  \
# 1497            0.0             5.0            11.0           0.0
#
#       prob_Planosols  prob_Arenosols  prob_Plinthosols  prob_Luvisols  \
# 1497             0.0            13.0               0.0            0.0
#
#       prob_Umbrisols  prob_Podzols  prob_Histosols  prob_Vertisols  \
# 1497             0.0           0.0             0.0             1.0
#
#       prob_Lixisols  prob_Phaeozems  prob_Regosols  prob_Solonetz  \
# 1497            0.0             0.0           13.0            2.0
#
#       prob_Solonchaks  prob_Leptosols  prob_Nitisols  prob_Stagnosols  \
# 1497             17.0            21.0            0.0              0.0
#
#       elevation  tavg  tmin  tmax      prcp  land_cost_year  \
# 1497      112.0  29.1  23.5  34.8  9.166667            2020
#
#       price_income_ratio  mortgage_perc_income  affordability_index  urban?  \
# 1497                  13                   193                    0       0
#
#       rental_yield  price_rent_ratio  union_density  stations_per_km
# 1497             6                16           23.8         0.148649

# %% [markdown]
# This is the 10th of Ramadan City LRT. This is a signficant outlier.[remove]

# %%
cooks_drop.append(1497)

# %%
df_adj.loc[[1616]]
# Out:
#      country   city  start_year  end_year  rr?  length  tunnel_per  tunnel  \
# 1616      SN  Dakar        2019      2024  0.0    19.0         0.0     0.0
#
#       elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1616       0.0      19.0       6.0      160.0       1435.0          1
#
#           cost currency  year  ppp_rate    cost_real    cost_km  c_length  \
# 1616  328872.0     CFAF  2022  0.004183  1375.747208  72.407748       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1616       0.0      0         1.015482     1397.047101     73.528795
#
#          train_type  duration  country_pop_den  region          sub_region  \
# 1616  Regional Rail         5        85.369137  Africa  Sub-Saharan Africa
#
#       area_km      lat      lng  population  time_diff  calculated_population  \
# 1616     83.0  14.6928 -17.4467   1438725.0         -2           1.529605e+06
#
#       city_density  per_below_line  reporting_gdp wrb_class_name  \
# 1616  18428.978846        74.35053    1360.239278      Arenosols
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 1616              4.0              2.0            2.0            0.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 1616            0.0            13.0           13.0               0.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 1616                0.0             2.0              0.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 1616             0.0             4.0           2.0             0.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 1616            28.0               1.0            8.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 1616           0.0             0.0             8.0            3.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 1616             1.0            5.0            0.0              3.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation  tavg  tmin  \
# 1616             2.0            0.0              0.0        7.0  25.1  22.0
#
#       tmax       prcp  land_cost_year  price_income_ratio  \
# 1616  28.4  42.916667            2020                  31
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1616                   649                    0       1             1
#
#       price_rent_ratio  union_density  stations_per_km
# 1616                53      11.405556         0.315789

# %% [markdown]
# This is the Dakar Regional Express Train (TER) Phase I. This is a signficant outlier.[remove]

# %%
cooks_drop.append(1616)

# %%
df_adj.loc[[1632]]
# Out:
#      country        city  start_year  end_year  rr?  length  tunnel_per  \
# 1632      CL  Valparaiso        2002      2005  0.0    43.0        0.12
#
#       tunnel  elevated  at_grade  stations  max_speed  track_gauge  overhead?  \
# 1632    5.16       0.0     37.84      20.0      120.0       1676.0          1
#
#           cost currency  year  ppp_rate   cost_real    cost_km  c_length  \
# 1632  195390.0      CHP  2004  0.003113  608.165287  14.143379       0.0
#
#       c_tunnel  anglo  inflation_index  cost_real_2023  cost_km_2023  \
# 1632       0.0      0         1.444923      878.751945     20.436092
#
#       train_type  duration  country_pop_den    region  \
# 1632  Light Rail         3        21.543075  Americas
#
#                            sub_region  area_km      lat      lng  population  \
# 1632  Latin America and the Caribbean    401.6 -33.0461 -71.6197    296655.0
#
#       time_diff  calculated_population  city_density  per_below_line  \
# 1632         16          260731.700247    649.232321       41.366704
#
#       reporting_gdp wrb_class_name  wrb_class_value  prob_Ferralsols  \
# 1632    7770.539111      Arenosols              4.0              0.0
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 1632            1.0            0.0            0.0            13.0
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 1632            1.0               0.0                0.0             6.0
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 1632              0.0            0.0             0.0            12.0
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 1632           0.0             3.0            15.0               1.0
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 1632            6.0             0.0           0.0             0.0
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 1632             6.0            2.0             3.0           12.0
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 1632            1.0              4.0            10.0            0.0
#
#       prob_Stagnosols  elevation   tavg  tmin  tmax       prcp  \
# 1632              0.0        8.0  13.35   8.2  18.5  90.833333
#
#       land_cost_year  price_income_ratio  mortgage_perc_income  \
# 1632            2004                   7                    40
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 1632                    2       0             8                10
#
#       union_density  stations_per_km
# 1632      15.323333         0.465116

# %% [markdown]
# This is the Valparaiso Tren Limache - Puetro (Valparaiso Metro). This is a signficant outlier.[remove]

# %%
cooks_drop.append(1632)

# %%
df_adj['region'].drop_duplicates()
# Out:
# 1          Asia
# 17       Europe
# 221      Africa
# 361    Americas
# 798     Oceania
# Name: region, dtype: object

# %% [markdown]
# ### Drop Cooks Outliers

# %%
valid_indices_seen = [index for index in cooks_drop if index in data.index]
valid_indices_unseen = [index for index in cooks_drop if index in data_unseen.index]

# %%
data.drop(index=valid_indices_seen,inplace = True)

# %%
data_unseen.drop(index = valid_indices_unseen,inplace = True)

# %%
data
# Out:
#       rr?     length  tunnel_per  tunnel   elevated   at_grade  stations  \
# 47    0.0  16.500000    1.000000   16.50   0.000000   0.000000      13.0
# 98    0.0  16.900000    1.000000   16.90   0.000000   0.000000      15.0
# 1289  0.0  14.377958    0.000000    0.00   0.000000  14.377958      15.0
# 1023  0.0  55.070000    1.000000   55.07   0.000000   0.000000      43.0
# 825   0.0  14.940000    0.087015    1.30  13.640000   0.000000      11.0
# ...   ...        ...         ...     ...        ...        ...       ...
# 509   0.0   4.300000    1.000000    4.30   0.000000   0.000000       5.0
# 1495  0.0   7.723243    0.000000    0.00   0.000000   7.723243      27.0
# 1259  0.0   4.200000    0.000000    0.00   1.691144   2.494856       2.0
# 1197  0.0  39.600000    0.411616   16.30  23.300000   0.000000      25.0
# 338   NaN  27.800000         NaN     NaN        NaN        NaN       NaN
#
#       max_speed  track_gauge  overhead?    year  anglo  cost_real_2023  \
# 47        100.0       1435.0        0.0  2010.0    0.0     4850.671393
# 98         80.0       1435.0        0.0  2009.0    0.0     5133.825405
# 1289       70.0       1435.0        1.0  2013.0    1.0      674.095003
# 1023       80.0       1435.0        1.0  2008.0    0.0     9844.449153
# 825        80.0       1435.0        1.0  2019.0    0.0     1403.682194
# ...         ...          ...        ...     ...    ...             ...
# 509        80.0       1435.0        0.0  2010.0    0.0     1443.219682
# 1495       60.0       1435.0        1.0  2017.0    1.0      108.011405
# 1259       60.0       1435.0        1.0  2015.0    1.0      224.559661
# 1197       80.0       1435.0        1.0  2018.0    0.0     6934.941734
# 338         NaN          NaN        NaN     NaN    NaN    13642.224729
#
#       train_type  duration  country_pop_den    region        sub_region  \
# 47           MRT       5.0       141.936072      Asia      Eastern Asia
# 98           MRT      14.0        92.975065    Europe   Southern Europe
# 1289  Light Rail       3.0       265.069537    Europe   Northern Europe
# 1023         MRT       5.0       140.551423      Asia      Eastern Asia
# 825          MRT       4.0       149.367573      Asia      Eastern Asia
# ...          ...       ...              ...       ...               ...
# 509         Tram      22.0       200.452516    Europe   Southern Europe
# 1495   Streetcar       3.0        35.542495  Americas  Northern America
# 1259  Light Rail       2.0        35.063329  Americas  Northern America
# 1197         MRT      14.0       460.449317      Asia     Southern Asia
# 338          NaN       NaN              NaN       NaN               NaN
#
#       area_km  population  calculated_population  city_density  \
# 47    12796.5  22366547.0           1.829448e+07   1429.647188
# 98     1072.0   4800000.0           4.538781e+06   4233.937562
# 1289    115.6   2705000.0           2.568938e+06  22222.648127
# 1023   3658.2   7964000.0           6.257439e+06   1710.523977
# 825    1172.9   3842100.0           3.748390e+06   3195.831055
# ...       ...         ...                    ...           ...
# 509     583.0    966144.0           9.700171e+05   1663.837207
# 1495    568.0    794344.0           7.680130e+05   1352.135646
# 1259    385.9   5668165.0           5.446780e+06  14114.485273
# 1197    250.0   1684222.0           1.618822e+06   6475.286428
# 338       NaN         NaN                    NaN           NaN
#
#       per_below_line  reporting_gdp  wrb_class_value  prob_Ferralsols  \
# 47         69.489729    4711.635127             18.0              0.0
# 98          2.616275   26751.881410             16.0              1.0
# 1289        0.955233   43927.886020              6.0              0.0
# 1023       69.489729    4711.635127             20.0              0.0
# 825        37.855836    8016.431435             11.0              0.0
# ...              ...            ...              ...              ...
# 509         1.611045   33738.129160              6.0              0.0
# 1495        2.248539   56863.371500              5.0              0.0
# 1259        2.248539   56863.371500             18.0              0.0
# 1197       88.900103    1580.059460             11.0              2.0
# 338              NaN            NaN              NaN              NaN
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 47              1.0            0.0            0.0            22.0
# 98              0.0            0.0            0.0            12.0
# 1289            1.0            2.0            0.0            25.0
# 1023            0.0            0.0            0.0             7.0
# 825             6.0            1.0            0.0            13.0
# ...             ...            ...            ...             ...
# 509             2.0            0.0            0.0            23.0
# 1495            0.0            0.0            0.0            10.0
# 1259            3.0            0.0            0.0            12.0
# 1197           15.0            0.0            0.0            10.0
# 338             NaN            NaN            NaN             NaN
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 47              5.0               4.0                0.0             4.0
# 98              0.0               4.0                0.0            12.0
# 1289            9.0               2.0                1.0             3.0
# 1023            6.0               7.0                0.0             1.0
# 825            23.0               0.0                0.0             1.0
# ...             ...               ...                ...             ...
# 509             5.0               3.0                0.0             7.0
# 1495            0.0               0.0                0.0            35.0
# 1259            1.0              10.0                0.0             2.0
# 1197            7.0               0.0                0.0             0.0
# 338             NaN               NaN                NaN             NaN
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 47                3.0            0.0             0.0            15.0
# 98                1.0            0.0             1.0             6.0
# 1289              0.0            0.0             0.0             8.0
# 1023              6.0            0.0             1.0             4.0
# 825               0.0            0.0             0.0            23.0
# ...               ...            ...             ...             ...
# 509               0.0            0.0             0.0             5.0
# 1495              0.0            0.0             6.0             7.0
# 1259              1.0            0.0             0.0             4.0
# 1197              0.0            0.0             0.0            18.0
# 338               NaN            NaN             NaN             NaN
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 47             0.0             0.0             2.0               0.0
# 98             2.0             0.0             3.0               0.0
# 1289           1.0             1.0             1.0               0.0
# 1023           0.0             1.0             3.0               0.0
# 825            6.0             7.0             1.0               0.0
# ...            ...             ...             ...               ...
# 509            1.0             2.0             0.0               0.0
# 1495           0.0             0.0             8.0               0.0
# 1259           2.0             2.0             0.0               0.0
# 1197           2.0             0.0             5.0               1.0
# 338            NaN             NaN             NaN               NaN
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 47             25.0             0.0           0.0             0.0
# 98             11.0             0.0           0.0             1.0
# 1289           19.0             1.0           9.0             0.0
# 1023           17.0             0.0           2.0             0.0
# 825             4.0             0.0           0.0             0.0
# ...             ...             ...           ...             ...
# 509            16.0             1.0           0.0             1.0
# 1495            3.0             0.0           0.0             0.0
# 1259           36.0             0.0           0.0             0.0
# 1197           11.0             1.0           0.0             0.0
# 338             NaN             NaN           NaN             NaN
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 47               2.0            0.0             3.0            2.0
# 98              11.0            1.0             6.0            9.0
# 1289             2.0            0.0             2.0            2.0
# 1023             1.0            0.0            25.0            6.0
# 825              1.0            4.0             0.0            1.0
# ...              ...            ...             ...            ...
# 509              6.0            1.0             4.0            9.0
# 1495             5.0            0.0             0.0           10.0
# 1259            11.0            1.0             3.0            6.0
# 1197             8.0            2.0             4.0            2.0
# 338              NaN            NaN             NaN            NaN
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 47              3.0              2.0             5.0            0.0
# 98              1.0              2.0            15.0            1.0
# 1289            1.0              0.0             6.0            0.0
# 1023            5.0              6.0             1.0            0.0
# 825             1.0              3.0             0.0            1.0
# ...             ...              ...             ...            ...
# 509             0.0              2.0            11.0            1.0
# 1495            4.0              7.0             3.0            0.0
# 1259            4.0              0.0             0.0            0.0
# 1197            0.0              3.0             4.0            1.0
# 338             NaN              NaN             NaN            NaN
#
#       prob_Stagnosols  elevation       tavg       tmin       tmax        prcp  \
# 47                0.0       50.0  12.083333   6.491667  17.666667   48.166667
# 98                0.0       30.0  16.700000  12.700000  20.800000   78.750000
# 1289              1.0       51.0  10.600000   7.500000  13.700000   69.583333
# 1023              0.0       42.0   8.650000   3.300000  14.100000   58.333333
# 825               0.0       26.0  15.766667  11.308333  20.200000   85.083333
# ...               ...        ...        ...        ...        ...         ...
# 509               0.0       29.0  16.950000  12.200000  21.700000   84.000000
# 1495              0.0     1186.0  21.150000  15.400000  27.000000    8.750000
# 1259              0.0      150.0  19.041667  13.400000  24.666667   76.408333
# 1197              0.0       66.0  25.650000  20.000000  31.400000  119.583333
# 338               NaN        NaN        NaN        NaN        NaN         NaN
#
#       land_cost_year  price_income_ratio  mortgage_perc_income  \
# 47            2010.0                17.0                 131.0
# 98            2009.0                12.0                  91.0
# 1289          2013.0                 6.0                  51.0
# 1023          2008.0                22.0                 184.0
# 825           2019.0                29.0                 231.0
# ...              ...                 ...                   ...
# 509           2010.0                14.0                 119.0
# 1495          2017.0                 3.0                  23.0
# 1259          2015.0                 2.0                  19.0
# 1197          2018.0                 9.0                 112.0
# 338              NaN                 NaN                   NaN
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 47                    0.0     0.0           5.0              20.0
# 98                    1.0     1.0           2.0              33.0
# 1289                  2.0     1.0           5.0              17.0
# 1023                  0.0     0.0           4.0              13.0
# 825                   0.0     1.0           1.0              54.0
# ...                   ...     ...           ...               ...
# 509                   0.0     0.0           4.0              23.0
# 1495                  4.0     0.0          12.0               8.0
# 1259                  5.0     1.0          11.0               9.0
# 1197                  0.0     1.0           3.0              32.0
# 338                   NaN     NaN           NaN               NaN
#
#       union_density  stations_per_km  leverage   residuals  \
# 47        16.312870         0.787879  0.031909  530.515843
# 98        23.628823         0.887574  0.029437  843.335886
# 1289      28.591909         1.043264  0.036754  -62.266276
# 1023      16.312870         0.780824  0.056987  706.929703
# 825       16.312870         0.736278  0.045511  -93.263178
# ...             ...              ...       ...         ...
# 509       38.052545         1.162791  0.069602  147.281005
# 1495      11.802000         3.495941  0.107962 -182.956106
# 1259      11.802000         0.476190  0.026019  -52.001162
# 1197      12.133509         0.631313  0.070748  374.101450
# 338             NaN              NaN       NaN         NaN
#
#       standardized_residuals  cooks_distance  cost_km_2023
# 47                  1.543769        0.001367           NaN
# 98                  2.507496        0.003170           NaN
# 1289               -0.282456        0.000022           NaN
# 1023                2.087260        0.004568           NaN
# 825                -0.377950        0.000062           NaN
# ...                      ...             ...           ...
# 509                 0.363111        0.000249           NaN
# 1495               -0.654273        0.000648           NaN
# 1259               -0.250831        0.000011           NaN
# 1197                1.061893        0.001636           NaN
# 338                      NaN             NaN    490.727508
#
# [1124 rows x 74 columns]

# %%
data.sort_values(by='standardized_residuals',ascending = False)
# Out:
#       rr?     length  tunnel_per  tunnel  elevated   at_grade  stations  \
# 1517  0.0  18.500000    0.000000    0.00       0.0  18.500000      18.0
# 1166  0.0  35.500000    1.000000   35.50       0.0   0.000000      30.0
# 1254  0.0  40.877868    0.000000    0.00       0.0  40.877868      31.0
# 1237  0.0  37.600000    0.053191    2.00      35.6   0.000000      26.0
# 97    0.0  47.800000    0.914226   43.70       4.1   0.000000      52.0
# ...   ...        ...         ...     ...       ...        ...       ...
# 653   0.0  39.000000    0.160256    6.25       0.0  32.750000      38.0
# 1480  0.0  22.500000    0.568889   12.80       0.0   9.700000      16.0
# 988   1.0  28.600000    0.000000    0.00      28.6   0.000000      20.0
# 1168  0.0  43.000000    1.000000   43.00       0.0   0.000000      32.0
# 338   NaN  27.800000         NaN     NaN       NaN        NaN       NaN
#
#       max_speed  track_gauge  overhead?    year  anglo  cost_real_2023  \
# 1517       70.0       1435.0        1.0  1998.0    0.0     9807.819347
# 1166       80.0       1435.0        0.0  2007.0    1.0    10209.891254
# 1254      100.0       1435.0        1.0  2027.0    1.0     8011.419793
# 1237      100.0       1435.0        0.0  2021.0    0.0    10574.870410
# 97         80.0       1445.0        1.0  2015.0    0.0    10314.641780
# ...         ...          ...        ...     ...    ...             ...
# 653        80.0       1435.0        0.0  2006.0    0.0     1366.989416
# 1480       60.0       1435.0        1.0  2018.0    0.0     1010.458389
# 988        65.0       1435.0        1.0  2021.0    0.0     2480.520980
# 1168       80.0       1435.0        0.0  2019.0    1.0     1916.399766
# 338         NaN          NaN        NaN     NaN    NaN    13642.224729
#
#       train_type  duration  country_pop_den    region          sub_region  \
# 1517        Tram       3.0        80.872892      Asia        Western Asia
# 1166         MRT      10.0      6602.300719      Asia  South-eastern Asia
# 1254  Light Rail       6.0        36.240985  Americas    Northern America
# 1237  Light Rail       8.0       101.050047      Asia  South-eastern Asia
# 97           MRT      23.0        92.952686    Europe     Southern Europe
# ...          ...       ...              ...       ...                 ...
# 653   Light Rail      17.0        90.434797      Asia        Western Asia
# 1480        Tram       4.0       240.794778      Asia        Western Asia
# 988   Light Rail       6.0      1882.126115      Asia        Western Asia
# 1168         MRT      10.0      7965.878492      Asia  South-eastern Asia
# 338          NaN       NaN              NaN       NaN                 NaN
#
#       area_km  population  calculated_population  city_density  \
# 1517   1055.0   2232374.0           1.514234e+06   1435.293349
# 1166    523.0   5983000.0           5.478445e+06  10475.038421
# 1254   1126.0   1516107.0           1.552560e+06   1378.828143
# 1237   2163.0   8911000.0           9.124864e+06   4218.614887
# 97     1072.0   4800000.0           4.679451e+06   4365.159198
# ...       ...         ...                    ...           ...
# 653    1290.0   1999998.0           1.614765e+06   1251.755834
# 1480     38.0    198600.0           1.836169e+05   4832.022734
# 988     760.0   1487202.0           1.499843e+06   1973.477917
# 1168    523.0   5983000.0           5.942590e+06  11362.505517
# 338       NaN         NaN                    NaN           NaN
#
#       per_below_line  reporting_gdp  wrb_class_value  prob_Ferralsols  \
# 1517       38.833735    6373.131907              5.0              0.0
# 1166        1.528690     950.000000              6.0             17.0
# 1254        2.157590   65536.734290             18.0              0.0
# 1237        4.818305    9955.242722              0.0             12.0
# 97          3.466943   25732.018360             16.0              1.0
# ...              ...            ...              ...              ...
# 653        25.943063    8173.536251              6.0              1.0
# 1480       43.486984    1500.000000             25.0              0.0
# 988        43.486984   26562.970000             24.0              0.0
# 1168        1.709393   82807.600000              6.0             17.0
# 338              NaN            NaN              NaN              NaN
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 1517            0.0            2.0            0.0            15.0
# 1166           14.0            2.0            0.0            17.0
# 1254           31.0            0.0            0.0             5.0
# 1237           51.0            2.0            0.0            10.0
# 97              0.0            0.0            0.0            12.0
# ...             ...            ...            ...             ...
# 653             7.0            0.0            0.0            30.0
# 1480            0.0            0.0            0.0             0.0
# 988             0.0            0.0            0.0             1.0
# 1168           14.0            2.0            0.0            17.0
# 338             NaN            NaN            NaN             NaN
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 1517            1.0               9.0                0.0            19.0
# 1166            2.0               0.0                0.0             0.0
# 1254            0.0               2.0                0.0             0.0
# 1237            1.0               0.0                0.0             0.0
# 97              0.0               4.0                0.0            12.0
# ...             ...               ...                ...             ...
# 653             0.0               4.0                0.0             6.0
# 1480            0.0               0.0                0.0             0.0
# 988             1.0               0.0                0.0             1.0
# 1168            2.0               0.0                0.0             0.0
# 338             NaN               NaN                NaN             NaN
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 1517              0.0            0.0             2.0             6.0
# 1166              0.0            0.0             0.0             8.0
# 1254              0.0            0.0             0.0             1.0
# 1237              0.0            0.0             0.0             2.0
# 97                1.0            0.0             1.0             6.0
# ...               ...            ...             ...             ...
# 653               2.0            0.0             0.0             5.0
# 1480              0.0            0.0             0.0             5.0
# 988               0.0            0.0             0.0             7.0
# 1168              0.0            0.0             0.0             8.0
# 338               NaN            NaN             NaN             NaN
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 1517           0.0             0.0             1.0               0.0
# 1166           1.0             1.0             3.0               8.0
# 1254           5.0             1.0             0.0               0.0
# 1237           1.0             1.0             5.0               2.0
# 97             2.0             0.0             3.0               0.0
# ...            ...             ...             ...               ...
# 653            1.0             0.0             0.0               0.0
# 1480           0.0             0.0             3.0               0.0
# 988            0.0             0.0            11.0               0.0
# 1168           1.0             1.0             3.0               8.0
# 338            NaN             NaN             NaN               NaN
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 1517           16.0             0.0           1.0             0.0
# 1166            0.0             0.0           3.0            16.0
# 1254           41.0             0.0           2.0             1.0
# 1237            1.0             0.0           2.0             3.0
# 97             11.0             0.0           0.0             1.0
# ...             ...             ...           ...             ...
# 653            20.0             0.0           0.0             0.0
# 1480            0.0             0.0           0.0             0.0
# 988             0.0             0.0           0.0             0.0
# 1168            0.0             0.0           3.0            16.0
# 338             NaN             NaN           NaN             NaN
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 1517             1.0            0.0             1.0           16.0
# 1166             1.0            3.0             1.0            0.0
# 1254             3.0            3.0             1.0            3.0
# 1237             1.0            1.0             1.0            0.0
# 97              11.0            1.0             6.0            9.0
# ...              ...            ...             ...            ...
# 653              1.0            0.0             7.0            7.0
# 1480             0.0            0.0             0.0           28.0
# 988              1.0            0.0             0.0           31.0
# 1168             1.0            3.0             1.0            0.0
# 338              NaN            NaN             NaN            NaN
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 1517            1.0              3.0             6.0            0.0
# 1166            0.0              0.0             0.0            2.0
# 1254            0.0              0.0             0.0            0.0
# 1237            0.0              0.0             0.0            2.0
# 97              1.0              2.0            15.0            1.0
# ...             ...              ...             ...            ...
# 653             0.0              0.0             7.0            0.0
# 1480            0.0             53.0             4.0            0.0
# 988             2.0             27.0            15.0            0.0
# 1168            0.0              0.0             0.0            2.0
# 338             NaN              NaN             NaN            NaN
#
#       prob_Stagnosols  elevation       tavg       tmin       tmax        prcp  \
# 1517              0.0     1025.0  11.608333   5.425000  17.825000   27.750000
# 1166              0.0       14.0  28.250000  25.000000  31.600000  176.250000
# 1254              0.0      209.0  15.558333   9.783333  21.300000   90.416667
# 1237              0.0       35.0  28.450000  24.100000  32.900000  202.083333
# 97                0.0       30.0  16.700000  12.700000  20.800000   78.750000
# ...               ...        ...        ...        ...        ...         ...
# 653               0.0      257.0  14.408333   8.725000  20.108333   56.916667
# 1480              0.0        0.0  28.600000  14.700000  25.100000    6.250000
# 988               0.0       55.0  29.100000  23.500000  34.800000    9.166667
# 1168              0.0       14.0  28.250000  25.000000  31.600000  176.250000
# 338               NaN        NaN        NaN        NaN        NaN         NaN
#
#       land_cost_year  price_income_ratio  mortgage_perc_income  \
# 1517          1998.0                 0.0                  53.0
# 1166          2007.0                19.0                 124.0
# 1254          2020.0                 3.0                  26.0
# 1237          2020.0                 9.0                  75.0
# 97            2015.0                 9.0                  66.0
# ...              ...                 ...                   ...
# 653           2006.0                 3.0                  68.0
# 1480          2018.0                 5.0                  44.0
# 988           2020.0                 8.0                  77.0
# 1168          2019.0                21.0                 133.0
# 338              NaN                 NaN                   NaN
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 1517                  2.0     0.0           8.0               9.0
# 1166                  0.0     1.0           3.0              23.0
# 1254                  3.0     0.0          11.0               8.0
# 1237                  1.0     1.0           3.0              27.0
# 97                    1.0     1.0           3.0              25.0
# ...                   ...     ...           ...               ...
# 653                   1.0     0.0           7.0              12.0
# 1480                  2.0     1.0           6.0              15.0
# 988                   1.0     0.0           7.0              12.0
# 1168                  0.0     1.0           2.0              42.0
# 338                   NaN     NaN           NaN               NaN
#
#       union_density  stations_per_km  leverage    residuals  \
# 1517       5.337857         0.972973  0.053227  3329.237888
# 1166      16.007242         0.845070  0.074154  1908.950444
# 1254      11.802000         0.758357  0.071165  1689.371682
# 1237       9.168442         0.691489  0.109162  1561.831756
# 97        23.628823         1.087866  0.067545  1535.287216
# ...             ...              ...       ...          ...
# 653        5.337857         0.974359  0.055791  -854.813309
# 1480       0.000000         0.711111  0.304446  -975.656651
# 988        0.000000         0.699301  0.105298 -1077.868572
# 1168      16.007242         0.744186  0.105572 -2084.030378
# 338             NaN              NaN       NaN          NaN
#
#       standardized_residuals  cooks_distance  cost_km_2023
# 1517               10.165987        0.093875           NaN
# 1166                5.790409        0.044964           NaN
# 1254                5.113937        0.033579           NaN
# 1237                4.721016        0.047859           NaN
# 97                  4.639239        0.026118           NaN
# ...                      ...             ...           ...
# 653                -2.724110        0.006522           NaN
# 1480               -3.096401        0.085441           NaN
# 988                -3.411292        0.021798           NaN
# 1168               -6.511045        0.081750           NaN
# 338                      NaN             NaN    490.727508
#
# [1124 rows x 74 columns]

# %%
data_unseen.sort_values(by='standardized_residuals',ascending = False)
# Out:
#       rr?  length  tunnel_per  tunnel  elevated  at_grade  stations  \
# 1158  0.0  19.700    0.131980   2.600    17.100       0.0      14.0
# 1105  0.0   9.700    0.731959   7.100     0.000       2.6       8.0
# 952   0.0  23.630    0.000000   0.000    23.630       0.0      17.0
# 1193  0.0  15.000    0.213333   3.200    10.800       1.0       7.0
# 1160  0.0  36.000    0.419444  15.100    15.900       5.0      13.0
# ...   ...     ...         ...     ...       ...       ...       ...
# 961   0.0  28.400    0.000000   0.000    28.400       0.0       8.0
# 309   0.0  21.700    1.000000  21.700     0.000       0.0      16.0
# 664   0.0  37.353    0.278050  10.386    26.967       0.0       9.0
# 965   NaN  29.700         NaN     NaN       NaN       NaN       NaN
# 984   NaN  31.000         NaN     NaN       NaN       NaN       NaN
#
#       max_speed  track_gauge  overhead?    year  anglo  cost_real_2023  \
# 1158       80.0       1435.0        1.0  2017.0    0.0     6564.872870
# 1105       60.0       1435.0        0.0  2011.0    0.0     4499.181569
# 952       100.0       1435.0        0.0  2025.0    0.0     6790.682166
# 1193       95.0       1435.0        0.0  2018.0    0.0     4939.992809
# 1160      100.0       1067.0        1.0  2016.0    1.0     6116.917169
# ...         ...          ...        ...     ...    ...             ...
# 961       140.0       1435.0        0.0  2017.0    0.0     2245.293590
# 309       120.0       1435.0        1.0  2009.0    0.0     1775.105043
# 664        80.0       1435.0        1.0  2023.0    0.0     2148.754371
# 965         NaN          NaN        NaN     NaN    NaN     2967.706658
# 984         NaN          NaN        NaN     NaN    NaN     2984.493750
#
#          train_type  duration  country_pop_den   region  \
# 1158            MRT       9.0       300.038762     Asia
# 1105            MRT      15.0       495.049644   Europe
# 952             MRT       5.0       139.904214     Asia
# 1193            MRT       4.0       128.698522     Asia
# 1160            MRT       6.0         3.144936  Oceania
# ...             ...       ...              ...      ...
# 961   Regional Rail       3.0       138.773908     Asia
# 309             MRT       7.0        93.844625     Asia
# 664             MRT       5.0       149.723553     Asia
# 965             NaN       NaN              NaN      NaN
# 984             NaN       NaN              NaN      NaN
#
#                      sub_region  area_km  population  calculated_population  \
# 1158         South-eastern Asia   2165.0  15136000.0           1.398149e+07
# 1105             Western Europe    219.3   1459402.0           1.370597e+06
# 952          South-eastern Asia   3199.0  18007000.0           1.945606e+07
# 1193               Western Asia    712.0   3331420.0           3.236232e+06
# 1160  Australia and New Zealand   1687.0   4840600.0           4.602311e+06
# ...                         ...      ...         ...                    ...
# 961          South-eastern Asia   3199.0  18007000.0           1.718990e+07
# 309                Western Asia   1471.0  16079000.0           1.387387e+07
# 664                Eastern Asia   5472.8  12135000.0           1.316777e+07
# 965                         NaN      NaN         NaN                    NaN
# 984                         NaN      NaN         NaN                    NaN
#
#       city_density  per_below_line  reporting_gdp  wrb_class_value  \
# 1158   6457.964278       43.567200    3756.490000             11.0
# 1105   6249.871245        0.232243   43574.775190             11.0
# 952    6081.918351       14.598018    5840.053067             11.0
# 1193   4545.269923       43.486984   34495.765270             25.0
# 1160   2728.103696        0.989104   57527.177030              6.0
# ...            ...             ...            ...              ...
# 961    5373.522205       14.598018    5840.053067             11.0
# 309    9431.593602       25.943063    8173.536251              6.0
# 664    2406.038044       37.855836    8016.431435              6.0
# 965            NaN             NaN            NaN              NaN
# 984            NaN             NaN            NaN              NaN
#
#       prob_Ferralsols  prob_Acrisols  prob_Andosols  prob_Cryosols  \
# 1158              6.0            9.0            1.0            0.0
# 1105              0.0            0.0            0.0            0.0
# 952               2.0            0.0            0.0            0.0
# 1193              1.0            0.0            0.0            0.0
# 1160              6.0           10.0            0.0            0.0
# ...               ...            ...            ...            ...
# 961               2.0            0.0            0.0            0.0
# 309               1.0            6.0            3.0            0.0
# 664               2.0            7.0            0.0            0.0
# 965               NaN            NaN            NaN            NaN
# 984               NaN            NaN            NaN            NaN
#
#       prob_Cambisols  prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  \
# 1158            19.0            4.0               0.0                0.0
# 1105            18.0            8.0               2.0                0.0
# 952              9.0            3.0               1.0                0.0
# 1193             2.0            1.0               0.0                0.0
# 1160            11.0            2.0               2.0                0.0
# ...              ...            ...               ...                ...
# 961              9.0            3.0               1.0                0.0
# 309             27.0            0.0               3.0                1.0
# 664             29.0            1.0               0.0                1.0
# 965              NaN            NaN               NaN                NaN
# 984              NaN            NaN               NaN                NaN
#
#       prob_Calcisols  prob_Chernozems  prob_Durisols  prob_Gypsisols  \
# 1158             0.0              0.0            0.0             0.0
# 1105             2.0              3.0            0.0             0.0
# 952              2.0              0.0            0.0             0.0
# 1193             5.0              0.0            0.0             0.0
# 1160             1.0              2.0            0.0             0.0
# ...              ...              ...            ...             ...
# 961              2.0              0.0            0.0             0.0
# 309              4.0              3.0            0.0             0.0
# 664              2.0              0.0            0.0             0.0
# 965              NaN              NaN            NaN             NaN
# 984              NaN              NaN            NaN             NaN
#
#       prob_Fluvisols  prob_Alisols  prob_Planosols  prob_Arenosols  \
# 1158            34.0           1.0             2.0             8.0
# 1105            22.0           0.0             1.0             6.0
# 952             61.0           0.0             1.0             0.0
# 1193            11.0           0.0             0.0             5.0
# 1160             1.0           0.0             6.0             9.0
# ...              ...           ...             ...             ...
# 961             61.0           0.0             1.0             0.0
# 309              5.0           2.0             0.0             0.0
# 664              5.0          11.0             2.0             2.0
# 965              NaN           NaN             NaN             NaN
# 984              NaN           NaN             NaN             NaN
#
#       prob_Plinthosols  prob_Luvisols  prob_Umbrisols  prob_Podzols  \
# 1158               5.0            2.0             0.0           0.0
# 1105               0.0            3.0             0.0          13.0
# 952                0.0            6.0             0.0           0.0
# 1193               0.0            0.0             0.0           0.0
# 1160               0.0            6.0             0.0           1.0
# ...                ...            ...             ...           ...
# 961                0.0            6.0             0.0           0.0
# 309                0.0           15.0             0.0           0.0
# 664                0.0            4.0             0.0           0.0
# 965                NaN            NaN             NaN           NaN
# 984                NaN            NaN             NaN           NaN
#
#       prob_Histosols  prob_Vertisols  prob_Lixisols  prob_Phaeozems  \
# 1158             0.0             3.0            2.0             0.0
# 1105             5.0             4.0            0.0             3.0
# 952              0.0             5.0            1.0             0.0
# 1193             0.0             0.0            0.0             0.0
# 1160             1.0            11.0            3.0             8.0
# ...              ...             ...            ...             ...
# 961              0.0             5.0            1.0             0.0
# 309              0.0             9.0            1.0             6.0
# 664              0.0             2.0            4.0             3.0
# 965              NaN             NaN            NaN             NaN
# 984              NaN             NaN            NaN             NaN
#
#       prob_Regosols  prob_Solonetz  prob_Solonchaks  prob_Leptosols  \
# 1158            0.0            0.0              0.0             1.0
# 1105            3.0            0.0              0.0             4.0
# 952             1.0            3.0              1.0             2.0
# 1193           27.0            0.0             43.0             3.0
# 1160            4.0            1.0              2.0             5.0
# ...             ...            ...              ...             ...
# 961             1.0            3.0              1.0             2.0
# 309            11.0            0.0              0.0             3.0
# 664            13.0            0.0              1.0             8.0
# 965             NaN            NaN              NaN             NaN
# 984             NaN            NaN              NaN             NaN
#
#       prob_Nitisols  prob_Stagnosols  elevation       tavg       tmin  \
# 1158            1.0              0.0       14.0  27.500000  24.600000
# 1105            0.0              0.0       19.0  11.500000   7.000000
# 952             0.0              0.0        4.0  28.400000  24.083333
# 1193            0.0              0.0       10.0  28.750000  23.700000
# 1160            3.0              0.0       72.0  18.191667  14.225000
# ...             ...              ...        ...        ...        ...
# 961             0.0              0.0        4.0  28.400000  24.083333
# 309             0.0              0.0       41.0  14.458333  10.383333
# 664             1.0              0.0      218.0  18.291667  15.291667
# 965             NaN              NaN        NaN        NaN        NaN
# 984             NaN              NaN        NaN        NaN        NaN
#
#            tmax        prcp  land_cost_year  price_income_ratio  \
# 1158  30.400000  165.166667          2017.0                26.0
# 1105  16.100000   55.416667          2011.0                 5.0
# 952   32.733333  124.833333          2020.0                22.0
# 1193  33.900000    7.916667          2018.0                 4.0
# 1160  22.133333  107.908333          2016.0                 8.0
# ...         ...         ...             ...                 ...
# 961   32.733333  124.833333          2017.0                24.0
# 309   18.491667   58.083333          2009.0                 4.0
# 664   21.275000   89.916667          2020.0                29.0
# 965         NaN         NaN             NaN                 NaN
# 984         NaN         NaN             NaN                 NaN
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 1158                 285.0                  0.0     1.0           4.0
# 1105                  43.0                  2.0     1.0           5.0
# 952                  185.0                  0.0     1.0           3.0
# 1193                  35.0                  2.0     1.0          10.0
# 1160                  66.0                  1.0     1.0           4.0
# ...                    ...                  ...     ...           ...
# 961                  212.0                  0.0     1.0           3.0
# 309                   75.0                  1.0     1.0           7.0
# 664                  231.0                  0.0     0.0           1.0
# 965                    NaN                  NaN     NaN           NaN
# 984                    NaN                  NaN     NaN           NaN
#
#       price_rent_ratio  union_density  stations_per_km  leverage    residuals  \
# 1158              22.0      20.403333         0.710660  0.226002  3469.857218
# 1105              17.0      21.885303         0.824742  0.256104  2401.048876
# 952               31.0       3.348848         0.719424  0.161316  2215.488221
# 1193               9.0       0.000000         0.466667  0.322776  1978.125640
# 1160              22.0      17.300000         0.361111  0.192617  1941.822365
# ...                ...            ...              ...       ...          ...
# 961               26.0       3.348848         0.281690  0.167520 -1913.455829
# 309               13.0       5.337857         0.737327  0.135159 -1991.443939
# 664               52.0      16.312870         0.240945  0.159739 -2169.357928
# 965                NaN            NaN              NaN       NaN          NaN
# 984                NaN            NaN              NaN       NaN          NaN
#
#       standardized_residuals  cooks_distance
# 1158                4.157238        0.101577
# 1105                2.855737        0.059667
# 952                 2.629778        0.025174
# 1193                2.340738        0.061586
# 1160                2.296532        0.024917
# ...                      ...             ...
# 961                -2.398087        0.019792
# 309                -2.493054        0.016027
# 664                -2.709702        0.023811
# 965                      NaN             NaN
# 984                      NaN             NaN
#
# [279 rows x 73 columns]

# %% [markdown]
# ### Dropping High Standardized Residuals
#
# After adjusting the data to account for the outliers, there are still a few significant outliers. Since I've gone through the data and verified its accuracytc, I'll outright remove these datapoints before re-running the model.

# %%
data.shape
# Out:
# (1124, 74)

# %%
data[data['standardized_residuals']>=3]
# Out:
#       rr?     length  tunnel_per  tunnel  elevated   at_grade  stations  \
# 389   0.0  58.300000    0.279588   16.30      42.0   0.000000      20.0
# 1254  0.0  40.877868    0.000000    0.00       0.0  40.877868      31.0
# 1201  0.0  16.000000    0.962500   15.40       0.6   0.000000       7.0
# 1247  0.0  13.100000    1.000000   13.10       0.0   0.000000       9.0
# 15    0.0  34.000000    0.235294    8.00       6.0  20.000000       9.0
# 1237  0.0  37.600000    0.053191    2.00      35.6   0.000000      26.0
# 97    0.0  47.800000    0.914226   43.70       4.1   0.000000      52.0
# 1166  0.0  35.500000    1.000000   35.50       0.0   0.000000      30.0
# 909   0.0  29.349008    0.170364    5.00      10.0  14.349008       8.0
# 1224  0.0  71.200000    0.200000   14.24       0.0  56.960000      27.0
# 1517  0.0  18.500000    0.000000    0.00       0.0  18.500000      18.0
# 388   0.0  27.800000    1.000000   27.80       0.0   0.000000      27.0
#
#       max_speed  track_gauge  overhead?    year  anglo  cost_real_2023  \
# 389       130.0       1067.0        1.0  2001.0    0.0     9778.091940
# 1254      100.0       1435.0        1.0  2027.0    1.0     8011.419793
# 1201       80.0       1600.0        0.0  2013.0    0.0     6613.858088
# 1247      100.0       1435.0        0.0  2017.0    0.0     5703.136539
# 15         80.0       1432.0        0.0  1996.0    0.0     7939.046466
# 1237      100.0       1435.0        0.0  2021.0    0.0    10574.870410
# 97         80.0       1445.0        1.0  2015.0    0.0    10314.641780
# 1166       80.0       1435.0        0.0  2007.0    1.0    10209.891254
# 909        90.0       1435.0        1.0  2030.0    1.0     5873.186658
# 1224       80.0       1435.0        1.0  2021.0    0.0     9622.257526
# 1517       70.0       1435.0        1.0  1998.0    0.0     9807.819347
# 388        70.0       1435.0        1.0  1996.0    0.0    10095.920180
#
#       train_type  duration  country_pop_den    region  \
# 389          MRT       8.0       348.831276      Asia
# 1254  Light Rail       6.0        36.240985  Americas
# 1201         MRT       6.0        24.134768  Americas
# 1247  Light Rail       7.0       236.010009      Asia
# 15           MRT       4.0      6129.047619      Asia
# 1237  Light Rail       8.0       101.050047      Asia
# 97           MRT      23.0        92.952686    Europe
# 1166         MRT      10.0      6602.300719      Asia
# 909   Light Rail      10.0        36.240985  Americas
# 1224         MRT       5.0       149.723553      Asia
# 1517        Tram       3.0        80.872892      Asia
# 388          MRT       8.0       345.012346      Asia
#
#                            sub_region  area_km  population  \
# 389                      Eastern Asia   6993.0  37732000.0
# 1254                 Northern America   1126.0   1516107.0
# 1201  Latin America and the Caribbean   2020.0  12592000.0
# 1247                     Western Asia    132.0   1186023.0
# 15                       Eastern Asia    290.0   7450000.0
# 1237               South-eastern Asia   2163.0   8911000.0
# 97                    Southern Europe   1072.0   4800000.0
# 1166               South-eastern Asia    523.0   5983000.0
# 909                  Northern America   1300.0  12121244.0
# 1224                     Eastern Asia   2672.0   2509243.0
# 1517                     Western Asia   1055.0   2232374.0
# 388                      Eastern Asia   6993.0  37732000.0
#
#       calculated_population  city_density  per_below_line  reporting_gdp  \
# 389            3.120057e+07   4461.686312        2.220306   25769.000000
# 1254           1.552560e+06   1378.828143        2.157590   65536.734290
# 1201           1.200025e+07   5940.718304       41.379542    7560.702040
# 1247           1.101340e+06   8343.486812       43.486984   66838.360000
# 15             6.546710e+06  22574.863522       91.142996    1653.430868
# 1237           9.124864e+06   4218.614887        4.818305    9955.242722
# 97             4.679451e+06   4365.159198        3.466943   25732.018360
# 1166           5.478445e+06  10475.038421        1.528690     950.000000
# 909            1.338939e+07  10299.534085        2.157590   65536.734290
# 1224           2.578749e+06    965.100685       37.855836    8016.431435
# 1517           1.514234e+06   1435.293349       38.833735    6373.131907
# 388            2.967834e+07   4244.006777        2.220306   25769.000000
#
#       wrb_class_value  prob_Ferralsols  prob_Acrisols  prob_Andosols  \
# 389               6.0              0.0           15.0            6.0
# 1254             18.0              0.0           31.0            0.0
# 1201              0.0             11.0           15.0            0.0
# 1247             25.0              0.0            0.0            0.0
# 15                0.0             13.0           37.0            4.0
# 1237              0.0             12.0           51.0            2.0
# 97               16.0              1.0            0.0            0.0
# 1166              6.0             17.0           14.0            2.0
# 909              15.0              0.0            0.0            0.0
# 1224             11.0              7.0           20.0            0.0
# 1517              5.0              0.0            0.0            2.0
# 388               6.0              0.0           15.0            6.0
#
#       prob_Cryosols  prob_Cambisols  prob_Gleysols  prob_Kastanozems  \
# 389             0.0            17.0           16.0               2.0
# 1254            0.0             5.0            0.0               2.0
# 1201            0.0             7.0            6.0               0.0
# 1247            0.0             2.0            1.0               0.0
# 15              0.0            15.0            3.0               0.0
# 1237            0.0            10.0            1.0               0.0
# 97              0.0            12.0            0.0               4.0
# 1166            0.0            17.0            2.0               0.0
# 909             0.0            11.0            0.0              26.0
# 1224            0.0             9.0            4.0               0.0
# 1517            0.0            15.0            1.0               9.0
# 388             0.0            17.0           16.0               2.0
#
#       prob_Albeluvisols  prob_Calcisols  prob_Chernozems  prob_Durisols  \
# 389                 0.0             0.0              2.0            0.0
# 1254                0.0             0.0              0.0            0.0
# 1201                0.0             3.0              0.0            0.0
# 1247                0.0             7.0              0.0            0.0
# 15                  0.0             0.0              0.0            0.0
# 1237                0.0             0.0              0.0            0.0
# 97                  0.0            12.0              1.0            0.0
# 1166                0.0             0.0              0.0            0.0
# 909                 0.0             2.0              0.0            0.0
# 1224                0.0             0.0              0.0            0.0
# 1517                0.0            19.0              0.0            0.0
# 388                 0.0             0.0              2.0            0.0
#
#       prob_Gypsisols  prob_Fluvisols  prob_Alisols  prob_Planosols  \
# 389              0.0             7.0           2.0             4.0
# 1254             0.0             1.0           5.0             1.0
# 1201             0.0             3.0           2.0             8.0
# 1247             0.0            13.0           0.0             0.0
# 15               0.0             4.0           3.0             0.0
# 1237             0.0             2.0           1.0             1.0
# 97               1.0             6.0           2.0             0.0
# 1166             0.0             8.0           1.0             1.0
# 909              0.0             2.0           0.0             0.0
# 1224             0.0            27.0           0.0             2.0
# 1517             2.0             6.0           0.0             0.0
# 388              0.0             7.0           2.0             4.0
#
#       prob_Arenosols  prob_Plinthosols  prob_Luvisols  prob_Umbrisols  \
# 389              0.0               0.0           11.0             0.0
# 1254             0.0               0.0           41.0             0.0
# 1201             6.0               0.0            5.0             0.0
# 1247             5.0               0.0            0.0             0.0
# 15               0.0               0.0            5.0             0.0
# 1237             5.0               2.0            1.0             0.0
# 97               3.0               0.0           11.0             0.0
# 1166             3.0               8.0            0.0             0.0
# 909              2.0               0.0           20.0             0.0
# 1224             0.0               3.0            2.0             0.0
# 1517             1.0               0.0           16.0             0.0
# 388              0.0               0.0           11.0             0.0
#
#       prob_Podzols  prob_Histosols  prob_Vertisols  prob_Lixisols  \
# 389            1.0             0.0             3.0            1.0
# 1254           2.0             1.0             3.0            3.0
# 1201           2.0             1.0             5.0            8.0
# 1247           0.0             0.0             2.0            0.0
# 15             1.0             1.0             1.0            4.0
# 1237           2.0             3.0             1.0            1.0
# 97             0.0             1.0            11.0            1.0
# 1166           3.0            16.0             1.0            3.0
# 909            0.0             0.0             6.0            0.0
# 1224           0.0             1.0             5.0            7.0
# 1517           1.0             0.0             1.0            0.0
# 388            1.0             0.0             3.0            1.0
#
#       prob_Phaeozems  prob_Regosols  prob_Solonetz  prob_Solonchaks  \
# 389              1.0            2.0            0.0              3.0
# 1254             1.0            3.0            0.0              0.0
# 1201             2.0            4.0            2.0              0.0
# 1247             0.0           33.0            0.0             35.0
# 15               0.0            0.0            0.0              0.0
# 1237             1.0            0.0            0.0              0.0
# 97               6.0            9.0            1.0              2.0
# 1166             1.0            0.0            0.0              0.0
# 909              2.0           18.0            0.0              0.0
# 1224             1.0            1.0            1.0              0.0
# 1517             1.0           16.0            1.0              3.0
# 388              1.0            2.0            0.0              3.0
#
#       prob_Leptosols  prob_Nitisols  prob_Stagnosols  elevation       tavg  \
# 389              4.0            0.0              0.0       40.0  15.791667
# 1254             0.0            0.0              0.0      209.0  15.558333
# 1201             4.0            2.0              0.0        5.0  24.750000
# 1247             0.0            0.0              0.0        7.0  29.100000
# 15               3.0            3.0              0.0        0.0  23.500000
# 1237             0.0            2.0              0.0       35.0  28.450000
# 97              15.0            1.0              0.0       30.0  16.700000
# 1166             0.0            2.0              0.0       14.0  28.250000
# 909              8.0            1.0              0.0      354.0  19.150000
# 1224             4.0            2.0              0.0       25.0  22.900000
# 1517             6.0            0.0              0.0     1025.0  11.608333
# 388              4.0            0.0              0.0       40.0  15.791667
#
#            tmin       tmax        prcp  land_cost_year  price_income_ratio  \
# 389   12.016667  19.541667  117.500000          2001.0                13.0
# 1254   9.783333  21.300000   90.416667          2020.0                 3.0
# 1201  21.700000  27.900000   89.166667          2013.0                13.0
# 1247  23.500000  34.800000    9.166667          2017.0                 6.0
# 15    21.600000  26.000000  202.600000          1996.0                 1.0
# 1237  24.100000  32.900000  202.083333          2020.0                 9.0
# 97    12.700000  20.800000   78.750000          2015.0                 9.0
# 1166  25.000000  31.600000  176.250000          2007.0                19.0
# 909   13.700000  24.600000   30.000000          2020.0                 3.0
# 1224  18.700000  27.200000  140.416667          2020.0                29.0
# 1517   5.425000  17.825000   27.750000          1998.0                 0.0
# 388   12.016667  19.541667  117.500000          1996.0                13.0
#
#       mortgage_perc_income  affordability_index  urban?  rental_yield  \
# 389                   77.0                  1.0     1.0           3.0
# 1254                  26.0                  3.0     0.0          11.0
# 1201                 157.0                  0.0     1.0           4.0
# 1247                  47.0                  2.0     1.0           9.0
# 15                    13.0                  1.0     1.0           5.0
# 1237                  75.0                  1.0     1.0           3.0
# 97                    66.0                  1.0     1.0           3.0
# 1166                 124.0                  0.0     1.0           3.0
# 909                   26.0                  3.0     1.0          10.0
# 1224                 231.0                  0.0     0.0           1.0
# 1517                  53.0                  2.0     0.0           8.0
# 388                   79.0                  1.0     1.0           4.0
#
#       price_rent_ratio  union_density  stations_per_km  leverage    residuals  \
# 389               31.0      21.337222         0.343053  0.084474  1198.657332
# 1254               8.0      11.802000         0.758357  0.071165  1689.371682
# 1201              20.0      16.784444         0.437500  0.056612  1253.563991
# 1247              10.0       0.000000         0.687023  0.094063  1052.320556
# 15                 5.0      21.699286         0.264706  0.115581  1013.819639
# 1237              27.0       9.168442         0.691489  0.109162  1561.831756
# 97                25.0      23.628823         1.087866  0.067545  1535.287216
# 1166              23.0      16.007242         0.845070  0.074154  1908.950444
# 909                9.0      11.802000         0.272582  0.062101  1113.767372
# 1224              52.0      16.312870         0.379213  0.055115  1121.703437
# 1517               9.0       5.337857         0.972973  0.053227  3329.237888
# 388               28.0      21.337222         0.971223  0.077464  1392.177985
#
#       standardized_residuals  cooks_distance  cost_km_2023
# 389                 3.602159        0.020653           NaN
# 1254                5.113937        0.033579           NaN
# 1201                3.771314        0.014258           NaN
# 1247                3.151330        0.018103           NaN
# 15                  3.032717        0.021663           NaN
# 1237                4.721016        0.047859           NaN
# 97                  4.639239        0.026118           NaN
# 1166                5.790409        0.044964           NaN
# 909                 3.340633        0.012491           NaN
# 1224                3.365082        0.011079           NaN
# 1517               10.165987        0.093875           NaN
# 388                 4.198352        0.025162           NaN

# %%
data = data[data['standardized_residuals'] < 3]

# %%
data
# Out:
#       rr?     length  tunnel_per  tunnel   elevated   at_grade  stations  \
# 47    0.0  16.500000    1.000000   16.50   0.000000   0.000000      13.0
# 98    0.0  16.900000    1.000000   16.90   0.000000   0.000000      15.0
# 1289  0.0  14.377958    0.000000    0.00   0.000000  14.377958      15.0
# 1023  0.0  55.070000    1.000000   55.07   0.000000   0.000000      43.0
# 825   0.0  14.940000    0.087015    1.30  13.640000   0.000000      11.0
# ...   ...        ...         ...     ...        ...        ...       ...
# 1135  0.0  24.000000    0.500000   12.00   0.000000  12.000000      34.0
# 509   0.0   4.300000    1.000000    4.30   0.000000   0.000000       5.0
# 1495  0.0   7.723243    0.000000    0.00   0.000000   7.723243      27.0
# 1259  0.0   4.200000    0.000000    0.00   1.691144   2.494856       2.0
# 1197  0.0  39.600000    0.411616   16.30  23.300000   0.000000      25.0
#
#       max_speed  track_gauge  overhead?    year  anglo  cost_real_2023  \
# 47        100.0       1435.0        0.0  2010.0    0.0     4850.671393
# 98         80.0       1435.0        0.0  2009.0    0.0     5133.825405
# 1289       70.0       1435.0        1.0  2013.0    1.0      674.095003
# 1023       80.0       1435.0        1.0  2008.0    0.0     9844.449153
# 825        80.0       1435.0        1.0  2019.0    0.0     1403.682194
# ...         ...          ...        ...     ...    ...             ...
# 1135       80.0       1435.0        1.0  2019.0    0.0     4854.585947
# 509        80.0       1435.0        0.0  2010.0    0.0     1443.219682
# 1495       60.0       1435.0        1.0  2017.0    1.0      108.011405
# 1259       60.0       1435.0        1.0  2015.0    1.0      224.559661
# 1197       80.0       1435.0        1.0  2018.0    0.0     6934.941734
#
#       train_type  duration  country_pop_den    region        sub_region  \
# 47           MRT       5.0       141.936072      Asia      Eastern Asia
# 98           MRT      14.0        92.975065    Europe   Southern Europe
# 1289  Light Rail       3.0       265.069537    Europe   Northern Europe
# 1023         MRT       5.0       140.551423      Asia      Eastern Asia
# 825          MRT       4.0       149.367573      Asia      Eastern Asia
# ...          ...       ...              ...       ...               ...
# 1135  Light Rail       7.0       418.391867      Asia      Western Asia
# 509         Tram      22.0       200.452516    Europe   Southern Europe
# 1495   Streetcar       3.0        35.542495  Americas  Northern America
# 1259  Light Rail       2.0        35.063329  Americas  Northern America
# 1197         MRT      14.0       460.449317      Asia     Southern Asia
#
#       area_km  population  calculated_population  city_density  \
# 47    12796.5  22366547.0           1.829448e+07   1429.647188
# 98     1072.0   4800000.0           4.538781e+06   4233.937562
# 1289    115.6   2705000.0           2.568938e+06  22222.648127
# 1023   3658.2   7964000.0           6.257439e+06   1710.523977
# 825    1172.9   3842100.0           3.748390e+06   3195.831055
# ...       ...         ...                    ...           ...
# 1135    453.0    435855.0           4.282325e+05    945.325524
# 509     583.0    966144.0           9.700171e+05   1663.837207
# 1495    568.0    794344.0           7.680130e+05   1352.135646
# 1259    385.9   5668165.0           5.446780e+06  14114.485273
# 1197    250.0   1684222.0           1.618822e+06   6475.286428
#
#       per_below_line  reporting_gdp  wrb_class_value  prob_Ferralsols  \
# 47         69.489729    4711.635127             18.0              0.0
# 98          2.616275   26751.881410             16.0              1.0
# 1289        0.955233   43927.886020              6.0              0.0
# 1023       69.489729    4711.635127             20.0              0.0
# 825        37.855836    8016.431435             11.0              0.0
# ...              ...            ...              ...              ...
# 1135        4.991383   35808.436430              5.0              0.0
# 509         1.611045   33738.129160              6.0              0.0
# 1495        2.248539   56863.371500              5.0              0.0
# 1259        2.248539   56863.371500             18.0              0.0
# 1197       88.900103    1580.059460             11.0              2.0
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 47              1.0            0.0            0.0            22.0
# 98              0.0            0.0            0.0            12.0
# 1289            1.0            2.0            0.0            25.0
# 1023            0.0            0.0            0.0             7.0
# 825             6.0            1.0            0.0            13.0
# ...             ...            ...            ...             ...
# 1135            1.0            0.0            0.0            12.0
# 509             2.0            0.0            0.0            23.0
# 1495            0.0            0.0            0.0            10.0
# 1259            3.0            0.0            0.0            12.0
# 1197           15.0            0.0            0.0            10.0
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 47              5.0               4.0                0.0             4.0
# 98              0.0               4.0                0.0            12.0
# 1289            9.0               2.0                1.0             3.0
# 1023            6.0               7.0                0.0             1.0
# 825            23.0               0.0                0.0             1.0
# ...             ...               ...                ...             ...
# 1135            0.0               0.0                0.0            15.0
# 509             5.0               3.0                0.0             7.0
# 1495            0.0               0.0                0.0            35.0
# 1259            1.0              10.0                0.0             2.0
# 1197            7.0               0.0                0.0             0.0
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 47                3.0            0.0             0.0            15.0
# 98                1.0            0.0             1.0             6.0
# 1289              0.0            0.0             0.0             8.0
# 1023              6.0            0.0             1.0             4.0
# 825               0.0            0.0             0.0            23.0
# ...               ...            ...             ...             ...
# 1135              1.0            0.0             0.0             2.0
# 509               0.0            0.0             0.0             5.0
# 1495              0.0            0.0             6.0             7.0
# 1259              1.0            0.0             0.0             4.0
# 1197              0.0            0.0             0.0            18.0
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 47             0.0             0.0             2.0               0.0
# 98             2.0             0.0             3.0               0.0
# 1289           1.0             1.0             1.0               0.0
# 1023           0.0             1.0             3.0               0.0
# 825            6.0             7.0             1.0               0.0
# ...            ...             ...             ...               ...
# 1135           0.0             0.0            10.0               0.0
# 509            1.0             2.0             0.0               0.0
# 1495           0.0             0.0             8.0               0.0
# 1259           2.0             2.0             0.0               0.0
# 1197           2.0             0.0             5.0               1.0
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 47             25.0             0.0           0.0             0.0
# 98             11.0             0.0           0.0             1.0
# 1289           19.0             1.0           9.0             0.0
# 1023           17.0             0.0           2.0             0.0
# 825             4.0             0.0           0.0             0.0
# ...             ...             ...           ...             ...
# 1135           12.0             0.0           0.0             0.0
# 509            16.0             1.0           0.0             1.0
# 1495            3.0             0.0           0.0             0.0
# 1259           36.0             0.0           0.0             0.0
# 1197           11.0             1.0           0.0             0.0
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 47               2.0            0.0             3.0            2.0
# 98              11.0            1.0             6.0            9.0
# 1289             2.0            0.0             2.0            2.0
# 1023             1.0            0.0            25.0            6.0
# 825              1.0            4.0             0.0            1.0
# ...              ...            ...             ...            ...
# 1135            12.0            3.0             2.0            9.0
# 509              6.0            1.0             4.0            9.0
# 1495             5.0            0.0             0.0           10.0
# 1259            11.0            1.0             3.0            6.0
# 1197             8.0            2.0             4.0            2.0
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 47              3.0              2.0             5.0            0.0
# 98              1.0              2.0            15.0            1.0
# 1289            1.0              0.0             6.0            0.0
# 1023            5.0              6.0             1.0            0.0
# 825             1.0              3.0             0.0            1.0
# ...             ...              ...             ...            ...
# 1135            0.0             11.0             6.0            0.0
# 509             0.0              2.0            11.0            1.0
# 1495            4.0              7.0             3.0            0.0
# 1259            4.0              0.0             0.0            0.0
# 1197            0.0              3.0             4.0            1.0
#
#       prob_Stagnosols  elevation       tavg       tmin       tmax        prcp  \
# 47                0.0       50.0  12.083333   6.491667  17.666667   48.166667
# 98                0.0       30.0  16.700000  12.700000  20.800000   78.750000
# 1289              1.0       51.0  10.600000   7.500000  13.700000   69.583333
# 1023              0.0       42.0   8.650000   3.300000  14.100000   58.333333
# 825               0.0       26.0  15.766667  11.308333  20.200000   85.083333
# ...               ...        ...        ...        ...        ...         ...
# 1135              0.0       17.0  18.550000  14.500000  22.700000   30.416667
# 509               0.0       29.0  16.950000  12.200000  21.700000   84.000000
# 1495              0.0     1186.0  21.150000  15.400000  27.000000    8.750000
# 1259              0.0      150.0  19.041667  13.400000  24.666667   76.408333
# 1197              0.0       66.0  25.650000  20.000000  31.400000  119.583333
#
#       land_cost_year  price_income_ratio  mortgage_perc_income  \
# 47            2010.0                17.0                 131.0
# 98            2009.0                12.0                  91.0
# 1289          2013.0                 6.0                  51.0
# 1023          2008.0                22.0                 184.0
# 825           2019.0                29.0                 231.0
# ...              ...                 ...                   ...
# 1135          2019.0                14.0                  97.0
# 509           2010.0                14.0                 119.0
# 1495          2017.0                 3.0                  23.0
# 1259          2015.0                 2.0                  19.0
# 1197          2018.0                 9.0                 112.0
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 47                    0.0     0.0           5.0              20.0
# 98                    1.0     1.0           2.0              33.0
# 1289                  2.0     1.0           5.0              17.0
# 1023                  0.0     0.0           4.0              13.0
# 825                   0.0     1.0           1.0              54.0
# ...                   ...     ...           ...               ...
# 1135                  1.0     0.0           3.0              32.0
# 509                   0.0     0.0           4.0              23.0
# 1495                  4.0     0.0          12.0               8.0
# 1259                  5.0     1.0          11.0               9.0
# 1197                  0.0     1.0           3.0              32.0
#
#       union_density  stations_per_km  leverage   residuals  \
# 47        16.312870         0.787879  0.031909  530.515843
# 98        23.628823         0.887574  0.029437  843.335886
# 1289      28.591909         1.043264  0.036754  -62.266276
# 1023      16.312870         0.780824  0.056987  706.929703
# 825       16.312870         0.736278  0.045511  -93.263178
# ...             ...              ...       ...         ...
# 1135      25.160000         1.416667  0.054691  518.038530
# 509       38.052545         1.162791  0.069602  147.281005
# 1495      11.802000         3.495941  0.107962 -182.956106
# 1259      11.802000         0.476190  0.026019  -52.001162
# 1197      12.133509         0.631313  0.070748  374.101450
#
#       standardized_residuals  cooks_distance  cost_km_2023
# 47                  1.543769        0.001367           NaN
# 98                  2.507496        0.003170           NaN
# 1289               -0.282456        0.000022           NaN
# 1023                2.087260        0.004568           NaN
# 825                -0.377950        0.000062           NaN
# ...                      ...             ...           ...
# 1135                1.505330        0.002343           NaN
# 509                 0.363111        0.000249           NaN
# 1495               -0.654273        0.000648           NaN
# 1259               -0.250831        0.000011           NaN
# 1197                1.061893        0.001636           NaN
#
# [1111 rows x 74 columns]

# %%
data_unseen[data_unseen['standardized_residuals']>=3]
# Out:
#       rr?  length  tunnel_per  tunnel  elevated  at_grade  stations  \
# 1158  0.0    19.7     0.13198     2.6      17.1       0.0      14.0
#
#       max_speed  track_gauge  overhead?    year  anglo  cost_real_2023  \
# 1158       80.0       1435.0        1.0  2017.0    0.0      6564.87287
#
#      train_type  duration  country_pop_den region          sub_region  \
# 1158        MRT       9.0       300.038762   Asia  South-eastern Asia
#
#       area_km  population  calculated_population  city_density  \
# 1158   2165.0  15136000.0           1.398149e+07   6457.964278
#
#       per_below_line  reporting_gdp  wrb_class_value  prob_Ferralsols  \
# 1158         43.5672        3756.49             11.0              6.0
#
#       prob_Acrisols  prob_Andosols  prob_Cryosols  prob_Cambisols  \
# 1158            9.0            1.0            0.0            19.0
#
#       prob_Gleysols  prob_Kastanozems  prob_Albeluvisols  prob_Calcisols  \
# 1158            4.0               0.0                0.0             0.0
#
#       prob_Chernozems  prob_Durisols  prob_Gypsisols  prob_Fluvisols  \
# 1158              0.0            0.0             0.0            34.0
#
#       prob_Alisols  prob_Planosols  prob_Arenosols  prob_Plinthosols  \
# 1158           1.0             2.0             8.0               5.0
#
#       prob_Luvisols  prob_Umbrisols  prob_Podzols  prob_Histosols  \
# 1158            2.0             0.0           0.0             0.0
#
#       prob_Vertisols  prob_Lixisols  prob_Phaeozems  prob_Regosols  \
# 1158             3.0            2.0             0.0            0.0
#
#       prob_Solonetz  prob_Solonchaks  prob_Leptosols  prob_Nitisols  \
# 1158            0.0              0.0             1.0            1.0
#
#       prob_Stagnosols  elevation  tavg  tmin  tmax        prcp  \
# 1158              0.0       14.0  27.5  24.6  30.4  165.166667
#
#       land_cost_year  price_income_ratio  mortgage_perc_income  \
# 1158          2017.0                26.0                 285.0
#
#       affordability_index  urban?  rental_yield  price_rent_ratio  \
# 1158                  0.0     1.0           4.0              22.0
#
#       union_density  stations_per_km  leverage    residuals  \
# 1158      20.403333          0.71066  0.226002  3469.857218
#
#       standardized_residuals  cooks_distance
# 1158                4.157238        0.101577

# %%
data_unseen = data_unseen[data_unseen['standardized_residuals'] < 3]

# %% [markdown]
# ### Model Re-run

# %%
data.dropna(inplace=True)
data_unseen.dropna(inplace=True)

# %%
data.shape
# Out:
# (0, 74)

# %%
drop_cols = ['leverage', 'residuals', 'standardized_residuals','cooks_distance']
data.drop(columns =drop_cols,inplace = True)
data_unseen.drop(columns =drop_cols,inplace = True)

# %%
s = setup(data,
          target = 'cost_real_2023',
          ordinal_features ={'wrb_class_value': list(range(0, 30))},
          categorical_features= cat_feats,
          numeric_features= cont_feats,
          normalize = True,
          normalize_method = 'zscore',
          verbose = False,
          feature_selection = True,
          n_features_to_select = 10,
          low_variance_threshold = 0.1,
          pca = False, 
          pca_components = 30,
          remove_multicollinearity = False,
          multicollinearity_threshold = 0.3
         )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/fm/_6kg8xkn3jz4slz27zwpqnhc0000gn/T/ipykernel_52125/452261159.py in <cell line: 1>()
# ----> 1 s = setup(data,
#       2           target = 'cost_real_2023',
#       3           ordinal_features ={'wrb_class_value': list(range(0, 30))},
#       4           categorical_features= cat_feats,
#       5           numeric_features= cont_feats,
#
# ~/miniconda3/envs/tf/lib/python3.9/site-packages/pycaret/regression/functional.py in setup(data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, transform_target, transform_target_method, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs)
#     598     exp = _EXPERIMENT_CLASS()
#     599     set_current_experiment(exp)
# --> 600     return exp.setup(
#     601         data=data,
#     602         data_func=data_func,
#
# ~/miniconda3/envs/tf/lib/python3.9/site-packages/pycaret/regression/oop.py in setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, transform_target, transform_target_method, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     722         self.data_split_shuffle = data_split_shuffle
#     723
# --> 724         self._prepare_train_test(
#     725             train_size=train_size,
#     726             test_data=test_data,
#
# ~/miniconda3/envs/tf/lib/python3.9/site-packages/pycaret/internal/preprocess/preprocessor.py in _prepare_train_test(self, train_size, test_data, data_split_stratify, data_split_shuffle)
#     234
#     235             # self.data is already prepared here
# --> 236             train, test = train_test_split(
#     237                 self.data,
#     238                 train_size=train_size,
#
# ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2560
#    2561     n_samples = _num_samples(arrays[0])
# -> 2562     n_train, n_test = _validate_shuffle_split(
#    2563         n_samples, test_size, train_size, default_test_size=0.25
#    2564     )
#
# ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/model_selection/_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2234
#    2235     if n_train == 0:
# -> 2236         raise ValueError(
#    2237             "With n_samples={}, test_size={} and train_size={}, the "
#    2238             "resulting train set will be empty. Adjust any of the "
#
# ValueError: With n_samples=0, test_size=None and train_size=0.7, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
compare_models(include = ['catboost','et','rf','lightgbm','gbr','xgboost','br'])

# %% [markdown]
# ##### Random Forest

# %%
rf = create_model('rf')
param_grid_rf = {
    'n_estimators': [50, 100, 200, 300],
    'max_depth': [None, 3, 4, 5, 6, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False],  # Default for RandomForest is True.
    'max_features': ['auto', 'sqrt', 'log2'],
}
rf_tuned = tune_model(
    rf,
    fold = 10,
    n_iter = 50,
    custom_grid = param_grid_rf,
    choose_better = False
)
predictions = predict_model(rf_tuned, data=data_unseen)
rf_bagged = ensemble_model(rf_tuned,method = 'Bagging',fold = 10,n_estimators = 100, choose_better = True)

# %% [markdown]
# ##### Extra Trees

# %%
et = create_model('et')
param_grid_et = {
    'n_estimators': [50, 100, 200, 300],
    'max_depth': [None, 3, 4, 5, 6, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False],  # Set bootstrap option. Default for ExtraTrees is False, but you can experiment with True.
    'max_features': ['auto', 'sqrt', 'log2']
}
et_tuned = tune_model(
    et,
    fold = 10,
    n_iter = 50,
    custom_grid = param_grid_et,
    choose_better = False
)
predictions = predict_model(et_tuned, data=data_unseen)
et_bagged = ensemble_model(et_tuned,method = 'Bagging',fold = 10,n_estimators = 100, choose_better = True)

# %% [markdown]
# ##### Baysian Ridge

# %%
br = create_model('br')
param_grid_br = {
    'n_iter': [100, 200, 300, 500],  # Maximum number of iterations.
    'tol': [1e-3, 1e-4, 1e-5],  # The stopping criterion.
    'alpha_1': [1e-6, 1e-5, 1e-4],  # Shape parameter for the Gamma distribution prior over alpha.
    'alpha_2': [1e-6, 1e-5, 1e-4],  # Inverse scale parameter (rate parameter) for the Gamma distribution prior over alpha.
    'lambda_1': [1e-6, 1e-5, 1e-4],  # Shape parameter for the Gamma distribution prior over lambda.
    'lambda_2': [1e-6, 1e-5, 1e-4],  # Inverse scale parameter (rate parameter) for the Gamma distribution prior over lambda.
    'alpha_init': [None, 1e-2, 1e-1, 1],  # Initial value for alpha.
    'lambda_init': [None, 1e-2, 1e-1, 1],  # Initial value for lambda.
    'fit_intercept': [True, False],  # Whether to calculate the intercept.
    'compute_score': [True, False],  # If True, compute the objective function at each step of the model.
    'copy_X': [True, False],  # If True, X will be copied; else, it may be overwritten.
}
br_tuned = tune_model(
    br,
    fold = 10,
    n_iter = 50,
    custom_grid = param_grid_br,
    choose_better = False
)
predictions = predict_model(br_tuned, data=data_unseen)
br_bagged = ensemble_model(br_tuned,method = 'Bagging',fold = 10,n_estimators = 100, choose_better = True)

# %% [markdown]
# ##### XGBoost

# %%
xg = create_model('xgboost')
param_grid_xg = {
    'learning_rate': [0.01, 0.05, 0.1, 0.2],  # Step size shrinkage used in the update to prevent overfitting.
    'max_depth': [3, 4, 5, 6, 7, 8, 10],  # Maximum depth of a tree.
    'min_child_weight': [1, 2, 5, 10],  # Minimum sum of instance weight (hessian) needed in a child.
    'subsample': [0.5, 0.7, 0.9, 1.0],  # Subsample ratio of the training instances.
    'colsample_bytree': [0.5, 0.7, 0.9, 1.0],  # Subsample ratio of columns when constructing each tree.
    'n_estimators': [50, 100, 200, 300],  # Number of boosting rounds.
    'objective': ['reg:squarederror', 'binary:logistic', 'multi:softmax'],  # Specifies the learning task and the corresponding objective.
    'gamma': [0, 0.25, 0.5, 1.0],  # Minimum loss reduction required to make a further partition on a leaf node of the tree.
    'reg_lambda': [0.1, 1.0, 5.0, 10.0],  # L2 regularization term on weights.
    'reg_alpha': [0.1, 1.0, 5.0, 10.0],  # L1 regularization term on weights.
}
xg_tuned = tune_model(
    xg,
    fold = 10,
    n_iter = 50,
    custom_grid = param_grid_xg,
    choose_better = False
)
predictions = predict_model(xg_tuned, data=data_unseen)
xg_bagged = ensemble_model(xg_tuned,method = 'Bagging',fold = 10,n_estimators = 100, choose_better = True)

# %% [markdown]
# ##### CatBoost

# %%
cat = create_model('catboost')
param_grid_cat = {
    'learning_rate': [0.01, 0.05, 0.1, 0.2],  # Learning rate.
    'depth': [3, 4, 5, 6, 7, 8, 10],  # Depth limit.
    'l2_leaf_reg': [1, 3, 5, 7, 9],  # Coefficient at the L2 regularization term of weights for leaf value.
    'bagging_temperature': [0.2, 0.5, 0.8, 1.0],  # The settings of the Bayesian bootstrap during training.
    'border_count': [32, 64, 128, 255],  # The number of splits for numerical features.
    'iterations': [50, 100, 200, 300],  # The maximum number of trees to be trained.
    'loss_function': ['RMSE', 'Logloss', 'MultiClass'],  # Objective function.
    'random_strength': [0.5, 1, 2, 3],  # The amount of randomness to use for scoring splits.
    'boosting_type': ['Ordered', 'Plain'],  # Boosting type implementation.
    'subsample': [0.5, 0.7, 0.9, 1.0],  # Sample rate for bagging.
    'rsm': [0.5, 0.7, 0.9, 1.0],  # (Equivalent to colsample_bytree in XGBoost) The percentage of features to use at each split selection.
    'grow_policy': ['SymmetricTree', 'Depthwise', 'Lossguide']  # Control the way new splits are added to the tree.
}
cat_tuned = tune_model(
    cat,
    fold = 10,
    n_iter = 50,
    custom_grid = param_grid_cat,
    choose_better = False
)
predict_model(cat_tuned, data=data_unseen)
cat_bagged = cat_tuned

# %% [markdown]
# ##### LightGBM

# %%
light = create_model('lightgbm')
param_grid_light = {
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'num_leaves': [31, 62, 127, 255],
    'max_depth': [3, 4, 5, 6, 7, 8, 10, -1],  # -1 means no limit.
    'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3],
    'subsample': [0.5, 0.7, 0.9, 1.0],
    'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
    'n_estimators': [50, 100, 200, 300],
    'objective': ['regression', 'binary', 'multiclass'],
    'reg_alpha': [0, 0.5, 1],
    'reg_lambda': [0, 0.5, 1],
    'boosting_type': ['gbdt', 'dart', 'goss']
}
light_tuned = tune_model(
    light,
    fold = 10,
    n_iter = 50,
    custom_grid = param_grid_light,
    choose_better = False
)
predictions = predict_model(light_tuned, data=data_unseen)
light_bagged = ensemble_model(light_tuned,method = 'Bagging',fold = 10,n_estimators = 100, choose_better = True)

# %% [markdown]
# ##### GradientBoost

# %%
gbr = create_model('gbr')
param_grid_gbr = {
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'max_depth': [3, 4, 5, 6, 7, 8, 10],
    'min_samples_split': [2, 4, 6, 8, 10],
    'min_samples_leaf': [1, 2, 3, 4],
    'subsample': [0.5, 0.7, 0.9, 1.0],
    'n_estimators': [50, 100, 200, 300],
    'max_features': ['auto', 'sqrt', 'log2'],
    'loss': ['ls', 'lad', 'huber', 'quantile'],
    'alpha': [0.5, 0.75, 0.9]
}
gbr_tuned = tune_model(
    gbr,
    fold = 10,
    n_iter = 50,
    custom_grid = param_grid_gbr,
    choose_better = False
)
predictions = predict_model(gbr_tuned, data=data_unseen)
gbr_bagged = ensemble_model(gbr_tuned,method = 'Bagging',fold = 10,n_estimators = 100, choose_better = True)

# %% [markdown]
# ### Blended Model

# %%
blended_final = blend_models([xg_bagged,cat])

# %%
predictions = predict_model(blended_final, data=data_unseen)

# %%
final_tuned = blend_models([xg_bagged,cat],weights = [.2,.8])

# %%
predictions = predict_model(final_tuned, data=data_unseen)

# %%
plot_model(final_tuned, plot = 'error')

# %%
plot_model(final_tuned, plot = 'residuals_interactive')

# %% [markdown]
# ### Finalized Model

# %%
finalized_model_user = finalize_model(final_tuned)

# %%
predictions = predict_model(finalized_model_user, data=data_unseen)

# %%
data_adj = data
data_adj_unseen = data_unseen

# %% [markdown]
# ### Summary of Model Progress

# %%
new_data = {
    'Model': 'Cat+XG (2nd Pass Outlier Removal)',
    'Version': 'M_D1',
    'Dataset': 'df_user',
    'MAE': 521.4628,
    'MSE': 534246.5738,
    'RMSE': 730.9217,
    'R2': 0.9128,
    'RMSLE': 0.3436,
    'MAPE': 0.2812
}

combined_metrics.loc[len(combined_metrics)] = new_data

# %%
combined_metrics

# %%
with open('pickles/data_adj.pkl', 'wb') as f:
    pickle.dump(data_adj, f)
with open('pickles/data_adj_unseen.pkl', 'wb') as f:
    pickle.dump(data_adj_unseen, f)
with open('pickles/combined_metrics.pkl', 'wb') as f:
    pickle.dump(combined_metrics, f)
